# %%
import pandas as pd
from lxml import etree
import datetime 
from xml.etree.ElementTree import Element, SubElement, tostring
from xml.dom.minidom import parseString

# %%
#render the csv into page xml, with the coords and text. below is another rendering using a the un-preprocessed Tesseract ocr

def arrange_rectangle_coords_from_string_to_string(coord_str):
    # Split the string into a list of tuples
    coords = [tuple(map(int, coord.split(','))) for coord in coord_str.split()]

    if len(coords) != 4:
        raise ValueError("Four coordinates are required to form a rectangle.")

    # Extract coordinates
    x_coords = [coord[0] for coord in coords]
    y_coords = [coord[1] for coord in coords]

    # Find the corners
    top_left = (min(x_coords), min(y_coords))
    top_right = (max(x_coords), min(y_coords))
    bottom_right = (max(x_coords), max(y_coords))
    bottom_left = (min(x_coords), max(y_coords))

    # Arrange in string format
    rectangle_string = f"{top_left[0]},{top_left[1]} {top_right[0]},{top_right[1]} {bottom_right[0]},{bottom_right[1]} {bottom_left[0]},{bottom_left[1]}"

    return rectangle_string

def create_page_xml(row):
    # Create the XML structure
    pcgts = Element('PcGts', {
        'xmlns': 'http://schema.primaresearch.org/PAGE/gts/pagecontent/2019-07-15',
        'xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
        'xsi:schemaLocation': 'http://schema.primaresearch.org/PAGE/gts/pagecontent/2019-07-15 http://schema.primaresearch.org/PAGE/gts/pagecontent/2019-07-15/pagecontent.xsd'
    })
    metadata = SubElement(pcgts, 'Metadata')
    creator = SubElement(metadata, 'Creator')
    creator.text = 'escriptorium'
    created = SubElement(metadata, 'Created')
    created.text = '2024-02-18T21:02:47.785694+00:00'
    last_change = SubElement(metadata, 'LastChange')
    last_change.text = '2024-02-20T08:09:51.332236+00:00'

    page = SubElement(pcgts, 'Page', {
        'imageFilename': f"{row['identifier']}.tif"
    })

    # Add regions with coordinates
    regions = {}

    for region_type in ['ocr_writen_on_coords', 'ocr_writen_by_coords', 'ocr_main_content_coords', 'ocr_additional_content_coords']:
        if pd.notna(row[region_type]):
            coords_str = arrange_rectangle_coords_from_string_to_string(row[region_type])
            text_column_name = region_type.replace('_coords', '')
            text_content = row[text_column_name] if pd.notna(row[text_column_name]) else ''

            if coords_str in regions:
                regions[coords_str] += ' ' + text_content
            else:
                regions[coords_str] = text_content

    for coords_str, text_content in regions.items():
        text_region = SubElement(page, 'TextRegion', {'id': f'eSc_region_{coords_str.replace(",", "_").replace(" ", "_")}', 'custom': 'structure {type:text;}'})
        coords = SubElement(text_region, 'Coords', {'points': coords_str})

        # Add a default text line with the same coordinates as the region
        text_line = SubElement(text_region, 'TextLine', {'id': f'eSc_line_{coords_str.replace(",", "_").replace(" ", "_")}', 'custom': 'structure {type:default;}'})
        line_coords = SubElement(text_line, 'Coords', {'points': coords_str})

        # Add a baseline with only the bottom line of the rectangle
        _,  _, bottom_left, bottom_right = coords_str.split()
        baseline_points = f"{bottom_right} {bottom_left}"
        baseline = SubElement(text_line, 'Baseline', {'points': baseline_points})

        text_equiv = SubElement(text_line, 'TextEquiv')
        unicode_element = SubElement(text_equiv, 'Unicode')
        unicode_element.text = text_content.strip()


    # Convert to a pretty XML string
    xml_str = tostring(pcgts)
    pretty_xml_str = parseString(xml_str).toprettyxml()

    return pretty_xml_str

def process_csv_to_xml(csv_file):
    df = pd.read_csv(csv_file, encoding='utf8')
    for _, row in df.iterrows():
        xml_str = create_page_xml(row)
        # Save the XML to a file
        with open(f'XMLS/{row["identifier"]}.xml', 'w', encoding='utf8') as f:
            f.write(xml_str)
    return df
            
# Example usage
csv_file = 'gnazim_db_meta_data_2k_fixed_coords_utf8.csv'
df = process_csv_to_xml(csv_file)

# %%
df.head(10)
# Out:
#       identifier                                       path  \
# 0   IDGNAZIM0001  \CD00085 גורי, חיים - גורי, חיים\2266.tif
# 1   IDGNAZIM0002  \CD00085 גורי, חיים - גורי, חיים\2277.tif
# 2   IDGNAZIM0003  \CD00085 גורי, חיים - גורי, חיים\2253.tif
# 3   IDGNAZIM0004  \CD00085 גורי, חיים - גורי, חיים\2264.tif
# 4   IDGNAZIM0005  \CD00085 גורי, חיים - גורי, חיים\2272.tif
# 5   IDGNAZIM0006  \CD00085 גורי, חיים - גורי, חיים\2262.tif
# 6   IDGNAZIM0007  \CD00085 גורי, חיים - גורי, חיים\2270.tif
# 7   IDGNAZIM0008  \CD00085 גורי, חיים - גורי, חיים\2258.tif
# 8   IDGNAZIM0009  \CD00085 גורי, חיים - גורי, חיים\2255.tif
# 9  IDGNAZIM00010  \CD00085 גורי, חיים - גורי, חיים\2257.tif
#
#                          gcp_file_id                       folder_name  \
# 0  1ASOIID456UbRActNY4dcTHyuq0vcow-z  \CD00085 גורי, חיים - גורי, חיים
# 1  10GB_ugUJSVRfVZFXvLpiOCH9dK6l2-1S  \CD00085 גורי, חיים - גורי, חיים
# 2  1b-fyZK6WC0_FRQSWw2DmHnQQB4L0aHZ3  \CD00085 גורי, חיים - גורי, חיים
# 3  1WLWQ1PZ0zDlKsy6ULhPqmos_lo0qFoGK  \CD00085 גורי, חיים - גורי, חיים
# 4  1mukseIvdGHRIHT0sa0Kl1y6eL1EVBYc3  \CD00085 גורי, חיים - גורי, חיים
# 5  1aPQ0oKwooEPbFdXtZfMbsixjTJtNaQfO  \CD00085 גורי, חיים - גורי, חיים
# 6  1cOJGWkJe34Ksus91eD0J1NkJkolFFLKl  \CD00085 גורי, חיים - גורי, חיים
# 7  1wJHtBpeV8RuzHvJdkYgOdY7HcT4t5KZD  \CD00085 גורי, חיים - גורי, חיים
# 8  1Sfb3E21zsbFqhrP50vF-xrRz_-5CkKex  \CD00085 גורי, חיים - גורי, חיים
# 9  1ue_PgSjq5bYLXN7GhGdnDl6XQ_VlAexJ  \CD00085 גורי, חיים - גורי, חיים
#
#   author_subject  type  Years                      gcp_folder_id file_name  \
# 0     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2266.tif
# 1     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2277.tif
# 2     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2253.tif
# 3     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2264.tif
# 4     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2272.tif
# 5     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2262.tif
# 6     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2270.tif
# 7     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2258.tif
# 8     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2255.tif
# 9     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2257.tif
#
#           ocr_writen_on  ...      ocr_additional_content_coords  \
# 0                  ]ערה  ...    485,696 550,696 485,812 550,812
# 1  גורי,חיים, עוזר יוסף  ...                                NaN
# 2                     -  ...    298,17 1204,17 298,162 1204,162
# 3                    ים  ...    571,285 743,285 571,343 743,343
# 4            גורי, חיים  ...    131,527 778,527 131,614 778,614
# 5           גורי.בסחיים  ...  999,505 1162,505 999,551 1162,551
# 6            גורי, היים  ...    565,253 986,253 565,339 986,339
# 7            גורי, חייס  ...    960,88 1196,88 960,152 1196,152
# 8             גורי, ח"ם  ...    587,527 841,527 587,592 841,592
# 9           גורי,ן חייס  ...    992,70 1229,70 992,135 1229,135
#
#   paragraphs_detection_successes  \
# 0                           True
# 1                           True
# 2                           True
# 3                           True
# 4                           True
# 5                           True
# 6                           True
# 7                           True
# 8                           True
# 9                           True
#
#                              ocr_all_text_preprocess  \
# 0                   סי | כב // / ָ 9 ה [ערה, ס.ל, /
# 1  גורי,חיים, עוזר יוסף הנה מוסלות טליתותינו יוסף...
# 2  %]ר, הו כ 3 א | ₪2 0 ת)שת | 4 א ג = תאו [ - , ...
# 3  גורי, חיים תקוות "אנסי התושך" שחלפה לפרתחב, 20...
# 4  גורי, חיים תס"תח - תסט"ז 5 7 (פה אומרים?) חתום...
# 5                       גורי.בסחיים ההפהיד רנוער לי
# 6  גורי, היים תשובה לעמוס עוז ‏ [על טכתבו הבהול] ...
# 7  גורי, חייס וכ תפילב2 2 היים אהל, שער לסירה הצק...
# 8  גו רי, חיים על החומה רי* וחו מה , תל- שביב, מ ...
# 9  גורי, חייס הפילה ריר משמר לילדים, שנה י"ג, חוב...
#
#                           ocr_all_text_no_preprocess  \
# 0                                                NaN
# 1  גורי,תיים 0 , עוזר יוסף הנח מוטלות טליתותינו י...
# 2       %!ר, / 27 ז 3 ₪9 2 7 ץ . גי \ תאו [ -. 5 וע
# 3  תקופת "אנטי התוטך" שחלפה למרחתחב, 80.4.1956, ע...
# 4  גורי, חיים תטש"ח - תשט"צך (מה אומרים?) חתום ג ...
# 5  גורי.חיים - התפקיד ‏ שנועד לי דבר.כב טבת תשמז2...
# 6  גורי, ‏ חיים תשובה לעמוס עוז [על מכתבו הבהול] ...
# 7  גורי, חיים : > תפילת כ חיים אהל, שער לשירה הצע...
# 8  גורי, ח"ם תפלה ₪5 על החומה, תלדאביב, מרץ 1950,...
# 9  גור", תיים תפילה רשיר-) משמר לילדים, שנה ל"ג, ...
#
#                 ocr_main_content_all_text_preprocess  \
# 0                                ָ 9 ה [ערה, ס.ל, /
# 1  ו יוסף עוזר משורר סחזר בתצטובר, בטיחוהת מפגלצ ...
# 2                                                NaN
# 3        אנסי התושך" שחלפה לפרתחב, 20.4.1956, עס' 2
# 4                 ום הג ) / לפרחב, 16.4.1956, עם' 2
# 5                                          רנוער לי
# 6   [על טכתבו הבהול] דבר,53 תערי תטל"ד, (2.10.75)...
# 7               לסירה הצקירה, ת"א תשסל"ג, עמ" 53/48
# 8      מה רי* וחו מה , תל- שביב, מ טפ 19 , נ כמ .10
# 9         לדים, שנה י"ג, חוב ו3, 22.4.1958, עם" 503
#
#              ocr_main_content_all_text_no_preprocess years  \
# 0                                                NaN   NaN
# 1  תינו יוסף עוזר משורר שחזר בתשובה בשיחות מפגש ע...   NaN
# 2                                                NaN   NaN
# 3                   שחלפה למרחתחב, 80.4.1956, עמ' 8    NaN
# 4                         ג למרהב, 16.4,1956, עמ' 2    NaN
# 5          ‏ שנועד לי דבר.כב טבת תשמז25.1.1987עמ 16    NaN
# 6   [על מכתבו הבהול] דבר,5 תשרי תשל"ד, (2.10.73)ע...   NaN
# 7                לשירה הצעירה, ת"א תשל"ג, עמ" 53/48    NaN
# 8                על החומה, תלדאביב, מרץ 1950, 9מ.10    NaN
# 9       לילדים, שנה ל"ג, הוב 31, 22.4.1958, עם* 503    NaN
#
#                                       gcp_image_link  \
# 0  https://drive.google.com/file/d/1ASOIID456UbRA...
# 1  https://drive.google.com/file/d/10GB_ugUJSVRfV...
# 2  https://drive.google.com/file/d/1b-fyZK6WC0_FR...
# 3  https://drive.google.com/file/d/1WLWQ1PZ0zDlKs...
# 4  https://drive.google.com/file/d/1mukseIvdGHRIH...
# 5  https://drive.google.com/file/d/1aPQ0oKwooEPbF...
# 6  https://drive.google.com/file/d/1cOJGWkJe34Ksu...
# 7  https://drive.google.com/file/d/1wJHtBpeV8RuzH...
# 8  https://drive.google.com/file/d/1Sfb3E21zsbFqh...
# 9  https://drive.google.com/file/d/1ue_PgSjq5bYLX...
#
#                                      gcp_folder_link is_handwritten
# 0  https://drive.google.com/drive/folders/1c6Bz4o...              1
# 1  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 2  https://drive.google.com/drive/folders/1c6Bz4o...              1
# 3  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 4  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 5  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 6  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 7  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 8  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 9  https://drive.google.com/drive/folders/1c6Bz4o...              0
#
# [10 rows x 26 columns]

# %%
df.head()
# Out:
#      identifier                                       path  \
# 0  IDGNAZIM0001  \CD00085 גורי, חיים - גורי, חיים\2266.tif
# 1  IDGNAZIM0002  \CD00085 גורי, חיים - גורי, חיים\2277.tif
# 2  IDGNAZIM0003  \CD00085 גורי, חיים - גורי, חיים\2253.tif
# 3  IDGNAZIM0004  \CD00085 גורי, חיים - גורי, חיים\2264.tif
# 4  IDGNAZIM0005  \CD00085 גורי, חיים - גורי, חיים\2272.tif
#
#                          gcp_file_id                       folder_name  \
# 0  1ASOIID456UbRActNY4dcTHyuq0vcow-z  \CD00085 גורי, חיים - גורי, חיים
# 1  10GB_ugUJSVRfVZFXvLpiOCH9dK6l2-1S  \CD00085 גורי, חיים - גורי, חיים
# 2  1b-fyZK6WC0_FRQSWw2DmHnQQB4L0aHZ3  \CD00085 גורי, חיים - גורי, חיים
# 3  1WLWQ1PZ0zDlKsy6ULhPqmos_lo0qFoGK  \CD00085 גורי, חיים - גורי, חיים
# 4  1mukseIvdGHRIHT0sa0Kl1y6eL1EVBYc3  \CD00085 גורי, חיים - גורי, חיים
#
#   author_subject  type  Years                      gcp_folder_id file_name  \
# 0     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2266.tif
# 1     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2277.tif
# 2     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2253.tif
# 3     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2264.tif
# 4     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2272.tif
#
#           ocr_writen_on  ...    ocr_additional_content_coords  \
# 0                  ]ערה  ...  485,696 550,696 485,812 550,812
# 1  גורי,חיים, עוזר יוסף  ...                              NaN
# 2                     -  ...  298,17 1204,17 298,162 1204,162
# 3                    ים  ...  571,285 743,285 571,343 743,343
# 4            גורי, חיים  ...  131,527 778,527 131,614 778,614
#
#   paragraphs_detection_successes  \
# 0                           True
# 1                           True
# 2                           True
# 3                           True
# 4                           True
#
#                              ocr_all_text_preprocess  \
# 0                   סי | כב // / ָ 9 ה [ערה, ס.ל, /
# 1  גורי,חיים, עוזר יוסף הנה מוסלות טליתותינו יוסף...
# 2  %]ר, הו כ 3 א | ₪2 0 ת)שת | 4 א ג = תאו [ - , ...
# 3  גורי, חיים תקוות "אנסי התושך" שחלפה לפרתחב, 20...
# 4  גורי, חיים תס"תח - תסט"ז 5 7 (פה אומרים?) חתום...
#
#                           ocr_all_text_no_preprocess  \
# 0                                                NaN
# 1  גורי,תיים 0 , עוזר יוסף הנח מוטלות טליתותינו י...
# 2       %!ר, / 27 ז 3 ₪9 2 7 ץ . גי \ תאו [ -. 5 וע
# 3  תקופת "אנטי התוטך" שחלפה למרחתחב, 80.4.1956, ע...
# 4  גורי, חיים תטש"ח - תשט"צך (מה אומרים?) חתום ג ...
#
#                 ocr_main_content_all_text_preprocess  \
# 0                                ָ 9 ה [ערה, ס.ל, /
# 1  ו יוסף עוזר משורר סחזר בתצטובר, בטיחוהת מפגלצ ...
# 2                                                NaN
# 3        אנסי התושך" שחלפה לפרתחב, 20.4.1956, עס' 2
# 4                 ום הג ) / לפרחב, 16.4.1956, עם' 2
#
#              ocr_main_content_all_text_no_preprocess years  \
# 0                                                NaN   NaN
# 1  תינו יוסף עוזר משורר שחזר בתשובה בשיחות מפגש ע...   NaN
# 2                                                NaN   NaN
# 3                   שחלפה למרחתחב, 80.4.1956, עמ' 8    NaN
# 4                         ג למרהב, 16.4,1956, עמ' 2    NaN
#
#                                       gcp_image_link  \
# 0  https://drive.google.com/file/d/1ASOIID456UbRA...
# 1  https://drive.google.com/file/d/10GB_ugUJSVRfV...
# 2  https://drive.google.com/file/d/1b-fyZK6WC0_FR...
# 3  https://drive.google.com/file/d/1WLWQ1PZ0zDlKs...
# 4  https://drive.google.com/file/d/1mukseIvdGHRIH...
#
#                                      gcp_folder_link is_handwritten
# 0  https://drive.google.com/drive/folders/1c6Bz4o...              1
# 1  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 2  https://drive.google.com/drive/folders/1c6Bz4o...              1
# 3  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 4  https://drive.google.com/drive/folders/1c6Bz4o...              0
#
# [5 rows x 26 columns]

# %%
# adapting the first rendering function to encode the OCRed data from tesseract, without any subdivision or coordinates.

def create_page_xml(row):
    # Create the XML structure
    pcgts = Element('PcGts', {
        'xmlns': 'http://schema.primaresearch.org/PAGE/gts/pagecontent/2019-07-15',
        'xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
        'xsi:schemaLocation': 'http://schema.primaresearch.org/PAGE/gts/pagecontent/2019-07-15 http://schema.primaresearch.org/PAGE/gts/pagecontent/2019-07-15/pagecontent.xsd'
    })
    metadata = SubElement(pcgts, 'Metadata')
    creator = SubElement(metadata, 'Creator')
    creator.text = 'escriptorium'
    created = SubElement(metadata, 'Created')
    created.text = '2024-02-18T21:02:47.785694+00:00'
    last_change = SubElement(metadata, 'LastChange')
    last_change.text = '2024-02-20T08:09:51.332236+00:00'

    page = SubElement(pcgts, 'Page', {
        'imageFilename': f"{row['identifier']}.tif"
    })

    # Add a default region and coordinates
    
    text_column_name = 'ocr_all_text_no_preprocess'
    if pd.notna(row[text_column_name]):
        text_content = row[text_column_name]
        image_path = f"Images/{row['identifier']}.tif"
        image = Image.open(image_path)

        # Get image dimensions
        width, height = image.size

        # Create default coordinates
        coords_str = f"0,0 {width},0 {width},{height} 0,{height}"

        text_region = SubElement(page, 'TextRegion', {'id': f'eSc_region_{coords_str.replace(",", "_").replace(" ", "_")}', 'custom': 'structure {type:text;}'})
        coords = SubElement(text_region, 'Coords', {'points': coords_str})

        # Add a default text line with the same coordinates as the region
        text_line = SubElement(text_region, 'TextLine', {'id': f'eSc_line_{coords_str.replace(",", "_").replace(" ", "_")}', 'custom': 'structure {type:default;}'})
        line_coords = SubElement(text_line, 'Coords', {'points': coords_str})

        # Add a baseline with only the bottom line of the rectangle
        _,  _, bottom_left, bottom_right = coords_str.split()
        baseline_points = f"{bottom_right} {bottom_left}"
        baseline = SubElement(text_line, 'Baseline', {'points': baseline_points})

        text_equiv = SubElement(text_line, 'TextEquiv')
        unicode_element = SubElement(text_equiv, 'Unicode')
        unicode_element.text = text_content.strip()


    # Convert to a pretty XML string
    xml_str = tostring(pcgts)
    pretty_xml_str = parseString(xml_str).toprettyxml()

    return pretty_xml_str

def process_csv_to_xml(csv_file):
    df = pd.read_csv(csv_file, encoding='utf8')
    for _, row in df.iterrows():
        xml_str = create_page_xml(row)
        # Save the XML to a file
        with open(f'XMLS/To Upload/{row["identifier"]}.xml', 'w', encoding='utf8') as f:
            f.write(xml_str)
    return df
            
# Example usage
csv_file = 'gnazim_db_meta_data_2k_fixed_coords_utf8.csv'
df = process_csv_to_xml(csv_file)

# %%
from PIL import Image

image_path = 'Images/IDGNAZIM0005.tif'
image = Image.open(image_path)

# Get image dimensions
width, height = image.size

# Create default coordinates
default_coordinates = f"0,0 {width},0 {width},{height} 0,{height}"

# Print default coordinates
print(f"Default coordinates: {default_coordinates}")
# Out:
# Default coordinates: 0,0 1186,0 1186,795 0,795

# %%
# download images from google drive

# %%
#initialize the drive
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive

def establish_connection() -> GoogleDrive:
    """Establishes connection to Google Drive.

    Returns:
        An instance of GoogleDrive which is authenticated and ready to use.
    """
    gauth = GoogleAuth()
    gauth.LocalWebserverAuth()  # This will open a browser window for authentication.
    return GoogleDrive(gauth)

def test_establish_connection():
    """Tests the establish_connection function by attempting to authenticate."""
    try:
        drive = establish_connection()
        print("Authentication successful!")
        return drive
    except Exception as e:
        print(f"Authentication failed: {e}")
        return None

def test_connection(drive: GoogleDrive):
    """Tests the connection to Google Drive by listing the first 5 files.

    Args:
        drive: An authenticated GoogleDrive instance.
    """
    if drive is None:
        print("Cannot test connection because authentication failed.")
        return

    try:
        file_list = drive.ListFile({'q': "'root' in parents and trashed=false", 'maxResults': 5}).GetList()
        print("Connection successful! Here are the first 5 files in your Google Drive:")
        for file in file_list:
            print(f'- {file["title"]}')
    except Exception as e:
        print(f"An error occurred while listing files: {e}")

if __name__ == "__main__":
    # Test the establish_connection function
    drive = test_establish_connection()

    # Test the connection
    test_connection(drive)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=1007301603530-of60vh7oh54n3ruao261tms36kehruan.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=online&response_type=code
#
# Authentication successful.
# Authentication successful!
# Connection successful! Here are the first 5 files in your Google Drive:
# - All Magazines All Object-Verb Sub-Corpus 2024-01-30.csv
# - Chapter 3, datafication and digital philology.pptx
# - תמונה הלל.jpeg
# - All Magazines Object-Verb Sub-Corpus 2024-01-09.csv
# - All Magazines Object-Verb Sub-Corpus 2023-12-25.csv

# %%
#now this works, after initializing above. make sure no localhost8080 are running
file_id = '1cGPC3OCLB58l9jYut--yhmgo8VMzpG2e'

# Path where the image will be saved
save_path = 'downloaded_image.tif'

def download_image(drive: GoogleDrive, file_id: str, save_path: str):
    """Downloads an image from Google Drive.

    Args:
        drive: An authenticated GoogleDrive instance.
        file_id: The ID of the file to download.
        save_path: The path where the image will be saved.
    """
    file = drive.CreateFile({'id': file_id})
    file.GetContentFile(save_path)
    print(f"Image downloaded and saved as {save_path}")

# Download the image
download_image(drive, file_id, save_path)

# %%
row['gcp_image_link']
# Out:
# 'https://drive.google.com/file/d/1cGPC3OCLB58l9jYut--yhmgo8VMzpG2e'

# %%
#this is the loop for downloading the images
for index, row in df.iterrows():
    file_id = row['gcp_file_id']
    destination = f"Images/{row['identifier']}.tif"  # Adjust the path as needed
    download_image(drive, file_id, destination)

# %%
#display the boxes of an image according to the coordinates 
import pandas as pd
from PIL import Image, ImageDraw

# Initialize the image filename
image_filename = "2272.tif"

# Load the CSV file into a DataFrame with the specified encoding
csv_file = 'gnazim_db_meta_data_2k_fixed_coords_utf8.csv'
df = pd.read_csv(csv_file, encoding="utf8")

# Filter the DataFrame for the row with the specified image filename
row = df[df['file_name'] == image_filename]

# Extract the coordinates from the appropriate columns
ocr_writen_on_coords = row['ocr_writen_on_coords'].values[0]
ocr_writen_by_coords = row['ocr_writen_by_coords'].values[0]
ocr_main_content_coords = row['ocr_main_content_coords'].values[0]
ocr_additional_content_coords = row['ocr_additional_content_coords'].values[0]

# Convert the coordinate strings to lists of tuples
def convert_to_tuples(coord_str):
    if pd.isna(coord_str):
        return []
    return [(int(x.split(',')[0]), int(x.split(',')[1])) for x in coord_str.split()]

ocr_writen_on_coords = convert_to_tuples(ocr_writen_on_coords)
ocr_writen_by_coords = convert_to_tuples(ocr_writen_by_coords)
ocr_main_content_coords = convert_to_tuples(ocr_main_content_coords)
ocr_additional_content_coords = convert_to_tuples(ocr_additional_content_coords)

# Load the image and draw the coordinates
image = Image.open(image_filename)
if image.mode != 'RGB':
    image = image.convert('RGB')

# Create a drawing context
draw = ImageDraw.Draw(image)

def draw_rectangle_from_coords(coords, color):
    if coords:
        # Assume the coordinates are in the order: top-left, top-right, bottom-right, bottom-left
        top_left = coords[0]
        bottom_right = coords[-1]
        draw.rectangle([top_left, bottom_right], outline=color, width=3)
        print('tried to draw...')

draw_rectangle_from_coords(ocr_writen_on_coords, 'red')
draw_rectangle_from_coords(ocr_writen_by_coords, 'green')
draw_rectangle_from_coords(ocr_main_content_coords, 'blue')
draw_rectangle_from_coords(ocr_additional_content_coords, 'yellow')

# Show the image
image.show()
# Out:
# tried to draw...
# tried to draw...
# tried to draw...
# tried to draw...

# %%
image = Image.open(image_filename)
image = image.convert('RGB')
draw.rectangle([50, 50, 200, 200], outline='green', width=3)
image.show()

# %%
image.close()

# %%
df
# Out:
#            identifier                                       path  \
# 0        IDGNAZIM0001  \CD00085 גורי, חיים - גורי, חיים\2266.tif
# 1        IDGNAZIM0002  \CD00085 גורי, חיים - גורי, חיים\2277.tif
# 2        IDGNAZIM0003  \CD00085 גורי, חיים - גורי, חיים\2253.tif
# 3        IDGNAZIM0004  \CD00085 גורי, חיים - גורי, חיים\2264.tif
# 4        IDGNAZIM0005  \CD00085 גורי, חיים - גורי, חיים\2272.tif
# ...               ...                                        ...
# 2273  IDGNAZIM0002274  \CD00085 גורי, חיים - גורי, חיים\0004.tif
# 2274  IDGNAZIM0002275  \CD00085 גורי, חיים - גורי, חיים\0009.tif
# 2275  IDGNAZIM0002276  \CD00085 גורי, חיים - גורי, חיים\0005.tif
# 2276  IDGNAZIM0002277  \CD00085 גורי, חיים - גורי, חיים\0003.tif
# 2277  IDGNAZIM0002278  \CD00085 גורי, חיים - גורי, חיים\0002.tif
#
#                             gcp_file_id                       folder_name  \
# 0     1ASOIID456UbRActNY4dcTHyuq0vcow-z  \CD00085 גורי, חיים - גורי, חיים
# 1     10GB_ugUJSVRfVZFXvLpiOCH9dK6l2-1S  \CD00085 גורי, חיים - גורי, חיים
# 2     1b-fyZK6WC0_FRQSWw2DmHnQQB4L0aHZ3  \CD00085 גורי, חיים - גורי, חיים
# 3     1WLWQ1PZ0zDlKsy6ULhPqmos_lo0qFoGK  \CD00085 גורי, חיים - גורי, חיים
# 4     1mukseIvdGHRIHT0sa0Kl1y6eL1EVBYc3  \CD00085 גורי, חיים - גורי, חיים
# ...                                 ...                               ...
# 2273  1JTYY7KeITKvyuRI-rcIErLE3tX1awH6p  \CD00085 גורי, חיים - גורי, חיים
# 2274  1f4jiF2X6maCKKVf6QrhIWOycfxVZk8aB  \CD00085 גורי, חיים - גורי, חיים
# 2275  1pqUFNIObU8iUAOIG7QeLs90HrFucSZhk  \CD00085 גורי, חיים - גורי, חיים
# 2276  1JCCh65Ed6RQGH62XrNVaziOW0Isl24Tp  \CD00085 גורי, חיים - גורי, חיים
# 2277  1DCs7WVGm_vUIHchO5ufn4L7q_e72Rngx  \CD00085 גורי, חיים - גורי, חיים
#
#      author_subject  type  Years                      gcp_folder_id file_name  \
# 0        גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2266.tif
# 1        גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2277.tif
# 2        גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2253.tif
# 3        גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2264.tif
# 4        גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  2272.tif
# ...             ...   ...    ...                                ...       ...
# 2273     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  0004.tif
# 2274     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  0009.tif
# 2275     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  0005.tif
# 2276     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  0003.tif
# 2277     גורי, חיים   NaN    NaN  1c6Bz4okJqtRXoTqvR4BXBxN3h1o71KDT  0002.tif
#
#              ocr_writen_on  ...      ocr_additional_content_coords  \
# 0                     ]ערה  ...    485,696 550,696 485,812 550,812
# 1     גורי,חיים, עוזר יוסף  ...                                NaN
# 2                        -  ...    298,17 1204,17 298,162 1204,162
# 3                       ים  ...    571,285 743,285 571,343 743,343
# 4               גורי, חיים  ...    131,527 778,527 131,614 778,614
# ...                    ...  ...                                ...
# 2273                  ל, 2  ...                                NaN
# 2274             גורי.חייס  ...    205,479 502,479 205,536 502,536
# 2275            גורי חתיים  ...  458,582 1157,582 458,657 1157,657
# 2276             גורי,חיים  ...  928,133 1168,133 928,206 1168,206
# 2277            וגורי חיים  ...    684,283 815,283 684,410 815,410
#
#      paragraphs_detection_successes  \
# 0                              True
# 1                              True
# 2                              True
# 3                              True
# 4                              True
# ...                             ...
# 2273                           True
# 2274                           True
# 2275                           True
# 2276                           True
# 2277                           True
#
#                                 ocr_all_text_preprocess  \
# 0                      סי | כב // / ָ 9 ה [ערה, ס.ל, /
# 1     גורי,חיים, עוזר יוסף הנה מוסלות טליתותינו יוסף...
# 2     %]ר, הו כ 3 א | ₪2 0 ת)שת | 4 א ג = תאו [ - , ...
# 3     גורי, חיים תקוות "אנסי התושך" שחלפה לפרתחב, 20...
# 4     גורי, חיים תס"תח - תסט"ז 5 7 (פה אומרים?) חתום...
# ...                                                 ...
# 2273  ל, 2 ב13 ג'ג הר 5% חוכ 53 - 91% | / 57 כ כ רצי...
# 2274  גורי.חייס (אבינו סבטמים יתקדס סמר,-) , (סיץ מת...
# 2275  י, תיים אביב 1975 (מדור רטימות סוף סבוץ) | חתו...
# 2276  גורי,חיים לכרחב, 199.₪.10, אבטירים [רבינה| [ ה...
# 2277                      וגורי חיים 1 פייב': חגור רגי
#
#                              ocr_all_text_no_preprocess  \
# 0                                                   NaN
# 1     גורי,תיים 0 , עוזר יוסף הנח מוטלות טליתותינו י...
# 2          %!ר, / 27 ז 3 ₪9 2 7 ץ . גי \ תאו [ -. 5 וע
# 3     תקופת "אנטי התוטך" שחלפה למרחתחב, 80.4.1956, ע...
# 4     גורי, חיים תטש"ח - תשט"צך (מה אומרים?) חתום ג ...
# ...                                                 ...
# 2273  0 |( 9 5+ ת'ג כ 90| -912| / 25%כי- ו : -0 ה5כ ...
# 2274  גורי.חיים (אבינו שבטמים יתקדס שמך,-)| / (טיץ מ...
# 2275  גוהי, חייםי | . |אביב 1975 (מדור רשימות סוף שב...
# 2276  גורי, חיים אבטיחים [רשימה] [חתפום:ג'ורי| למרחב...
# 2277                           יבורי, חלים פסיב': חגור
#
#                    ocr_main_content_all_text_preprocess  \
# 0                                   ָ 9 ה [ערה, ס.ל, /
# 1     ו יוסף עוזר משורר סחזר בתצטובר, בטיחוהת מפגלצ ...
# 2                                                   NaN
# 3           אנסי התושך" שחלפה לפרתחב, 20.4.1956, עס' 2
# 4                    ום הג ) / לפרחב, 16.4.1956, עם' 2
# ...                                                 ...
# 2273               / 57 כ כ רציי -07 5 ןו ] 7 ת!ג 64 2
# 2274  ים יתקדס סמר,-) , (סיץ מתור התילת הכופרים" סגנ...
# 2275               ר דבר, סז ניפן תסל"ה,(28.0.75),?מ 2
# 2276                 9.₪.10, אבטירים [רבינה| [ הת וכ:ג
# 2277                                           גור רגי
#
#                 ocr_main_content_all_text_no_preprocess years  \
# 0                                                   NaN   NaN
# 1     תינו יוסף עוזר משורר שחזר בתשובה בשיחות מפגש ע...   NaN
# 2                                                   NaN   NaN
# 3                      שחלפה למרחתחב, 80.4.1956, עמ' 8    NaN
# 4                            ג למרהב, 16.4,1956, עמ' 2    NaN
# ...                                                 ...   ...
# 2273               ו : -0 ה5כ ו ( 7% 7 תג 4 ,8 , 1. <2    NaN
# 2274  ים יתקדס שמך,-)| / (טיץ מתוך"תתפילת הכופרים" ס...   NaN
# 2275     | חתום צור) דבר, טז ניפן תשל"ה,(28.3.75),עמ 2    NaN
# 2276       [רשימה] [חתפום:ג'ורי| למרחב,18.8,1955,פמ. 4    NaN
# 2277                                                ור    NaN
#
#                                          gcp_image_link  \
# 0     https://drive.google.com/file/d/1ASOIID456UbRA...
# 1     https://drive.google.com/file/d/10GB_ugUJSVRfV...
# 2     https://drive.google.com/file/d/1b-fyZK6WC0_FR...
# 3     https://drive.google.com/file/d/1WLWQ1PZ0zDlKs...
# 4     https://drive.google.com/file/d/1mukseIvdGHRIH...
# ...                                                 ...
# 2273  https://drive.google.com/file/d/1JTYY7KeITKvyu...
# 2274  https://drive.google.com/file/d/1f4jiF2X6maCKK...
# 2275  https://drive.google.com/file/d/1pqUFNIObU8iUA...
# 2276  https://drive.google.com/file/d/1JCCh65Ed6RQGH...
# 2277  https://drive.google.com/file/d/1DCs7WVGm_vUIH...
#
#                                         gcp_folder_link is_handwritten
# 0     https://drive.google.com/drive/folders/1c6Bz4o...              1
# 1     https://drive.google.com/drive/folders/1c6Bz4o...              0
# 2     https://drive.google.com/drive/folders/1c6Bz4o...              1
# 3     https://drive.google.com/drive/folders/1c6Bz4o...              0
# 4     https://drive.google.com/drive/folders/1c6Bz4o...              0
# ...                                                 ...            ...
# 2273  https://drive.google.com/drive/folders/1c6Bz4o...              1
# 2274  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 2275  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 2276  https://drive.google.com/drive/folders/1c6Bz4o...              0
# 2277  https://drive.google.com/drive/folders/1c6Bz4o...              0
#
# [2278 rows x 26 columns]
