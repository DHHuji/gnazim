# %%
from PIL import Image, ImageOps
import os
import xml.etree.ElementTree as ET

def pad_tiff_image(image_path, target_size, save_path):
    """
    Pads a TIFF image with the required size and centers it, saving the result.
    
    Parameters:
    - image_path: Path to the TIFF image file.
    - target_size: Target size (width, height) for padding.
    - save_path: Path to save the padded image.
    
    Returns:
    - original_size: The original size of the image before padding.
    """
    img = Image.open(image_path)
    original_size = img.size  # (original_width, original_height)
    
    # Calculate padding
    left_padding = (target_size[0] - original_size[0]) // 2
    top_padding = (target_size[1] - original_size[1]) // 2
    
    # Add padding around the image
    padded_img = ImageOps.expand(img, border=(left_padding, top_padding), fill="white")
    
    # Save the padded image
    padded_img.save(save_path, format='TIFF')
    print(f"Padded image saved to {save_path}")
    
    return original_size

def adjust_alto_coordinates_for_padding(xml_file_path, output_file_path, original_size, target_size):
    """
    Adjusts the coordinates in the ALTO XML file by applying the x and y offsets for padding.
    
    Parameters:
    - xml_file_path: Path to the original ALTO XML file.
    - output_file_path: Path to save the modified XML file.
    - original_size: Tuple (original_width, original_height) of the image.
    - target_size: Tuple (target_width, target_height) after padding.
    """
    # Register the namespace without adding a prefix
    ET.register_namespace('', "http://www.loc.gov/standards/alto/ns-v4#")
    
    # Calculate padding offsets
    original_width, original_height = original_size
    target_width, target_height = target_size
    x_offset = (target_width - original_width) // 2
    y_offset = (target_height - original_height) // 2

    # Parse the XML file
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Update the Page width and height to the new size
    ns = {'alto': 'http://www.loc.gov/standards/alto/ns-v4#'}
    page = root.find('.//alto:Page', ns)
    page.set('WIDTH', str(target_width))
    page.set('HEIGHT', str(target_height))

    # Adjust coordinates in TextBlocks, TextLines, and Polygons
    for block in root.findall('.//alto:TextBlock', ns):
        # Adjust block coordinates (HPOS and VPOS)
        block.set('HPOS', str(int(block.get('HPOS')) + x_offset))
        block.set('VPOS', str(int(block.get('VPOS')) + y_offset))

        # Adjust polygons in the block (handling space-separated points)
        shape = block.find('.//alto:Shape/alto:Polygon', ns)
        if shape is not None:
            points = shape.get('POINTS').split()
            new_points = []
            for i in range(0, len(points), 2):  # Process x, y pairs
                try:
                    x = int(points[i])
                    y = int(points[i + 1])
                    new_points.append(f"{x + x_offset} {y + y_offset}")
                except (ValueError, IndexError):
                    print(f"Error parsing point: {points[i:i+2]}")
            shape.set('POINTS', ' '.join(new_points))

        # Adjust each TextLine's coordinates and baseline
        for line in block.findall('.//alto:TextLine', ns):
            line.set('HPOS', str(int(line.get('HPOS')) + x_offset))
            line.set('VPOS', str(int(line.get('VPOS')) + y_offset))

            # Adjust baseline coordinates (also space-separated)
            baseline = line.get('BASELINE', '')
            if baseline:
                baseline_points = baseline.split()
                new_baseline = []
                for i in range(0, len(baseline_points), 2):  # Process x, y pairs
                    try:
                        x = int(baseline_points[i])
                        y = int(baseline_points[i + 1])
                        new_baseline.append(f"{x + x_offset} {y + y_offset}")
                    except (ValueError, IndexError):
                        print(f"Error parsing baseline point: {baseline_points[i:i+2]}")
                line.set('BASELINE', ' '.join(new_baseline))

            # Adjust polygons in the line (handling space-separated points)
            shape = line.find('.//alto:Shape/alto:Polygon', ns)
            if shape is not None:
                points = shape.get('POINTS').split()
                new_points = []
                for i in range(0, len(points), 2):  # Process x, y pairs
                    try:
                        x = int(points[i])
                        y = int(points[i + 1])
                        new_points.append(f"{x + x_offset} {y + y_offset}")
                    except (ValueError, IndexError):
                        print(f"Error parsing point: {points[i:i+2]}")
                shape.set('POINTS', ' '.join(new_points))

    # Save the updated XML with correct namespaces
    tree.write(output_file_path, xml_declaration=True, encoding="UTF-8", method="xml")
    print(f"XML coordinates adjusted and saved to {output_file_path}")

def update_all_xmls_and_images_in_folder(input_folder, output_folder, image_folder, padded_image_folder, target_size):
    """
    Loops through all XML files in the input folder, pads their corresponding TIFF images, adjusts XML coordinates,
    and saves the padded images and XML files to the respective output folders.
    
    Parameters:
    - input_folder: Path to the folder containing the original XML files.
    - output_folder: Path to the folder where the updated XML files will be saved.
    - image_folder: Path to the folder containing the corresponding TIFF images.
    - padded_image_folder: Path to save the padded TIFF images.
    - target_size: Tuple (target_width, target_height) after padding.
    """
    # Ensure the output folders exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    if not os.path.exists(padded_image_folder):
        os.makedirs(padded_image_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith('.xml'):
            xml_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, filename)

            # Find the corresponding TIFF image
            base_filename = os.path.splitext(filename)[0]  # Get base name without extension
            tiff_file_path = os.path.join(image_folder, f"{base_filename}.tif")
            padded_image_path = os.path.join(padded_image_folder, f"{base_filename}.tif")

            if os.path.exists(tiff_file_path):
                # Pad the TIFF image and get its original size
                original_size = pad_tiff_image(tiff_file_path, target_size=target_size, save_path=padded_image_path)

                # Adjust the XML coordinates based on the original image size
                adjust_alto_coordinates_for_padding(xml_file_path, output_file_path, original_size, target_size)
            else:
                print(f"Warning: No corresponding TIFF image found for {filename}")

# Example usage:

input_folder = "training_data/updated_uri_gt_alto"  # Replace with the path to the folder with TIFF images
output_folder = "training_data/padded_uri_gt_alto" # Replace with the folder to save updated XML files
image_folder = "training_data/updated_uri_gt_alto"   # Folder containing the TIFF images
padded_image_folder = "training_data/padded_uri_gt_alto"  # Folder to save the padded TIFF images
target_size = (1800, 1800)  # New image size after padding

update_all_xmls_and_images_in_folder(input_folder, output_folder, image_folder, padded_image_folder, target_size)
# Out:
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM0001.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM0001.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00010.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00010.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000100.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000100.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000101.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000101.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000102.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000102.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000103.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000103.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000104.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000104.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000105.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000105.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000106.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000106.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000107.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000107.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000108.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000108.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000109.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000109.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00011.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00011.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000110.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000110.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000111.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000111.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000112.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000112.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000113.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000113.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000114.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000114.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000115.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000115.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000116.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000116.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000117.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000117.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000118.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000118.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000119.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000119.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00012.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00012.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000120.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000120.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000121.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000121.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000122.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000122.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000123.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000123.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000124.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000124.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000125.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000125.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000126.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000126.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000127.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000127.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000128.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000128.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000129.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000129.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00013.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00013.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000130.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000130.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000131.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000131.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000132.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000132.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000133.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000133.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000134.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000134.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000135.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000135.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000136.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000136.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000137.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000137.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000138.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000138.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000139.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000139.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00014.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00014.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000140.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000140.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000141.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000141.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000142.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000142.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000143.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000143.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000144.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000144.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000145.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000145.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000146.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000146.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000147.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000147.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000148.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000148.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000149.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000149.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00015.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00015.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000150.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000150.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000151.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000151.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000152.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000152.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000153.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000153.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000154.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000154.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000155.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000155.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000156.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000156.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000157.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000157.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000158.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000158.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000159.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000159.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00016.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00016.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000160.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000160.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000161.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000161.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000162.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000162.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000163.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000163.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000164.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000164.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000165.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000165.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000166.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000166.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000167.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000167.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000168.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000168.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000169.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000169.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00017.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00017.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000170.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000170.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000171.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000171.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000172.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000172.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000173.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000173.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000174.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000174.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000175.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000175.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000176.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000176.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000177.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000177.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000178.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000178.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000179.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000179.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00018.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00018.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000180.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000180.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000181.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000181.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000182.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000182.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000183.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000183.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000184.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000184.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000185.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000185.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000186.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000186.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000187.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000187.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000188.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000188.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000189.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000189.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00019.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00019.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000190.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000190.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000191.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000191.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000192.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000192.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000193.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000193.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000194.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000194.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000195.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000195.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000196.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000196.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000197.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000197.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000198.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000198.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000199.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000199.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM0002.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM0002.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00020.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00020.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000200.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000200.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000201.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000201.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000202.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000202.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000203.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000203.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000204.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000204.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000205.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000205.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000206.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000206.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000207.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000207.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000208.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000208.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000209.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000209.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00021.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00021.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000210.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000210.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000211.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000211.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000212.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000212.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000213.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000213.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000214.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000214.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000215.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000215.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000216.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000216.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000217.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000217.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000218.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000218.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000219.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000219.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00022.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00022.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000220.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000220.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000221.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000221.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000222.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000222.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000223.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000223.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000224.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000224.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000225.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000225.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000226.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000226.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000227.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000227.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000228.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000228.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000229.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000229.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00023.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00023.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000230.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000230.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000231.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000231.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000232.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000232.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000233.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000233.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000234.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000234.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000235.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000235.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000236.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000236.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000237.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000237.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000238.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000238.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000239.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000239.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00024.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00024.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000240.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000240.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000241.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000241.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000242.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000242.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000243.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000243.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000244.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000244.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000245.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000245.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000246.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000246.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000247.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000247.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000248.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000248.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000249.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000249.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00025.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00025.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM000250.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM000250.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00026.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00026.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00027.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00027.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00028.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00028.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00029.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00029.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM0003.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM0003.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00030.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00030.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00031.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00031.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00032.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00032.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00033.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00033.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00034.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00034.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00035.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00035.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00036.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00036.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00037.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00037.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00038.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00038.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00039.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00039.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM0004.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM0004.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00040.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00040.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00041.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00041.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00042.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00042.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00043.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00043.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00044.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00044.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00045.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00045.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00046.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00046.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00047.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00047.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00048.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00048.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00049.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00049.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM0005.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM0005.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00050.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00050.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00051.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00051.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00052.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00052.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00053.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00053.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00054.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00054.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00055.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00055.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00056.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00056.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00057.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00057.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00058.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00058.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00059.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00059.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM0006.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM0006.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00060.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00060.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00061.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00061.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00062.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00062.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00063.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00063.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00064.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00064.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00065.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00065.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00066.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00066.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00067.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00067.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00068.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00068.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00069.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00069.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM0007.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM0007.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00070.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00070.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00071.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00071.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00072.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00072.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00073.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00073.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00074.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00074.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00075.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00075.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00076.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00076.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00077.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00077.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00078.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00078.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00079.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00079.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM0008.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM0008.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00080.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00080.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00081.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00081.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00082.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00082.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00083.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00083.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00084.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00084.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00085.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00085.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00086.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00086.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00087.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00087.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00088.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00088.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00089.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00089.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM0009.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM0009.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00090.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00090.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00091.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00091.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00092.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00092.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00093.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00093.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00094.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00094.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00095.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00095.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00096.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00096.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00097.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00097.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00098.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00098.xml
# Padded image saved to training_data/padded_uri_gt_alto\IDGNAZIM00099.tif
# XML coordinates adjusted and saved to training_data/padded_uri_gt_alto\IDGNAZIM00099.xml

# %%
from PIL import Image, ImageOps
import os
import xml.etree.ElementTree as ET

def pad_tiff_image(image_path, target_size, save_path):
    """
    Pads a specific TIFF image with the required size and centers it, saving the result.
    
    Parameters:
    - image_path: Path to the TIFF image file.
    - target_size: Target size (width, height) for padding.
    - save_path: Path to save the padded image.
    
    Returns:
    - original_size: The original size of the image before padding.
    """
    img = Image.open(image_path)
    original_size = img.size  # (original_width, original_height)
    
    # Calculate padding
    left_padding = (target_size[0] - original_size[0]) // 2
    top_padding = (target_size[1] - original_size[1]) // 2
    
    # Add padding around the image
    padded_img = ImageOps.expand(img, border=(left_padding, top_padding), fill="white")
    
    # Save the padded image
    padded_img.save(save_path, format='TIFF')
    print(f"Padded image saved to {save_path}")
    
    return original_size

def adjust_alto_coordinates_for_padding(xml_file_path, output_file_path, original_size, target_size):
    """
    Adjusts the coordinates in the ALTO XML file by applying the x and y offsets for padding.
    
    Parameters:
    - xml_file_path: Path to the original ALTO XML file.
    - output_file_path: Path to save the modified XML file.
    - original_size: Tuple (original_width, original_height) of the image.
    - target_size: Tuple (target_width, target_height) after padding.
    """
    # Register the namespace without adding a prefix
    ET.register_namespace('', "http://www.loc.gov/standards/alto/ns-v4#")
    
    # Calculate padding offsets
    original_width, original_height = original_size
    target_width, target_height = target_size
    x_offset = (target_width - original_width) // 2
    y_offset = (target_height - original_height) // 2

    # Parse the XML file
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Update the Page width and height to the new size
    ns = {'alto': 'http://www.loc.gov/standards/alto/ns-v4#'}
    page = root.find('.//alto:Page', ns)
    page.set('WIDTH', str(target_width))
    page.set('HEIGHT', str(target_height))

    # Adjust coordinates in TextBlocks, TextLines, and Polygons
    for block in root.findall('.//alto:TextBlock', ns):
        # Adjust block coordinates (HPOS and VPOS)
        block.set('HPOS', str(int(block.get('HPOS')) + x_offset))
        block.set('VPOS', str(int(block.get('VPOS')) + y_offset))

        # Adjust polygons in the block (handling space-separated points)
        shape = block.find('.//alto:Shape/alto:Polygon', ns)
        if shape is not None:
            points = shape.get('POINTS').split()
            new_points = []
            for i in range(0, len(points), 2):  # Process x, y pairs
                try:
                    x = int(points[i])
                    y = int(points[i + 1])
                    new_points.append(f"{x + x_offset} {y + y_offset}")
                except (ValueError, IndexError):
                    print(f"Error parsing point: {points[i:i+2]}")
            shape.set('POINTS', ' '.join(new_points))

        # Adjust each TextLine's coordinates and baseline
        for line in block.findall('.//alto:TextLine', ns):
            line.set('HPOS', str(int(line.get('HPOS')) + x_offset))
            line.set('VPOS', str(int(line.get('VPOS')) + y_offset))

            # Adjust baseline coordinates (also space-separated)
            baseline = line.get('BASELINE', '')
            if baseline:
                baseline_points = baseline.split()
                new_baseline = []
                for i in range(0, len(baseline_points), 2):  # Process x, y pairs
                    try:
                        x = int(baseline_points[i])
                        y = int(baseline_points[i + 1])
                        new_baseline.append(f"{x + x_offset} {y + y_offset}")
                    except (ValueError, IndexError):
                        print(f"Error parsing baseline point: {baseline_points[i:i+2]}")
                line.set('BASELINE', ' '.join(new_baseline))

            # Adjust polygons in the line (handling space-separated points)
            shape = line.find('.//alto:Shape/alto:Polygon', ns)
            if shape is not None:
                points = shape.get('POINTS').split()
                new_points = []
                for i in range(0, len(points), 2):  # Process x, y pairs
                    try:
                        x = int(points[i])
                        y = int(points[i + 1])
                        new_points.append(f"{x + x_offset} {y + y_offset}")
                    except (ValueError, IndexError):
                        print(f"Error parsing point: {points[i:i+2]}")
                shape.set('POINTS', ' '.join(new_points))

    # Save the updated XML with correct namespaces
    tree.write(output_file_path, xml_declaration=True, encoding="UTF-8", method="xml")
    print(f"XML coordinates adjusted and saved to {output_file_path}")

# Example usage:
image_path = "Images/IDGNAZIM000710.tif"  # Path to the TIFF image file
# xml_file_path = "path/to/your/input.xml"  # Path to the corresponding XML file
padded_image_path = "trial_padded_image.tif"  # Path to save the padded TIFF image
# output_xml_path = "path/to/save/adjusted_xml.xml"  # Path to save the adjusted XML file
target_size = (1700, 1700)  # New image size after padding

# Pad the image
original_size = pad_tiff_image(image_path, target_size=target_size, save_path=padded_image_path)

# # Adjust the XML coordinates based on padding
# adjust_alto_coordinates_for_padding(xml_file_path, output_xml_path, original_size, target_size)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 127
#     124 target_size = (1700, 1700)  # New image size after padding
#     126 # Pad the image
# --> 127 original_size = pad_tiff_image(image_path, target_size=target_size, save_path=padded_image_path)
#     129 # # Adjust the XML coordinates based on padding
#     130 # adjust_alto_coordinates_for_padding(xml_file_path, output_xml_path, original_size, target_size)
#
# Cell In[6], line 28, in pad_tiff_image(image_path, target_size, save_path)
#      25 padded_img = ImageOps.expand(img, border=(left_padding, top_padding), fill="white")
#      27 # Save the padded image
# ---> 28 padded_img.save(save_path, format='TIF')
#      29 print(f"Padded image saved to {save_path}")
#      31 return original_size
#
# File ~\anaconda3\lib\site-packages\PIL\Image.py:2418, in Image.save(self, fp, format, **params)
#    2416     save_handler = SAVE_ALL[format.upper()]
#    2417 else:
# -> 2418     save_handler = SAVE[format.upper()]
#    2420 created = False
#    2421 if open_fp:
#
# KeyError: 'TIF'

# %%
from PIL import Image, ImageOps
import os

def pad_images_in_folder(input_folder, output_folder, target_size=(1700, 1700)):
    """
    Pads all TIFF images in the input folder to the specified size and saves them in the output folder.

    Parameters:
    - input_folder: Path to the folder containing the original TIFF images.
    - output_folder: Path to the folder where the padded images will be saved.
    - target_size: Tuple specifying the target (width, height) after padding.
    """
    # Ensure the output folder exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate over all TIFF images in the input folder
    for filename in os.listdir(input_folder):
        if filename.lower().endswith('.tif'):
            input_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Pad and save the image
            pad_tiff_image(input_path, target_size, output_path)

def pad_tiff_image(image_path, target_size, save_path):
    """
    Pads a single TIFF image to the specified size and saves it.

    Parameters:
    - image_path: Path to the original TIFF image.
    - target_size: Tuple specifying the target (width, height) after padding.
    - save_path: Path to save the padded image.
    """
    img = Image.open(image_path)
    original_size = img.size  # (original_width, original_height)

    # Calculate padding
    left_padding = (target_size[0] - original_size[0]) // 2
    top_padding = (target_size[1] - original_size[1]) // 2

    # Add padding and center the image
    padded_img = ImageOps.expand(img, border=(left_padding, top_padding), fill="white")

    # Save the padded image
    padded_img.save(save_path, format='TIFF')
    print(f"Padded image saved: {save_path}")

# Example usage:
input_folder = "Data/זלדה"  # Replace with the path to your folder with TIFF images
output_folder = "Data/זלדה/Padded Images"  # Replace with the path to the target output folder
target_size = (1800, 1800)  # Specify the desired target size after padding

# Run the function to pad all images in the folder
pad_images_in_folder(input_folder, output_folder, target_size)
# Out:
# Padded image saved: Data/זלדה/Padded Images\2785.tif
# Padded image saved: Data/זלדה/Padded Images\2786.tif
# Padded image saved: Data/זלדה/Padded Images\2787.tif
# Padded image saved: Data/זלדה/Padded Images\2788.tif
# Padded image saved: Data/זלדה/Padded Images\2789.tif
# Padded image saved: Data/זלדה/Padded Images\2790.tif
# Padded image saved: Data/זלדה/Padded Images\2791.tif
# Padded image saved: Data/זלדה/Padded Images\2792.tif
# Padded image saved: Data/זלדה/Padded Images\2793.tif
# Padded image saved: Data/זלדה/Padded Images\2794.tif
# Padded image saved: Data/זלדה/Padded Images\2795.tif
# Padded image saved: Data/זלדה/Padded Images\2796.tif
# Padded image saved: Data/זלדה/Padded Images\2797.tif
# Padded image saved: Data/זלדה/Padded Images\2798.tif
# Padded image saved: Data/זלדה/Padded Images\2799.tif
# Padded image saved: Data/זלדה/Padded Images\2800.tif
# Padded image saved: Data/זלדה/Padded Images\2801.tif
# Padded image saved: Data/זלדה/Padded Images\2802.tif
# Padded image saved: Data/זלדה/Padded Images\2803.tif
# Padded image saved: Data/זלדה/Padded Images\2804.tif
# Padded image saved: Data/זלדה/Padded Images\2805.tif
# Padded image saved: Data/זלדה/Padded Images\2806.tif
# Padded image saved: Data/זלדה/Padded Images\2807.tif
# Padded image saved: Data/זלדה/Padded Images\2808.tif
# Padded image saved: Data/זלדה/Padded Images\2809.tif
# Padded image saved: Data/זלדה/Padded Images\2810.tif
# Padded image saved: Data/זלדה/Padded Images\2811.tif
# Padded image saved: Data/זלדה/Padded Images\2812.tif
# Padded image saved: Data/זלדה/Padded Images\2813.tif
# Padded image saved: Data/זלדה/Padded Images\2814.tif
# Padded image saved: Data/זלדה/Padded Images\2815.tif
# Padded image saved: Data/זלדה/Padded Images\2816.tif
# Padded image saved: Data/זלדה/Padded Images\2817.tif
# Padded image saved: Data/זלדה/Padded Images\2818.tif
# Padded image saved: Data/זלדה/Padded Images\2819.tif
# Padded image saved: Data/זלדה/Padded Images\2820.tif
# Padded image saved: Data/זלדה/Padded Images\2821.tif
# Padded image saved: Data/זלדה/Padded Images\2822.tif
# Padded image saved: Data/זלדה/Padded Images\2823.tif
# Padded image saved: Data/זלדה/Padded Images\2824.tif
# Padded image saved: Data/זלדה/Padded Images\2825.tif
# Padded image saved: Data/זלדה/Padded Images\2826.tif
# Padded image saved: Data/זלדה/Padded Images\2827.tif
# Padded image saved: Data/זלדה/Padded Images\2828.tif
# Padded image saved: Data/זלדה/Padded Images\2829.tif
# Padded image saved: Data/זלדה/Padded Images\2830.tif
# Padded image saved: Data/זלדה/Padded Images\2831.tif
# Padded image saved: Data/זלדה/Padded Images\2832.tif
# Padded image saved: Data/זלדה/Padded Images\2833.tif
# Padded image saved: Data/זלדה/Padded Images\2834.tif
# Padded image saved: Data/זלדה/Padded Images\2835.tif
# Padded image saved: Data/זלדה/Padded Images\2836.tif
# Padded image saved: Data/זלדה/Padded Images\2837.tif
# Padded image saved: Data/זלדה/Padded Images\2838.tif
# Padded image saved: Data/זלדה/Padded Images\2839.tif
# Padded image saved: Data/זלדה/Padded Images\2840.tif
# Padded image saved: Data/זלדה/Padded Images\2841.tif
# Padded image saved: Data/זלדה/Padded Images\2842.tif
# Padded image saved: Data/זלדה/Padded Images\2843.tif
# Padded image saved: Data/זלדה/Padded Images\2844.tif
# Padded image saved: Data/זלדה/Padded Images\2845.tif
# Padded image saved: Data/זלדה/Padded Images\2846.tif
# Padded image saved: Data/זלדה/Padded Images\2847.tif
# Padded image saved: Data/זלדה/Padded Images\2848.tif
# Padded image saved: Data/זלדה/Padded Images\2849.tif
# Padded image saved: Data/זלדה/Padded Images\2850.tif
# Padded image saved: Data/זלדה/Padded Images\2851.tif
# Padded image saved: Data/זלדה/Padded Images\2852.tif
# Padded image saved: Data/זלדה/Padded Images\2853.tif
# Padded image saved: Data/זלדה/Padded Images\2854.tif
# Padded image saved: Data/זלדה/Padded Images\2855.tif
# Padded image saved: Data/זלדה/Padded Images\2856.tif
# Padded image saved: Data/זלדה/Padded Images\2857.tif
# Padded image saved: Data/זלדה/Padded Images\2858.tif
# Padded image saved: Data/זלדה/Padded Images\2859.tif
# Padded image saved: Data/זלדה/Padded Images\2860.tif
# Padded image saved: Data/זלדה/Padded Images\2861.tif
# Padded image saved: Data/זלדה/Padded Images\2862.tif
# Padded image saved: Data/זלדה/Padded Images\2863.tif
# Padded image saved: Data/זלדה/Padded Images\2864.tif
# Padded image saved: Data/זלדה/Padded Images\2865.tif
# Padded image saved: Data/זלדה/Padded Images\2866.tif
# Padded image saved: Data/זלדה/Padded Images\2867.tif
# Padded image saved: Data/זלדה/Padded Images\2868.tif
# Padded image saved: Data/זלדה/Padded Images\2869.tif
# Padded image saved: Data/זלדה/Padded Images\2870.tif
# Padded image saved: Data/זלדה/Padded Images\2871.tif
# Padded image saved: Data/זלדה/Padded Images\2872.tif
# Padded image saved: Data/זלדה/Padded Images\2873.tif
# Padded image saved: Data/זלדה/Padded Images\2874.tif
# Padded image saved: Data/זלדה/Padded Images\2875.tif
# Padded image saved: Data/זלדה/Padded Images\2876.tif
# Padded image saved: Data/זלדה/Padded Images\2877.tif
# Padded image saved: Data/זלדה/Padded Images\2878.tif
# Padded image saved: Data/זלדה/Padded Images\2879.tif
# Padded image saved: Data/זלדה/Padded Images\2880.tif
# Padded image saved: Data/זלדה/Padded Images\2881.tif
# Padded image saved: Data/זלדה/Padded Images\2882.tif
# Padded image saved: Data/זלדה/Padded Images\2883.tif
# Padded image saved: Data/זלדה/Padded Images\2884.tif
# Padded image saved: Data/זלדה/Padded Images\2885.tif
# Padded image saved: Data/זלדה/Padded Images\2886.tif
# Padded image saved: Data/זלדה/Padded Images\2887.tif
# Padded image saved: Data/זלדה/Padded Images\2888.tif
# Padded image saved: Data/זלדה/Padded Images\2889.tif
# Padded image saved: Data/זלדה/Padded Images\2890.tif
# Padded image saved: Data/זלדה/Padded Images\2891.tif
# Padded image saved: Data/זלדה/Padded Images\2892.tif
# Padded image saved: Data/זלדה/Padded Images\2893.tif
# Padded image saved: Data/זלדה/Padded Images\2894.tif
# Padded image saved: Data/זלדה/Padded Images\2895.tif
# Padded image saved: Data/זלדה/Padded Images\2896.tif
# Padded image saved: Data/זלדה/Padded Images\2897.tif
# Padded image saved: Data/זלדה/Padded Images\2898.tif
# Padded image saved: Data/זלדה/Padded Images\2899.tif
# Padded image saved: Data/זלדה/Padded Images\2900.tif
# Padded image saved: Data/זלדה/Padded Images\2901.tif
# Padded image saved: Data/זלדה/Padded Images\2902.tif
# Padded image saved: Data/זלדה/Padded Images\2903.tif
# Padded image saved: Data/זלדה/Padded Images\2904.tif
# Padded image saved: Data/זלדה/Padded Images\2905.tif
# Padded image saved: Data/זלדה/Padded Images\2906.tif
# Padded image saved: Data/זלדה/Padded Images\2907.tif
# Padded image saved: Data/זלדה/Padded Images\2908.tif
# Padded image saved: Data/זלדה/Padded Images\2909.tif
# Padded image saved: Data/זלדה/Padded Images\2910.tif
# Padded image saved: Data/זלדה/Padded Images\2911.tif
# Padded image saved: Data/זלדה/Padded Images\2912.tif
# Padded image saved: Data/זלדה/Padded Images\2913.tif
# Padded image saved: Data/זלדה/Padded Images\2914.tif
# Padded image saved: Data/זלדה/Padded Images\2915.tif
# Padded image saved: Data/זלדה/Padded Images\2916.tif
# Padded image saved: Data/זלדה/Padded Images\2917.tif
# Padded image saved: Data/זלדה/Padded Images\2918.tif
# Padded image saved: Data/זלדה/Padded Images\2919.tif
# Padded image saved: Data/זלדה/Padded Images\2920.tif
# Padded image saved: Data/זלדה/Padded Images\2921.tif
# Padded image saved: Data/זלדה/Padded Images\2922.tif
# Padded image saved: Data/זלדה/Padded Images\2923.tif
# Padded image saved: Data/זלדה/Padded Images\2924.tif
# Padded image saved: Data/זלדה/Padded Images\2925.tif
# Padded image saved: Data/זלדה/Padded Images\2926.tif
# Padded image saved: Data/זלדה/Padded Images\2927.tif
# Padded image saved: Data/זלדה/Padded Images\2928.tif
# Padded image saved: Data/זלדה/Padded Images\2929.tif
# Padded image saved: Data/זלדה/Padded Images\2930.tif
# Padded image saved: Data/זלדה/Padded Images\2931.tif
# Padded image saved: Data/זלדה/Padded Images\2932.tif
# Padded image saved: Data/זלדה/Padded Images\2933.tif
# Padded image saved: Data/זלדה/Padded Images\2934.tif
# Padded image saved: Data/זלדה/Padded Images\2935.tif
# Padded image saved: Data/זלדה/Padded Images\2936.tif
# Padded image saved: Data/זלדה/Padded Images\2937.tif
# Padded image saved: Data/זלדה/Padded Images\2938.tif
# Padded image saved: Data/זלדה/Padded Images\2939.tif
# Padded image saved: Data/זלדה/Padded Images\2940.tif
# Padded image saved: Data/זלדה/Padded Images\2941.tif
# Padded image saved: Data/זלדה/Padded Images\2942.tif
# Padded image saved: Data/זלדה/Padded Images\2943.tif
# Padded image saved: Data/זלדה/Padded Images\2944.tif
# Padded image saved: Data/זלדה/Padded Images\2945.tif
# Padded image saved: Data/זלדה/Padded Images\2946.tif
# Padded image saved: Data/זלדה/Padded Images\2947.tif
# Padded image saved: Data/זלדה/Padded Images\2948.tif
# Padded image saved: Data/זלדה/Padded Images\2949.tif
# Padded image saved: Data/זלדה/Padded Images\2950.tif
# Padded image saved: Data/זלדה/Padded Images\2951.tif
# Padded image saved: Data/זלדה/Padded Images\2952.tif
# Padded image saved: Data/זלדה/Padded Images\2953.tif
# Padded image saved: Data/זלדה/Padded Images\2954.tif
# Padded image saved: Data/זלדה/Padded Images\2955.tif
# Padded image saved: Data/זלדה/Padded Images\2956.tif
# Padded image saved: Data/זלדה/Padded Images\2957.tif
# Padded image saved: Data/זלדה/Padded Images\2958.tif
# Padded image saved: Data/זלדה/Padded Images\2959.tif
# Padded image saved: Data/זלדה/Padded Images\2960.tif
# Padded image saved: Data/זלדה/Padded Images\2961.tif
# Padded image saved: Data/זלדה/Padded Images\2962.tif
# Padded image saved: Data/זלדה/Padded Images\2963.tif
# Padded image saved: Data/זלדה/Padded Images\2964.tif
# Padded image saved: Data/זלדה/Padded Images\2965.tif
# Padded image saved: Data/זלדה/Padded Images\2966.tif
# Padded image saved: Data/זלדה/Padded Images\2967.tif
# Padded image saved: Data/זלדה/Padded Images\2968.tif
# Padded image saved: Data/זלדה/Padded Images\2969.tif
# Padded image saved: Data/זלדה/Padded Images\2970.tif
# Padded image saved: Data/זלדה/Padded Images\2971.tif
# Padded image saved: Data/זלדה/Padded Images\2972.tif
# Padded image saved: Data/זלדה/Padded Images\2973.tif
# Padded image saved: Data/זלדה/Padded Images\2974.tif
# Padded image saved: Data/זלדה/Padded Images\2975.tif
# Padded image saved: Data/זלדה/Padded Images\2976.tif
# Padded image saved: Data/זלדה/Padded Images\2977.tif
# Padded image saved: Data/זלדה/Padded Images\2978.tif
# Padded image saved: Data/זלדה/Padded Images\2979.tif
# Padded image saved: Data/זלדה/Padded Images\2980.tif
# Padded image saved: Data/זלדה/Padded Images\2981.tif
# Padded image saved: Data/זלדה/Padded Images\2982.tif
# Padded image saved: Data/זלדה/Padded Images\2983.tif
# Padded image saved: Data/זלדה/Padded Images\2984.tif
# Padded image saved: Data/זלדה/Padded Images\2985.tif
# Padded image saved: Data/זלדה/Padded Images\2986.tif
# Padded image saved: Data/זלדה/Padded Images\2987.tif
# Padded image saved: Data/זלדה/Padded Images\2988.tif
# Padded image saved: Data/זלדה/Padded Images\2989.tif
# Padded image saved: Data/זלדה/Padded Images\2990.tif
# Padded image saved: Data/זלדה/Padded Images\2991.tif
# Padded image saved: Data/זלדה/Padded Images\2992.tif
# Padded image saved: Data/זלדה/Padded Images\2993.tif
# Padded image saved: Data/זלדה/Padded Images\2994.tif
# Padded image saved: Data/זלדה/Padded Images\2995.tif
# Padded image saved: Data/זלדה/Padded Images\2996.tif
# Padded image saved: Data/זלדה/Padded Images\2997.tif
# Padded image saved: Data/זלדה/Padded Images\2998.tif
# Padded image saved: Data/זלדה/Padded Images\2999.tif
# Padded image saved: Data/זלדה/Padded Images\3000.tif
