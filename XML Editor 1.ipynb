# %%
import os
import shutil
import xml.etree.ElementTree as ET
import openpyxl

# Function to replace commas with spaces in all coordinate attributes
def modify_coordinates_in_xml(xml_file, output_folder, jpg_filename):
    # Define the namespace
    namespace = {'ns': 'http://www.loc.gov/standards/alto/ns-v4#'}

    # Parse the XML file
    tree = ET.parse(xml_file)
    root = tree.getroot()

    # Add the missing xmlns attribute to the root element (if not already present)
    if 'xmlns' not in root.attrib:
        root.set('xmlns', 'http://www.loc.gov/standards/alto/ns-v4#')

    # Iterate through all elements in the XML
    for elem in root.iter():
        # Iterate through all attributes of each element
        for key, value in elem.attrib.items():
            # Check if the attribute value contains coordinates (e.g., points or coords or baseline)
            if 'POINTS' in key or 'COORDS' in key or 'BASELINE' in key:
                # Replace commas with spaces in the coordinates
                new_value = value.replace(',', ' ')
                # Update the attribute with the modified value
                elem.attrib[key] = new_value

            # Remove MASK if empty
            if key == 'MASK' and not value:
                del elem.attrib[key]

            # Ensure proper 'BASELINE' data (add placeholder if missing)
#             if key == 'BASELINE' and not value:
#                 # Add a default baseline if missing (This is a placeholder, adjust as needed)
#                 elem.attrib[key] = "0 0 0 0 0 0 0 0"  # Example placeholder, you can adjust this

        # Update 'fileName' attribute without the namespace prefix
        if elem.tag == '{http://www.loc.gov/standards/alto/ns-v4#}fileName':  # Adjust based on actual tag with namespace
            elem.tag = 'fileName'  # Remove the namespace prefix by changing the tag name
            elem.text = jpg_filename  # Set the filename without the path

    # Write the modified XML to the new folder
    modified_xml_file = os.path.join(output_folder, os.path.basename(xml_file))
    tree.write(modified_xml_file)

    return modified_xml_file

# Function to copy files and create metadata
def process_folder_structure(root_folder, destination_folder, metadata_filename):
    # Create a new Excel file for storing metadata
    wb = openpyxl.Workbook()
    sheet = wb.active
    sheet.append(["File Name", "Path"])  # Header for the metadata

    # Traverse the folder structure
    for subdir, dirs, files in os.walk(root_folder):
        # Look for JPG files and Alto XML files in the appropriate subfolders
        if subdir.endswith("alto"):  # If we're in the 'alto' folder
            # Find all JPGs in the parent folder (above 'alto')
            parent_folder = os.path.dirname(subdir)
            for file in os.listdir(parent_folder):
                if file.lower().endswith(('.jpg', '.jpeg', '.tif', '.tiff')):  # Handle jpg, jpeg, tif, and tiff files
                    # Copy the JPG file to the destination folder
                    image_file_path = os.path.join(parent_folder, file)
                    destination_image = os.path.join(destination_folder, file)
                    shutil.copy(image_file_path, destination_image)

                    # Log metadata for the image
                    sheet.append([file, image_file_path])

            # Now look for the XML files in the 'alto' folder
            for file in files:
                if file.lower().endswith(".xml"):
                    # Process the XML file by fixing its coordinates and updating its filename
                    xml_file_path = os.path.join(subdir, file)
                    image_filename = os.path.splitext(file)[0] + (".tif" if file.lower().endswith(".tif") else ".jpg")  # Update extension accordingly
                    modified_xml_path = modify_coordinates_in_xml(xml_file_path, destination_folder, image_filename)

                    # Log metadata for the XML
                    sheet.append([file, xml_file_path])

    # Save the metadata Excel file
    metadata_file_path = os.path.join(destination_folder, metadata_filename)
    wb.save(metadata_file_path)

    print(f"Processing complete. Metadata saved in: {metadata_file_path}")


# Example usage
root_folder = 'HebHTR_Transkribus'  # Replace with the path to your root folder
destination_folder = 'HTR_pages_Transkribus_NEW'  # Replace with the path to your destination folder
metadata_filename = 'page_metadata.xlsx'  # Name for the metadata file

# Make sure the destination folder exists
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Call the function to process the folder structure
process_folder_structure(root_folder, destination_folder, metadata_filename)
# Out:
# Processing complete. Metadata saved in: HTR_pages_Transkribus\page_metadata.xlsx

# %%
# adapting coordinates (no commas and flipping LTR)
import os
import xml.etree.ElementTree as ET
import shutil
import openpyxl

def flip_ltr_baseline_if_needed(baseline_str):
    coords = baseline_str.replace(',', ' ').split()
    if len(coords) % 2 != 0:
        return baseline_str  # Invalid, skip flipping

    points = [(float(coords[i]), float(coords[i+1])) for i in range(0, len(coords), 2)]
    x_values = [x for x, y in points]

    # Detect if LTR: Xs mostly decreasing
    if all(x_values[i] > x_values[i + 1] for i in range(len(x_values) - 1)):
        flipped = list(reversed(points))
        return ' '.join(f"{x:.2f} {y:.2f}" for x, y in flipped)
    else:
        return baseline_str.replace(',', ' ')  # Just replace commas with spaces if not LTR


def modify_coordinates_in_xml(xml_file, output_folder, jpg_filename):
    namespace = {'ns': 'http://www.loc.gov/standards/alto/ns-v4#'}
    tree = ET.parse(xml_file)
    root = tree.getroot()

    if 'xmlns' not in root.attrib:
        root.set('xmlns', 'http://www.loc.gov/standards/alto/ns-v4#')

    for elem in root.iter():
        for key, value in elem.attrib.items():
            if 'BASELINE' in key:
                new_value = flip_ltr_baseline_if_needed(value)
                elem.attrib[key] = new_value

            elif 'POINTS' in key or 'COORDS' in key:
                elem.attrib[key] = value.replace(',', ' ')

            if key == 'MASK' and not value:
                del elem.attrib[key]

        # Fix <fileName> element tag and value
        if elem.tag == '{http://www.loc.gov/standards/alto/ns-v4#}fileName':
            elem.tag = 'fileName'
            elem.text = jpg_filename

    modified_xml_file = os.path.join(output_folder, os.path.basename(xml_file))
    tree.write(modified_xml_file)
    return modified_xml_file

# Function to copy files and create metadata
def process_folder_structure(root_folder, destination_folder, metadata_filename):
    # Create a new Excel file for storing metadata
    wb = openpyxl.Workbook()
    sheet = wb.active
    sheet.append(["File Name", "Path"])  # Header for the metadata

    # Traverse the folder structure
    for subdir, dirs, files in os.walk(root_folder):
        # Look for JPG files and Alto XML files in the appropriate subfolders
        if subdir.endswith("alto"):  # If we're in the 'alto' folder
            # Find all JPGs in the parent folder (above 'alto')
            parent_folder = os.path.dirname(subdir)
            for file in os.listdir(parent_folder):
                if file.lower().endswith(('.jpg', '.jpeg', '.tif', '.tiff')):  # Handle jpg, jpeg, tif, and tiff files
                    # Copy the JPG file to the destination folder
                    image_file_path = os.path.join(parent_folder, file)
                    destination_image = os.path.join(destination_folder, file)
                    shutil.copy(image_file_path, destination_image)

                    # Log metadata for the image
                    sheet.append([file, image_file_path])

            # Now look for the XML files in the 'alto' folder
            for file in files:
                if file.lower().endswith(".xml"):
                    # Process the XML file by fixing its coordinates and updating its filename
                    xml_file_path = os.path.join(subdir, file)
                    image_filename = os.path.splitext(file)[0] + (".tif" if file.lower().endswith(".tif") else ".jpg")  # Update extension accordingly
                    modified_xml_path = modify_coordinates_in_xml(xml_file_path, destination_folder, image_filename)

                    # Log metadata for the XML
                    sheet.append([file, xml_file_path])

    # Save the metadata Excel file
    metadata_file_path = os.path.join(destination_folder, metadata_filename)
    wb.save(metadata_file_path)

    print(f"Processing complete. Metadata saved in: {metadata_file_path}")


# Example usage
root_folder = 'HebHTR_Transkribus'  # Replace with the path to your root folder
destination_folder = 'HTR_pages_Transkribus_NEW - Copy'  # Replace with the path to your destination folder
metadata_filename = 'page_metadata.xlsx'  # Name for the metadata file

# Make sure the destination folder exists
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Call the function to process the folder structure
process_folder_structure(root_folder, destination_folder, metadata_filename)
# Out:
# Processing complete. Metadata saved in: HTR_pages_Transkribus_NEW - Copy\page_metadata.xlsx

# %%
import os
import xml.etree.ElementTree as ET

# Function to modify XML to point to the corresponding image file
def update_xml_filename(xml_file, image_files, output_folder):
    # Parse the XML file
    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    # Add the missing xmlns attribute to the root element (if not already present)
    if 'xmlns' not in root.attrib:
        root.set('xmlns', 'http://www.loc.gov/standards/alto/ns-v4#')
        
    # Get the base filename without extension
    base_filename = os.path.splitext(os.path.basename(xml_file))[0]

    # Find the corresponding image file by matching base filenames
    corresponding_image = None
    for image in image_files:
        if os.path.splitext(image)[0] == base_filename:
            corresponding_image = image
            break

            
    
    # If a corresponding image is found, update the XML
    if corresponding_image:
        # Look for the fileName tag (or its equivalent) in the XML
        for elem in root.iter():
            if 'fileName' in elem.tag:  # Assuming 'fileName' is the tag you want to modify
                elem.text = corresponding_image  # Set the exact filename (including extension)

        # Write the modified XML to the output folder
        modified_xml_file = os.path.join(output_folder, os.path.basename(xml_file))
        tree.write(modified_xml_file)
        print(f"Updated XML: {modified_xml_file}")
    else:
        print(f"Warning: No corresponding image found for {xml_file}")

# Function to process the folder and update all XML files
def process_folder(folder_path, output_folder):
    # Get a list of all XML and image files in the folder
    xml_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.xml')]
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.tif', '.tiff'))]

#     # Ensure there are exactly 330 XML and 330 image files
#     if len(xml_files) != 330 or len(image_files) != 330:
#         print("Error: The folder should contain exactly 330 XML files and 330 image files.")
#         return

    # Process each XML file
    for xml_file in xml_files:
        xml_file_path = os.path.join(folder_path, xml_file)
        update_xml_filename(xml_file_path, image_files, output_folder)

# Example usage
folder_path = 'HTR_pages_Transkribus_NEW - Copy'  # Replace with your folder path
output_folder = 'HTR_pages_Transkribus_NEW - Copy'  # Replace with your output folder path

# Make sure the output folder exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Process the folder and update the XML files
process_folder(folder_path, output_folder)
# Out:
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_11-3_312_5_0002-Mattathias-0003.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_11-3_312_5_0003-Mattathias-0001.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_26.4.48 - P1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_CamScanner 11-05-2020 13.22_page-0023.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_CamScanner 11-05-2020 13.22_page-0034.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_CamScanner 11-05-2020 13.22_page-0039.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_CamScanner 11-05-2020 13.22_page-0043.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_CamScanner 11-05-2020 13.22_page-0050.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_CamScanner 11-05-2020 13.22_page-0052.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_CamScanner 11-05-2020 13.22_page-0055.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_CamScanner 11-05-2020 13.22_page-0057.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_ea.en.letters.01.01.01.0010.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_ea.en.letters.01.01.02.0001.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_IMG_20190731_123532.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_IMG_20190801_164520.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_let5.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_p001.xml
# Warning: No corresponding image found for HTR_pages_Transkribus_NEW - Copy\0001_אחי145-3_Page_01.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_אחי145-3_Page_14.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_אני משוקע כולי בספר אמריקני של ג_והן אוהרה_1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_הסילופים שנעשו בתיאור חייו של יוסף לישנסקי_1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_הפדיון הגבירו כבר פעולתם מירדן ומן הלבנון_1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_השגתי כרטיס יחיד לפסטיבל - מחזה של שקספיר_1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_יצחק מולדבי - השתתפותו בהגנת תל חי_1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_ישבתי למעלה משעה עם רחל (ינאית) בבית הנשיא_1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_לבוא במגע עם ילדי העולים לעמוד על דרכי חנוכם_1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_לברכה 10-10-73  .xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_לברכה 7-11-73 _0001.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_מה שלום גיא ואיך הוא מתפתח.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_משה שרת חלש... אני חושד בזקן כי בכך רצה_1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_נורית ודרור קצירי - 1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_עמ1 - מידב - 05.05.1952.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_פגשתי את אורנה פורת ויוסף מילוא_1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0001_רדיו אמרסון נאה בחיצוניותו וצלול מבחינת הטון_1.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_11-3_312_5_0002-Mattathias-0005.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_11-3_312_5_0003-Mattathias-0002.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_26.4.48 - P2.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_CamScanner 11-05-2020 13.22_page-0035.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_CamScanner 11-05-2020 13.22_page-0040.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_CamScanner 11-05-2020 13.22_page-0056.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_ea.en.letters.01.01.01.0011.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_ea.en.letters.01.01.02.0002.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_IMG_20190731_123552.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_IMG_20190801_164534.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_let6.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_p002.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_אחי145-3_Page_02.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_אני משוקע כולי בספר אמריקני של ג_והן אוהרה_2.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_הסילופים שנעשו בתיאור חייו של יוסף לישנסקי_2.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_הפדיון הגבירו כבר פעולתם מירדן ומן הלבנון_2.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_השגתי כרטיס יחיד לפסטיבל - מחזה של שקספיר_2.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_יצחק מולדבי - השתתפותו בהגנת תל חי_2.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_ישבתי למעלה משעה עם רחל (ינאית) בבית הנשיא_2.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_לבוא במגע עם ילדי העולים לעמוד על דרכי חנוכם_2.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_משה שרת חלש... אני חושד בזקן כי בכך רצה_2.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_עמ2  - מידב - 05.05.1952.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_פגשתי את אורנה פורת ויוסף מילוא_2.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0002_רדיו אמרסון נאה בחיצוניותו וצלול מבחינת הטון_2.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0003_11-3_312_5_0002-Mattathias-0007.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0003_11-3_312_5_0003-Mattathias-0004.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0003_ea.en.letters.01.01.01.0012.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0003_ea.en.letters.01.01.02.0003.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0003_IMG_20190731_123604.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0003_IMG_20190801_164558.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0003_let7.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0003_אחי145-3_Page_03.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0003_עמ3 - מידב - 05.05.1952.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0004_11-3_312_5_0002-Mattathias-0017.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0004_11-3_312_5_0003-Mattathias-0005.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0004_ea.en.letters.01.01.0003.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0004_ea.en.letters.01.01.02.0004.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0004_IMG_20190731_123616.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0004_IMG_20190801_164607.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0004_let8.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0004_אחי145-3_Page_04.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0004_עמ4 - מידב - 05.05.1952.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0005_11-3_312_5_0002-Mattathias-0019.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0005_11-3_312_5_0003-Mattathias-0006.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0005_ea.en.letters.01.01.0004.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0005_ea.en.letters.01.01.02.0005.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0005_IMG_20190731_123623.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0005_IMG_20190801_164616.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0005_אחי145-3_Page_05.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0006_11-3_312_5_0002-Mattathias-0034.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0006_11-3_312_5_0003-Mattathias-0008.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0006_ea.en.letters.01.01.0005.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0006_ea.en.letters.01.01.02.0006.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0006_IMG_20190731_123634.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0006_IMG_20190801_164624.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0006_אחי145-3_Page_06.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0007_11-3_312_5_0002-Mattathias-0048.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0007_11-3_312_5_0003-Mattathias-0009.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0007_ea.en.letters.01.01.0006.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0007_ea.en.letters.01.01.02.0007.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0007_IMG_20190731_123643.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0007_IMG_20190801_164629.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0007_אחי145-3_Page_07.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0008_11-3_312_5_0002-Mattathias-0050.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0008_11-3_312_5_0003-Mattathias-0010.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0008_ea.en.letters.01.01.0007.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0008_ea.en.letters.01.01.03.0008.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0008_IMG_20190731_123721.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0008_IMG_20190801_164641.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0008_אחי145-3_Page_08.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0009_11-3_312_5_0002-Mattathias-0055.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0009_11-3_312_5_0003-Mattathias-0014.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0009_ea.en.letters.01.01.0008.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0009_ea.en.letters.01.01.03.0009.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0009_IMG_20190731_123729.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0009_IMG_20190801_164646.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0009_אחי145-3_Page_09.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0010_11-3_312_5_0002-Mattathias-0057.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0010_11-3_312_5_0003-Mattathias-0015.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0010_ea.en.letters.01.01.0009.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0010_ea.en.letters.01.01.03.0011.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0010_IMG_20190731_123743.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0010_IMG_20190801_164653.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0010_אחי145-3_Page_10.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0011_11-3_312_5_0002-Mattathias-0065.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0011_11-3_312_5_0003-Mattathias-0017.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0011_ea.en.letters.01.01.03.0012.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0011_IMG_20190731_123749.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0011_IMG_20190801_164658.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0011_אחי145-3_Page_12.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0012_11-3_312_5_0002-Mattathias-0066.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0012_11-3_312_5_0003-Mattathias-0019.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0012_IMG_20190731_123755.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0012_IMG_20190801_164706.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0012_אחי145-3_Page_13.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0013_11-3_312_5_0002-Mattathias-0067.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0013_11-3_312_5_0003-Mattathias-0021.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0013_IMG_20190731_123802.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0013_IMG_20190801_164710.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0013_אחי145-3_Page_15.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0014_11-3_312_5_0002-Mattathias-0087.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0014_11-3_312_5_0003-Mattathias-0026.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0014_IMG_20190731_123809.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0014_IMG_20190801_164719.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0014_אחי145-3_Page_16.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0015_11-3_312_5_0002-Mattathias-0102.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0015_IMG_20190731_123819.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0015_IMG_20190801_164725.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0015_אחי145-3_Page_17.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0016_11-3_312_5_0002-Mattathias-0107.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0016_IMG_20190731_123829.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0016_IMG_20190801_164734.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0016_אחי145-3_Page_18.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0017_11-3_312_5_0002-Mattathias-0112.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0017_IMG_20190731_123842.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0017_IMG_20190801_164741.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0017_אחי145-3_Page_19.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0018_11-3_312_5_0002-Mattathias-0113.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0018_IMG_20190731_123853.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0018_IMG_20190801_164755.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0018_אחי145-3_Page_21.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0019_11-3_312_5_0002-Mattathias-0114.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0019_IMG_20190731_123858.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0019_IMG_20190801_164801.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0019_אחי145-3_Page_22.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0020_11-3_312_5_0002-Mattathias-0118.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0020_IMG_20190731_123908.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0020_IMG_20190801_164811.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0020_אחי145-3_Page_24.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0021_11-3_312_5_0002-Mattathias-0124.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0021_IMG_20190731_123917.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0021_IMG_20190801_164815.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0021_אחי145-3_Page_25.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0022_11-3_312_5_0002-Mattathias-0135.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0022_IMG_20190731_123926.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0022_IMG_20190801_164825.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0022_אחי145-3_Page_26.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0023_11-3_312_5_0002-Mattathias-0156.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0023_IMG_20190731_123934.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0023_IMG_20190801_164828.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0023_אחי145-3_Page_27.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0024_11-3_312_5_0002-Mattathias-0158.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0024_IMG_20190731_123944.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0024_IMG_20190801_164837.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0024_אחי145-3_Page_28.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0025_11-3_312_5_0002-Mattathias-0159.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0025_IMG_20190731_123948.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0025_IMG_20190801_164840.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0025_אחי145-3_Page_29.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0026_11-3_312_5_0002-Mattathias-0160.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0026_IMG_20190731_123957.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0026_IMG_20190801_164857.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0026_אחי145-3_Page_30.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0027_11-3_312_5_0002-Mattathias-0161.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0027_IMG_20190731_124001.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0027_IMG_20190801_164907.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0027_אחי146-3_Page_02.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0028_11-3_312_5_0002-Mattathias-0162.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0028_IMG_20190731_124025.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0028_IMG_20190801_164922.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0028_אחי146-3_Page_03.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0029_11-3_312_5_0002-Mattathias-0168.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0029_IMG_20190731_124030.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0029_IMG_20190801_164926.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0029_אחי146-3_Page_04.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0030_11-3_312_5_0002-Mattathias-0170.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0030_IMG_20190731_124040.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0030_IMG_20190801_164943.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0031_11-3_312_5_0002-Mattathias-0171.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0031_IMG_20190731_124047.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0031_IMG_20190801_164949.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0032_11-3_312_5_0002-Mattathias-0173.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0032_IMG_20190731_124057.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0032_IMG_20190801_165000.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0033_11-3_312_5_0002-Mattathias-0174.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0033_IMG_20190731_124102.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0033_IMG_20190801_165005.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0034_11-3_312_5_0002-Mattathias-0180.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0034_IMG_20190731_124110.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0034_IMG_20190801_165014.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0035_11-3_312_5_0002-Mattathias-0189.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0035_IMG_20190731_124118.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0035_IMG_20190801_165019.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0036_11-3_312_5_0002-Mattathias-0190.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0036_IMG_20190731_124127.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0036_IMG_20190801_165026.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0037_11-3_312_5_0002-Mattathias-0196.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0037_IMG_20190731_124135.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0037_IMG_20190801_165030.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0038_11-3_312_5_0002-Mattathias-0198.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0038_IMG_20190731_124147.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0038_IMG_20190801_165034.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0039_11-3_312_5_0002-Mattathias-0200.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0039_IMG_20190731_124153.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0039_IMG_20190801_165042.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0040_11-3_312_5_0002-Mattathias-0201.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0040_IMG_20190731_124202.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0040_IMG_20190801_165047.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0041_11-3_312_5_0002-Mattathias-0204.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0041_IMG_20190731_124208.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0041_IMG_20190801_165057.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0042_11-3_312_5_0002-Mattathias-0213.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0042_IMG_20190731_124220.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0042_IMG_20190801_165103.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0043_11-3_312_5_0002-Mattathias-0215.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0043_IMG_20190731_124226.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0043_IMG_20190801_165112.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0044_11-3_312_5_0002-Mattathias-0217.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0044_IMG_20190731_124238.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0044_IMG_20190801_165116.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0045_11-3_312_5_0002-Mattathias-0218.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0045_IMG_20190731_124244.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0045_IMG_20190801_165122.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0046_11-3_312_5_0002-Mattathias-0220.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0046_IMG_20190731_124253.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0046_IMG_20190801_165131.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0047_11-3_312_5_0002-Mattathias-0223.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0047_IMG_20190731_124258.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0047_IMG_20190801_165144.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0048_11-3_312_5_0002-Mattathias-0225.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0048_IMG_20190731_124307.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0048_IMG_20190801_165149.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0049_11-3_312_5_0002-Mattathias-0226.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0049_IMG_20190731_124311.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0049_IMG_20190801_165200.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0050_11-3_312_5_0002-Mattathias-0227.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0050_IMG_20190731_124320.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0050_IMG_20190801_165205.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0051_11-3_312_5_0002-Mattathias-0228.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0051_IMG_20190731_124325.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0051_IMG_20190801_165213.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0052_11-3_312_5_0002-Mattathias-0229.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0052_IMG_20190731_124332.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0052_IMG_20190801_165219.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0053_11-3_312_5_0002-Mattathias-0230.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0053_IMG_20190731_124337.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0054_11-3_312_5_0002-Mattathias-0231.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0054_IMG_20190731_124346.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0055_11-3_312_5_0002-Mattathias-0232.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0055_IMG_20190731_124354.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0056_11-3_312_5_0002-Mattathias-0233.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0057_11-3_312_5_0002-Mattathias-0234.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0058_11-3_312_5_0002-Mattathias-0235.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0059_11-3_312_5_0002-Mattathias-0236.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0060_11-3_312_5_0002-Mattathias-0237.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0061_11-3_312_5_0002-Mattathias-0238.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0062_11-3_312_5_0002-Mattathias-0239.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0063_11-3_312_5_0002-Mattathias-0240.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0064_11-3_312_5_0002-Mattathias-0241.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0065_11-3_312_5_0002-Mattathias-0242.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0066_11-3_312_5_0002-Mattathias-0243.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0067_11-3_312_5_0002-Mattathias-0244.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0068_11-3_312_5_0002-Mattathias-0245.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0069_11-3_312_5_0002-Mattathias-0246.xml
# Updated XML: HTR_pages_Transkribus_NEW - Copy\0070_11-3_312_5_0002-Mattathias-0247.xml

# %%
# update flipped coordinates in xmls in a single folder
import os
import xml.etree.ElementTree as ET

# Function to flip coordinates if they are RTL
def flip_coordinates_if_needed(baseline):
    # Split the baseline into pairs of (X, Y)
    coordinates = baseline.split()
    
    # Extract the X-coordinates
    x_coords = coordinates[::2]  # X-coordinates are at even indices
    
    # Check if the X-coordinates are decreasing (RTL)
    if all(x_coords[i] > x_coords[i+1] for i in range(len(x_coords)-1)):
        flipped_coordinates = []
        
        # Reverse the X-coordinates while keeping the Y-coordinates in the same order
        for i in range(0, len(coordinates), 2):
            flipped_coordinates.insert(0, coordinates[i])  # X-coordinate
            flipped_coordinates.insert(0, coordinates[i+1])  # Y-coordinate
        
        # Return the flipped coordinates
        return ' '.join(flipped_coordinates)
    
    # Handle cases where X-coordinates might be too close (e.g., vertical lines)
    # We only flip if there's a significant difference between X-coordinates
    x_differences = [abs(int(x_coords[i]) - int(x_coords[i+1])) for i in range(len(x_coords)-1)]
    
    # If X-coordinates are too close (indicating vertical), we won't flip
    if all(diff < 10 for diff in x_differences):  # Threshold of 10, adjust as needed
        return baseline
    
    # Otherwise, return as is (LTR)
    return baseline

# Function to modify XML to point to the corresponding image file and flip coordinates
def update_xml_filename(xml_file, image_files, output_folder):
    # Parse the XML file
    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    # Add the missing xmlns attribute to the root element (if not already present)
    if 'xmlns' not in root.attrib:
        root.set('xmlns', 'http://www.loc.gov/standards/alto/ns-v4#')
        
    # Get the base filename without extension
    base_filename = os.path.splitext(os.path.basename(xml_file))[0]

    # Find the corresponding image file by matching base filenames
    corresponding_image = None
    for image in image_files:
        if os.path.splitext(image)[0] == base_filename:
            corresponding_image = image
            break
    
    # If a corresponding image is found, update the XML
    if corresponding_image:
        # Look for the fileName tag (or its equivalent) in the XML
        for elem in root.iter():
            if 'fileName' in elem.tag:  # Assuming 'fileName' is the tag you want to modify
                elem.text = corresponding_image  # Set the exact filename (including extension)
        
        # Check and flip the coordinates if needed
        for elem in root.iter():
            if 'BASELINE' in elem.attrib:  # Look for the BASELINE attribute
                flipped_value = flip_coordinates_if_needed(elem.attrib['BASELINE'])  # Flip if needed
                elem.attrib['BASELINE'] = flipped_value  # Set the flipped coordinates
        
        # Write the modified XML to the output folder
        modified_xml_file = os.path.join(output_folder, os.path.basename(xml_file))
        tree.write(modified_xml_file)
        print(f"Updated XML: {modified_xml_file}")
    else:
        print(f"Warning: No corresponding image found for {xml_file}")

# Function to process the folder and update all XML files
def process_folder(folder_path, output_folder):
    # Get a list of all XML and image files in the folder
    xml_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.xml')]
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.jpg', '.jpeg', '.tif', '.tiff'))]

    # Process each XML file
    for xml_file in xml_files:
        xml_file_path = os.path.join(folder_path, xml_file)
        update_xml_filename(xml_file_path, image_files, output_folder)

# Example usage
folder_path = 'HTR_pages_Transkribus'  # Replace with your folder path
output_folder = 'HTR_pages_Transkribus'  # Replace with your output folder path

# Make sure the output folder exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Process the folder and update the XML files
process_folder(folder_path, output_folder)
# Out:
# Updated XML: HTR_pages_Transkribus\0001_11-3_312_5_0002-Mattathias-0003.xml
# Updated XML: HTR_pages_Transkribus\0001_11-3_312_5_0003-Mattathias-0001.xml
# Updated XML: HTR_pages_Transkribus\0001_26.4.48 - P1.xml
# Updated XML: HTR_pages_Transkribus\0001_CamScanner 11-05-2020 13.22_page-0023.xml
# Updated XML: HTR_pages_Transkribus\0001_CamScanner 11-05-2020 13.22_page-0034.xml
# Updated XML: HTR_pages_Transkribus\0001_CamScanner 11-05-2020 13.22_page-0039.xml
# Updated XML: HTR_pages_Transkribus\0001_CamScanner 11-05-2020 13.22_page-0043.xml
# Updated XML: HTR_pages_Transkribus\0001_CamScanner 11-05-2020 13.22_page-0050.xml
# Updated XML: HTR_pages_Transkribus\0001_CamScanner 11-05-2020 13.22_page-0052.xml
# Updated XML: HTR_pages_Transkribus\0001_CamScanner 11-05-2020 13.22_page-0055.xml
# Updated XML: HTR_pages_Transkribus\0001_CamScanner 11-05-2020 13.22_page-0057.xml
# Updated XML: HTR_pages_Transkribus\0001_ea.en.letters.01.01.01.0010.xml
# Updated XML: HTR_pages_Transkribus\0001_ea.en.letters.01.01.02.0001.xml
# Updated XML: HTR_pages_Transkribus\0001_IMG_20190731_123532.xml
# Updated XML: HTR_pages_Transkribus\0001_IMG_20190801_164520.xml
# Updated XML: HTR_pages_Transkribus\0001_let5.xml
# Updated XML: HTR_pages_Transkribus\0001_p001.xml
# Updated XML: HTR_pages_Transkribus\0001_אחי145-3_Page_08.xml
# Updated XML: HTR_pages_Transkribus\0001_אחי145-3_Page_14.xml
# Updated XML: HTR_pages_Transkribus\0001_אני משוקע כולי בספר אמריקני של ג_והן אוהרה_1.xml
# Updated XML: HTR_pages_Transkribus\0001_הסילופים שנעשו בתיאור חייו של יוסף לישנסקי_1.xml
# Updated XML: HTR_pages_Transkribus\0001_הפדיון הגבירו כבר פעולתם מירדן ומן הלבנון_1.xml
# Updated XML: HTR_pages_Transkribus\0001_השגתי כרטיס יחיד לפסטיבל - מחזה של שקספיר_1.xml
# Updated XML: HTR_pages_Transkribus\0001_יצחק מולדבי - השתתפותו בהגנת תל חי_1.xml
# Updated XML: HTR_pages_Transkribus\0001_ישבתי למעלה משעה עם רחל (ינאית) בבית הנשיא_1.xml
# Updated XML: HTR_pages_Transkribus\0001_לבוא במגע עם ילדי העולים לעמוד על דרכי חנוכם_1.xml
# Updated XML: HTR_pages_Transkribus\0001_לברכה 10-10-73  .xml
# Updated XML: HTR_pages_Transkribus\0001_לברכה 7-11-73 _0001.xml
# Updated XML: HTR_pages_Transkribus\0001_מה שלום גיא ואיך הוא מתפתח.xml
# Updated XML: HTR_pages_Transkribus\0001_משה שרת חלש... אני חושד בזקן כי בכך רצה_1.xml
# Updated XML: HTR_pages_Transkribus\0001_נורית ודרור קצירי - 1.xml
# Updated XML: HTR_pages_Transkribus\0001_עמ 1.xml
# Updated XML: HTR_pages_Transkribus\0001_עמ1 - מידב - 05.05.1952.xml
# Updated XML: HTR_pages_Transkribus\0001_פגשתי את אורנה פורת ויוסף מילוא_1.xml
# Updated XML: HTR_pages_Transkribus\0001_רדיו אמרסון נאה בחיצוניותו וצלול מבחינת הטון_1.xml
# Updated XML: HTR_pages_Transkribus\0002_11-3_312_5_0002-Mattathias-0005.xml
# Updated XML: HTR_pages_Transkribus\0002_11-3_312_5_0003-Mattathias-0002.xml
# Updated XML: HTR_pages_Transkribus\0002_2.xml
# Updated XML: HTR_pages_Transkribus\0002_26.4.48 - P2.xml
# Updated XML: HTR_pages_Transkribus\0002_CamScanner 11-05-2020 13.22_page-0035.xml
# Updated XML: HTR_pages_Transkribus\0002_CamScanner 11-05-2020 13.22_page-0040.xml
# Updated XML: HTR_pages_Transkribus\0002_CamScanner 11-05-2020 13.22_page-0056.xml
# Updated XML: HTR_pages_Transkribus\0002_ea.en.letters.01.01.01.0011.xml
# Updated XML: HTR_pages_Transkribus\0002_ea.en.letters.01.01.02.0002.xml
# Updated XML: HTR_pages_Transkribus\0002_IMG_20190731_123552.xml
# Updated XML: HTR_pages_Transkribus\0002_IMG_20190801_164534.xml
# Updated XML: HTR_pages_Transkribus\0002_let6.xml
# Updated XML: HTR_pages_Transkribus\0002_p002.xml
# Updated XML: HTR_pages_Transkribus\0002_אחי145-3_Page_02.xml
# Updated XML: HTR_pages_Transkribus\0002_אחי145-3_Page_21.xml
# Updated XML: HTR_pages_Transkribus\0002_אני משוקע כולי בספר אמריקני של ג_והן אוהרה_2.xml
# Updated XML: HTR_pages_Transkribus\0002_הסילופים שנעשו בתיאור חייו של יוסף לישנסקי_2.xml
# Updated XML: HTR_pages_Transkribus\0002_הפדיון הגבירו כבר פעולתם מירדן ומן הלבנון_2.xml
# Updated XML: HTR_pages_Transkribus\0002_השגתי כרטיס יחיד לפסטיבל - מחזה של שקספיר_2.xml
# Updated XML: HTR_pages_Transkribus\0002_יצחק מולדבי - השתתפותו בהגנת תל חי_2.xml
# Updated XML: HTR_pages_Transkribus\0002_ישבתי למעלה משעה עם רחל (ינאית) בבית הנשיא_2.xml
# Updated XML: HTR_pages_Transkribus\0002_לבוא במגע עם ילדי העולים לעמוד על דרכי חנוכם_2.xml
# Updated XML: HTR_pages_Transkribus\0002_משה שרת חלש... אני חושד בזקן כי בכך רצה_2.xml
# Updated XML: HTR_pages_Transkribus\0002_עמ2  - מידב - 05.05.1952.xml
# Updated XML: HTR_pages_Transkribus\0002_פגשתי את אורנה פורת ויוסף מילוא_2.xml
# Updated XML: HTR_pages_Transkribus\0002_רדיו אמרסון נאה בחיצוניותו וצלול מבחינת הטון_2.xml
# Updated XML: HTR_pages_Transkribus\0003_11-3_312_5_0002-Mattathias-0007.xml
# Updated XML: HTR_pages_Transkribus\0003_11-3_312_5_0003-Mattathias-0004.xml
# Updated XML: HTR_pages_Transkribus\0003_ea.en.letters.01.01.01.0012.xml
# Updated XML: HTR_pages_Transkribus\0003_ea.en.letters.01.01.02.0003.xml
# Updated XML: HTR_pages_Transkribus\0003_IMG_20190731_123604.xml
# Updated XML: HTR_pages_Transkribus\0003_IMG_20190801_164558.xml
# Updated XML: HTR_pages_Transkribus\0003_let7.xml
# Updated XML: HTR_pages_Transkribus\0003_אחי145-3_Page_03.xml
# Updated XML: HTR_pages_Transkribus\0003_אחי146-3_Page_03.xml
# Updated XML: HTR_pages_Transkribus\0003_עמ 4.xml
# Updated XML: HTR_pages_Transkribus\0003_עמ3 - מידב - 05.05.1952.xml
# Updated XML: HTR_pages_Transkribus\0004_11-3_312_5_0002-Mattathias-0017.xml
# Updated XML: HTR_pages_Transkribus\0004_11-3_312_5_0003-Mattathias-0005.xml
# Updated XML: HTR_pages_Transkribus\0004_11.xml
# Updated XML: HTR_pages_Transkribus\0004_5.xml
# Updated XML: HTR_pages_Transkribus\0004_ea.en.letters.01.01.0003.xml
# Updated XML: HTR_pages_Transkribus\0004_ea.en.letters.01.01.02.0004.xml
# Updated XML: HTR_pages_Transkribus\0004_IMG_20190731_123616.xml
# Updated XML: HTR_pages_Transkribus\0004_IMG_20190801_164607.xml
# Updated XML: HTR_pages_Transkribus\0004_let8.xml
# Updated XML: HTR_pages_Transkribus\0004_אחי145-3_Page_04.xml
# Updated XML: HTR_pages_Transkribus\0004_עמ4 - מידב - 05.05.1952.xml
# Updated XML: HTR_pages_Transkribus\0005_11-3_312_5_0002-Mattathias-0019.xml
# Updated XML: HTR_pages_Transkribus\0005_11-3_312_5_0003-Mattathias-0006.xml
# Updated XML: HTR_pages_Transkribus\0005_6.xml
# Updated XML: HTR_pages_Transkribus\0005_ea.en.letters.01.01.0004.xml
# Updated XML: HTR_pages_Transkribus\0005_ea.en.letters.01.01.02.0005.xml
# Updated XML: HTR_pages_Transkribus\0005_IMG_20190731_123623.xml
# Updated XML: HTR_pages_Transkribus\0005_IMG_20190801_164616.xml
# Updated XML: HTR_pages_Transkribus\0005_אחי145-3_Page_05.xml
# Updated XML: HTR_pages_Transkribus\0005_השגתי כרטיס יחיד לפסטיבל - מחזה של שקספיר_1.xml
# Updated XML: HTR_pages_Transkribus\0006_11-3_312_5_0002-Mattathias-0034.xml
# Updated XML: HTR_pages_Transkribus\0006_11-3_312_5_0003-Mattathias-0008.xml
# Updated XML: HTR_pages_Transkribus\0006_7.xml
# Updated XML: HTR_pages_Transkribus\0006_ea.en.letters.01.01.0005.xml
# Updated XML: HTR_pages_Transkribus\0006_ea.en.letters.01.01.02.0006.xml
# Updated XML: HTR_pages_Transkribus\0006_IMG_20190731_123634.xml
# Updated XML: HTR_pages_Transkribus\0006_IMG_20190801_164624.xml
# Updated XML: HTR_pages_Transkribus\0006_אחי145-3_Page_06.xml
# Updated XML: HTR_pages_Transkribus\0006_אני משוקע כולי בספר אמריקני של ג_והן אוהרה_1.xml
# Updated XML: HTR_pages_Transkribus\0007_11-3_312_5_0002-Mattathias-0048.xml
# Updated XML: HTR_pages_Transkribus\0007_11-3_312_5_0003-Mattathias-0009.xml
# Updated XML: HTR_pages_Transkribus\0007_8.xml
# Updated XML: HTR_pages_Transkribus\0007_ea.en.letters.01.01.0006.xml
# Updated XML: HTR_pages_Transkribus\0007_ea.en.letters.01.01.01.0010.xml
# Updated XML: HTR_pages_Transkribus\0007_ea.en.letters.01.01.02.0007.xml
# Updated XML: HTR_pages_Transkribus\0007_IMG_20190731_123643.xml
# Updated XML: HTR_pages_Transkribus\0007_IMG_20190801_164629.xml
# Updated XML: HTR_pages_Transkribus\0007_אחי145-3_Page_07.xml
# Updated XML: HTR_pages_Transkribus\0008_11-3_312_5_0002-Mattathias-0050.xml
# Updated XML: HTR_pages_Transkribus\0008_11-3_312_5_0003-Mattathias-0010.xml
# Updated XML: HTR_pages_Transkribus\0008_9.xml
# Updated XML: HTR_pages_Transkribus\0008_ea.en.letters.01.01.0007.xml
# Updated XML: HTR_pages_Transkribus\0008_ea.en.letters.01.01.02.0001.xml
# Updated XML: HTR_pages_Transkribus\0008_ea.en.letters.01.01.03.0008.xml
# Updated XML: HTR_pages_Transkribus\0008_IMG_20190731_123721.xml
# Updated XML: HTR_pages_Transkribus\0008_IMG_20190801_164641.xml
# Updated XML: HTR_pages_Transkribus\0008_אחי145-3_Page_08.xml
# Updated XML: HTR_pages_Transkribus\0009_10.xml
# Updated XML: HTR_pages_Transkribus\0009_11-3_312_5_0002-Mattathias-0055.xml
# Updated XML: HTR_pages_Transkribus\0009_11-3_312_5_0003-Mattathias-0014.xml
# Updated XML: HTR_pages_Transkribus\0009_ea.en.letters.01.01.0008.xml
# Updated XML: HTR_pages_Transkribus\0009_ea.en.letters.01.01.03.0009.xml
# Updated XML: HTR_pages_Transkribus\0009_ea.en.letters.01.01.03.0012.xml
# Updated XML: HTR_pages_Transkribus\0009_IMG_20190731_123729.xml
# Updated XML: HTR_pages_Transkribus\0009_IMG_20190801_164646.xml
# Updated XML: HTR_pages_Transkribus\0009_אחי145-3_Page_09.xml
# Updated XML: HTR_pages_Transkribus\0010_11-3_312_5_0002-Mattathias-0057.xml
# Updated XML: HTR_pages_Transkribus\0010_11-3_312_5_0003-Mattathias-0015.xml
# Updated XML: HTR_pages_Transkribus\0010_11.xml
# Updated XML: HTR_pages_Transkribus\0010_ea.en.letters.01.01.0009.xml
# Updated XML: HTR_pages_Transkribus\0010_ea.en.letters.01.01.03.0011.xml
# Updated XML: HTR_pages_Transkribus\0010_IMG_20190731_123743.xml
# Updated XML: HTR_pages_Transkribus\0010_IMG_20190801_164653.xml
# Updated XML: HTR_pages_Transkribus\0010_אחי145-3_Page_10.xml
# Updated XML: HTR_pages_Transkribus\0011_11-3_312_5_0002-Mattathias-0065.xml
# Updated XML: HTR_pages_Transkribus\0011_11-3_312_5_0003-Mattathias-0017.xml
# Updated XML: HTR_pages_Transkribus\0011_12.xml
# Updated XML: HTR_pages_Transkribus\0011_ea.en.letters.01.01.03.0012.xml
# Updated XML: HTR_pages_Transkribus\0011_IMG_20190731_123749.xml
# Updated XML: HTR_pages_Transkribus\0011_IMG_20190731_123908.xml
# Updated XML: HTR_pages_Transkribus\0011_IMG_20190801_164658.xml
# Updated XML: HTR_pages_Transkribus\0011_אחי145-3_Page_12.xml
# Updated XML: HTR_pages_Transkribus\0012_11-3_312_5_0002-Mattathias-0066.xml
# Updated XML: HTR_pages_Transkribus\0012_11-3_312_5_0003-Mattathias-0019.xml
# Updated XML: HTR_pages_Transkribus\0012_13.xml
# Updated XML: HTR_pages_Transkribus\0012_IMG_20190731_123755.xml
# Updated XML: HTR_pages_Transkribus\0012_IMG_20190731_124040.xml
# Updated XML: HTR_pages_Transkribus\0012_IMG_20190801_164706.xml
# Updated XML: HTR_pages_Transkribus\0012_אחי145-3_Page_13.xml
# Updated XML: HTR_pages_Transkribus\0013_11-3_312_5_0002-Mattathias-0067.xml
# Updated XML: HTR_pages_Transkribus\0013_11-3_312_5_0003-Mattathias-0021.xml
# Updated XML: HTR_pages_Transkribus\0013_14.xml
# Updated XML: HTR_pages_Transkribus\0013_IMG_20190731_123802.xml
# Updated XML: HTR_pages_Transkribus\0013_IMG_20190731_124202.xml
# Updated XML: HTR_pages_Transkribus\0013_IMG_20190801_164710.xml
# Updated XML: HTR_pages_Transkribus\0013_אחי145-3_Page_15.xml
# Updated XML: HTR_pages_Transkribus\0014_11-3_312_5_0002-Mattathias-0087.xml
# Updated XML: HTR_pages_Transkribus\0014_11-3_312_5_0003-Mattathias-0026.xml
# Updated XML: HTR_pages_Transkribus\0014_IMG_20190731_123809.xml
# Updated XML: HTR_pages_Transkribus\0014_IMG_20190731_124320.xml
# Updated XML: HTR_pages_Transkribus\0014_IMG_20190801_164719.xml
# Updated XML: HTR_pages_Transkribus\0014_אחי145-3_Page_16.xml
# Updated XML: HTR_pages_Transkribus\0015_11-3_312_5_0002-Mattathias-0102.xml
# Updated XML: HTR_pages_Transkribus\0015_IMG_20190731_123819.xml
# Updated XML: HTR_pages_Transkribus\0015_IMG_20190801_164646.xml
# Updated XML: HTR_pages_Transkribus\0015_IMG_20190801_164725.xml
# Updated XML: HTR_pages_Transkribus\0015_אחי145-3_Page_17.xml
# Updated XML: HTR_pages_Transkribus\0016_11-3_312_5_0002-Mattathias-0107.xml
# Updated XML: HTR_pages_Transkribus\0016_IMG_20190731_123829.xml
# Updated XML: HTR_pages_Transkribus\0016_IMG_20190801_164734.xml
# Updated XML: HTR_pages_Transkribus\0016_IMG_20190801_164801.xml
# Updated XML: HTR_pages_Transkribus\0016_אחי145-3_Page_18.xml
# Updated XML: HTR_pages_Transkribus\0017_11-3_312_5_0002-Mattathias-0112.xml
# Updated XML: HTR_pages_Transkribus\0017_IMG_20190731_123842.xml
# Updated XML: HTR_pages_Transkribus\0017_IMG_20190801_164741.xml
# Updated XML: HTR_pages_Transkribus\0017_IMG_20190801_164926.xml
# Updated XML: HTR_pages_Transkribus\0017_אחי145-3_Page_19.xml
# Updated XML: HTR_pages_Transkribus\0018_11-3_312_5_0002-Mattathias-0113.xml
# Updated XML: HTR_pages_Transkribus\0018_IMG_20190731_123853.xml
# Updated XML: HTR_pages_Transkribus\0018_IMG_20190801_164755.xml
# Updated XML: HTR_pages_Transkribus\0018_IMG_20190801_165042.xml
# Updated XML: HTR_pages_Transkribus\0018_אחי145-3_Page_21.xml
# Updated XML: HTR_pages_Transkribus\0019_11-3_312_5_0002-Mattathias-0114.xml
# Updated XML: HTR_pages_Transkribus\0019_IMG_20190731_123858.xml
# Updated XML: HTR_pages_Transkribus\0019_IMG_20190801_164801.xml
# Updated XML: HTR_pages_Transkribus\0019_IMG_20190801_165200.xml
# Updated XML: HTR_pages_Transkribus\0019_אחי145-3_Page_22.xml
# Updated XML: HTR_pages_Transkribus\0020_11-3_312_5_0002-Mattathias-0118.xml
# Updated XML: HTR_pages_Transkribus\0020_CamScanner 11-05-2020 13.22_page-0043.xml
# Updated XML: HTR_pages_Transkribus\0020_IMG_20190731_123908.xml
# Updated XML: HTR_pages_Transkribus\0020_IMG_20190801_164811.xml
# Updated XML: HTR_pages_Transkribus\0020_אחי145-3_Page_24.xml
# Updated XML: HTR_pages_Transkribus\0021_11-3_312_5_0002-Mattathias-0034.xml
# Updated XML: HTR_pages_Transkribus\0021_11-3_312_5_0002-Mattathias-0124.xml
# Updated XML: HTR_pages_Transkribus\0021_IMG_20190731_123917.xml
# Updated XML: HTR_pages_Transkribus\0021_IMG_20190801_164815.xml
# Updated XML: HTR_pages_Transkribus\0021_אחי145-3_Page_25.xml
# Updated XML: HTR_pages_Transkribus\0022_11-3_312_5_0002-Mattathias-0102.xml
# Updated XML: HTR_pages_Transkribus\0022_11-3_312_5_0002-Mattathias-0135.xml
# Updated XML: HTR_pages_Transkribus\0022_IMG_20190731_123926.xml
# Updated XML: HTR_pages_Transkribus\0022_IMG_20190801_164825.xml
# Updated XML: HTR_pages_Transkribus\0022_אחי145-3_Page_26.xml
# Updated XML: HTR_pages_Transkribus\0023_11-3_312_5_0002-Mattathias-0156.xml
# Updated XML: HTR_pages_Transkribus\0023_11-3_312_5_0002-Mattathias-0160.xml
# Updated XML: HTR_pages_Transkribus\0023_IMG_20190731_123934.xml
# Updated XML: HTR_pages_Transkribus\0023_IMG_20190801_164828.xml
# Updated XML: HTR_pages_Transkribus\0023_אחי145-3_Page_27.xml
# Updated XML: HTR_pages_Transkribus\0024_11-3_312_5_0002-Mattathias-0158.xml
# Updated XML: HTR_pages_Transkribus\0024_11-3_312_5_0002-Mattathias-0173.xml
# Updated XML: HTR_pages_Transkribus\0024_IMG_20190731_123944.xml
# Updated XML: HTR_pages_Transkribus\0024_IMG_20190801_164837.xml
# Updated XML: HTR_pages_Transkribus\0024_אחי145-3_Page_28.xml
# Updated XML: HTR_pages_Transkribus\0025_11-3_312_5_0002-Mattathias-0159.xml
# Updated XML: HTR_pages_Transkribus\0025_11-3_312_5_0002-Mattathias-0189.xml
# Updated XML: HTR_pages_Transkribus\0025_IMG_20190731_123948.xml
# Updated XML: HTR_pages_Transkribus\0025_IMG_20190801_164840.xml
# Updated XML: HTR_pages_Transkribus\0025_אחי145-3_Page_29.xml
# Updated XML: HTR_pages_Transkribus\0026_11-3_312_5_0002-Mattathias-0160.xml
# Updated XML: HTR_pages_Transkribus\0026_11-3_312_5_0002-Mattathias-0229.xml
# Updated XML: HTR_pages_Transkribus\0026_IMG_20190731_123957.xml
# Updated XML: HTR_pages_Transkribus\0026_IMG_20190801_164857.xml
# Updated XML: HTR_pages_Transkribus\0026_אחי145-3_Page_30.xml
# Updated XML: HTR_pages_Transkribus\0027_11-3_312_5_0002-Mattathias-0161.xml
# Updated XML: HTR_pages_Transkribus\0027_11-3_312_5_0002-Mattathias-0232.xml
# Updated XML: HTR_pages_Transkribus\0027_IMG_20190731_124001.xml
# Updated XML: HTR_pages_Transkribus\0027_IMG_20190801_164907.xml
# Updated XML: HTR_pages_Transkribus\0027_אחי146-3_Page_02.xml
# Updated XML: HTR_pages_Transkribus\0028_11-3_312_5_0002-Mattathias-0162.xml
# Updated XML: HTR_pages_Transkribus\0028_11-3_312_5_0003-Mattathias-0001.xml
# Updated XML: HTR_pages_Transkribus\0028_IMG_20190731_124025.xml
# Updated XML: HTR_pages_Transkribus\0028_IMG_20190801_164922.xml
# Updated XML: HTR_pages_Transkribus\0028_אחי146-3_Page_03.xml
# Updated XML: HTR_pages_Transkribus\0029_11-3_312_5_0002-Mattathias-0168.xml
# Updated XML: HTR_pages_Transkribus\0029_11-3_312_5_0003-Mattathias-0019.xml
# Updated XML: HTR_pages_Transkribus\0029_IMG_20190731_124030.xml
# Updated XML: HTR_pages_Transkribus\0029_IMG_20190801_164926.xml
# Updated XML: HTR_pages_Transkribus\0029_אחי146-3_Page_04.xml
# Updated XML: HTR_pages_Transkribus\0030_11-3_312_5_0002-Mattathias-0170.xml
# Updated XML: HTR_pages_Transkribus\0030_IMG_20190731_124040.xml
# Updated XML: HTR_pages_Transkribus\0030_IMG_20190801_164943.xml
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 96
#      93     os.makedirs(output_folder)
#      95 # Process the folder and update the XML files
# ---> 96 process_folder(folder_path, output_folder)
#
# Cell In[16], line 85, in process_folder(folder_path, output_folder)
#      83 for xml_file in xml_files:
#      84     xml_file_path = os.path.join(folder_path, xml_file)
# ---> 85     update_xml_filename(xml_file_path, image_files, output_folder)
#
# Cell In[16], line 66, in update_xml_filename(xml_file, image_files, output_folder)
#      64 for elem in root.iter():
#      65     if 'BASELINE' in elem.attrib:  # Look for the BASELINE attribute
# ---> 66         flipped_value = flip_coordinates_if_needed(elem.attrib['BASELINE'])  # Flip if needed
#      67         elem.attrib['BASELINE'] = flipped_value  # Set the flipped coordinates
#      69 # Write the modified XML to the output folder
#
# Cell In[16], line 27, in flip_coordinates_if_needed(baseline)
#      23     return ' '.join(flipped_coordinates)
#      25 # Handle cases where X-coordinates might be too close (e.g., vertical lines)
#      26 # We only flip if there's a significant difference between X-coordinates
# ---> 27 x_differences = [abs(int(x_coords[i]) - int(x_coords[i+1])) for i in range(len(x_coords)-1)]
#      29 # If X-coordinates are too close (indicating vertical), we won't flip
#      30 if all(diff < 10 for diff in x_differences):  # Threshold of 10, adjust as needed
#
# Cell In[16], line 27, in <listcomp>(.0)
#      23     return ' '.join(flipped_coordinates)
#      25 # Handle cases where X-coordinates might be too close (e.g., vertical lines)
#      26 # We only flip if there's a significant difference between X-coordinates
# ---> 27 x_differences = [abs(int(x_coords[i]) - int(x_coords[i+1])) for i in range(len(x_coords)-1)]
#      29 # If X-coordinates are too close (indicating vertical), we won't flip
#      30 if all(diff < 10 for diff in x_differences):  # Threshold of 10, adjust as needed
#
# ValueError: invalid literal for int() with base 10: '301.99999999999966'

# %%
######## OLD stuff

# %%
import os
import xml.etree.ElementTree as ET

def update_xml_file(xml_path, tiff_to_jpeg_map):
    """
    Update the XML file to point to the corresponding JPEG image.
    """
    try:
        tree = ET.parse(xml_path)
        root = tree.getroot()
        namespace = {'ns': 'http://schema.primaresearch.org/PAGE/gts/pagecontent/2019-07-15'}

        page_element = root.find('ns:Page', namespace)

        if page_element is not None:
            tiff_filename = page_element.get('imageFilename')
            if tiff_filename in tiff_to_jpeg_map:
                jpeg_filename = tiff_to_jpeg_map[tiff_filename]
                page_element.set('imageFilename', jpeg_filename)
                tree.write(xml_path)
                print(f'Updated {xml_path} to point to {jpeg_filename}')
            else:
                print(f'No JPEG mapping found for {tiff_filename} in {xml_path}')
        else:
            print(f'No Page element found in {xml_path}')
    except Exception as e:
        print(f'Error updating XML file {xml_path}: {e}')

def main():
    directory = r'C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\uri_gt'

    # Collect TIFF to JPEG mappings
    tiff_to_jpeg_map = {}
    for file in os.listdir(directory):
        if file.lower().endswith('.tif'):
            tiff_filename = file
            jpeg_filename = file.replace('.tif', '.jpeg')
            tiff_to_jpeg_map[tiff_filename] = jpeg_filename

    # Update XML files in the directory
    for file in os.listdir(directory):
        if file.lower().endswith('.xml'):
            xml_path = os.path.join(directory, file)
            update_xml_file(xml_path, tiff_to_jpeg_map)

if __name__ == '__main__':
    main()
# Out:
# No JPEG mapping found for IDGNAZIM0001.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM0001.xml
# No JPEG mapping found for IDGNAZIM00010.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00010.xml
# No JPEG mapping found for IDGNAZIM000100.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000100.xml
# No JPEG mapping found for IDGNAZIM000101.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000101.xml
# No JPEG mapping found for IDGNAZIM000102.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000102.xml
# No JPEG mapping found for IDGNAZIM000103.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000103.xml
# No JPEG mapping found for IDGNAZIM000104.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000104.xml
# No JPEG mapping found for IDGNAZIM000105.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000105.xml
# No JPEG mapping found for IDGNAZIM000106.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000106.xml
# No JPEG mapping found for IDGNAZIM000107.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000107.xml
# No JPEG mapping found for IDGNAZIM000108.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000108.xml
# No JPEG mapping found for IDGNAZIM000109.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000109.xml
# No JPEG mapping found for IDGNAZIM00011.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00011.xml
# No JPEG mapping found for IDGNAZIM000110.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000110.xml
# No JPEG mapping found for IDGNAZIM000111.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000111.xml
# No JPEG mapping found for IDGNAZIM000112.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000112.xml
# No JPEG mapping found for IDGNAZIM000113.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000113.xml
# No JPEG mapping found for IDGNAZIM000114.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000114.xml
# No JPEG mapping found for IDGNAZIM000115.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000115.xml
# No JPEG mapping found for IDGNAZIM000116.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000116.xml
# No JPEG mapping found for IDGNAZIM000117.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000117.xml
# No JPEG mapping found for IDGNAZIM000118.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000118.xml
# No JPEG mapping found for IDGNAZIM000119.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000119.xml
# No JPEG mapping found for IDGNAZIM00012.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00012.xml
# No JPEG mapping found for IDGNAZIM000120.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000120.xml
# No JPEG mapping found for IDGNAZIM000121.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000121.xml
# No JPEG mapping found for IDGNAZIM000122.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000122.xml
# No JPEG mapping found for IDGNAZIM000123.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000123.xml
# No JPEG mapping found for IDGNAZIM000124.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000124.xml
# No JPEG mapping found for IDGNAZIM000125.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000125.xml
# No JPEG mapping found for IDGNAZIM000126.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000126.xml
# No JPEG mapping found for IDGNAZIM000127.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000127.xml
# No JPEG mapping found for IDGNAZIM000128.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000128.xml
# No JPEG mapping found for IDGNAZIM000129.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000129.xml
# No JPEG mapping found for IDGNAZIM00013.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00013.xml
# No JPEG mapping found for IDGNAZIM000130.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000130.xml
# No JPEG mapping found for IDGNAZIM000131.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000131.xml
# No JPEG mapping found for IDGNAZIM000132.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000132.xml
# No JPEG mapping found for IDGNAZIM000133.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000133.xml
# No JPEG mapping found for IDGNAZIM000134.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000134.xml
# No JPEG mapping found for IDGNAZIM000135.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000135.xml
# No JPEG mapping found for IDGNAZIM000136.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000136.xml
# No JPEG mapping found for IDGNAZIM000137.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000137.xml
# No JPEG mapping found for IDGNAZIM000138.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000138.xml
# No JPEG mapping found for IDGNAZIM000139.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000139.xml
# No JPEG mapping found for IDGNAZIM00014.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00014.xml
# No JPEG mapping found for IDGNAZIM000140.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000140.xml
# No JPEG mapping found for IDGNAZIM000141.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000141.xml
# No JPEG mapping found for IDGNAZIM000142.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000142.xml
# No JPEG mapping found for IDGNAZIM000143.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000143.xml
# No JPEG mapping found for IDGNAZIM000144.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000144.xml
# No JPEG mapping found for IDGNAZIM000145.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000145.xml
# No JPEG mapping found for IDGNAZIM000146.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000146.xml
# No JPEG mapping found for IDGNAZIM000147.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000147.xml
# No JPEG mapping found for IDGNAZIM000148.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000148.xml
# No JPEG mapping found for IDGNAZIM000149.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000149.xml
# No JPEG mapping found for IDGNAZIM00015.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00015.xml
# No JPEG mapping found for IDGNAZIM000150.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000150.xml
# No JPEG mapping found for IDGNAZIM000151.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000151.xml
# No JPEG mapping found for IDGNAZIM000152.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000152.xml
# No JPEG mapping found for IDGNAZIM000153.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000153.xml
# No JPEG mapping found for IDGNAZIM000154.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000154.xml
# No JPEG mapping found for IDGNAZIM000155.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000155.xml
# No JPEG mapping found for IDGNAZIM000156.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000156.xml
# No JPEG mapping found for IDGNAZIM000157.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000157.xml
# No JPEG mapping found for IDGNAZIM000158.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000158.xml
# No JPEG mapping found for IDGNAZIM000159.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000159.xml
# No JPEG mapping found for IDGNAZIM00016.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00016.xml
# No JPEG mapping found for IDGNAZIM000160.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000160.xml
# No JPEG mapping found for IDGNAZIM000161.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000161.xml
# No JPEG mapping found for IDGNAZIM000162.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000162.xml
# No JPEG mapping found for IDGNAZIM000163.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000163.xml
# No JPEG mapping found for IDGNAZIM000164.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000164.xml
# No JPEG mapping found for IDGNAZIM000165.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000165.xml
# No JPEG mapping found for IDGNAZIM000166.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000166.xml
# No JPEG mapping found for IDGNAZIM000167.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000167.xml
# No JPEG mapping found for IDGNAZIM000168.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000168.xml
# No JPEG mapping found for IDGNAZIM000169.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000169.xml
# No JPEG mapping found for IDGNAZIM00017.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00017.xml
# No JPEG mapping found for IDGNAZIM000170.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000170.xml
# No JPEG mapping found for IDGNAZIM000171.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000171.xml
# No JPEG mapping found for IDGNAZIM000172.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000172.xml
# No JPEG mapping found for IDGNAZIM000173.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000173.xml
# No JPEG mapping found for IDGNAZIM000174.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000174.xml
# No JPEG mapping found for IDGNAZIM000175.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000175.xml
# No JPEG mapping found for IDGNAZIM000176.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000176.xml
# No JPEG mapping found for IDGNAZIM000177.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000177.xml
# No JPEG mapping found for IDGNAZIM000178.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000178.xml
# No JPEG mapping found for IDGNAZIM000179.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000179.xml
# No JPEG mapping found for IDGNAZIM00018.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00018.xml
# No JPEG mapping found for IDGNAZIM000180.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000180.xml
# No JPEG mapping found for IDGNAZIM000181.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000181.xml
# No JPEG mapping found for IDGNAZIM000182.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000182.xml
# No JPEG mapping found for IDGNAZIM000183.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000183.xml
# No JPEG mapping found for IDGNAZIM000184.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000184.xml
# No JPEG mapping found for IDGNAZIM000185.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000185.xml
# No JPEG mapping found for IDGNAZIM000186.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000186.xml
# No JPEG mapping found for IDGNAZIM000187.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000187.xml
# No JPEG mapping found for IDGNAZIM000188.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000188.xml
# No JPEG mapping found for IDGNAZIM000189.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000189.xml
# No JPEG mapping found for IDGNAZIM00019.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00019.xml
# No JPEG mapping found for IDGNAZIM000190.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000190.xml
# No JPEG mapping found for IDGNAZIM000191.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000191.xml
# No JPEG mapping found for IDGNAZIM000192.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000192.xml
# No JPEG mapping found for IDGNAZIM000193.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000193.xml
# No JPEG mapping found for IDGNAZIM000194.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000194.xml
# No JPEG mapping found for IDGNAZIM000195.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000195.xml
# No JPEG mapping found for IDGNAZIM000196.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000196.xml
# No JPEG mapping found for IDGNAZIM000197.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000197.xml
# No JPEG mapping found for IDGNAZIM000198.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000198.xml
# No JPEG mapping found for IDGNAZIM000199.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000199.xml
# No JPEG mapping found for IDGNAZIM0002.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM0002.xml
# No JPEG mapping found for IDGNAZIM00020.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00020.xml
# No JPEG mapping found for IDGNAZIM000200.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000200.xml
# No JPEG mapping found for IDGNAZIM000201.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000201.xml
# No JPEG mapping found for IDGNAZIM000202.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000202.xml
# No JPEG mapping found for IDGNAZIM000203.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000203.xml
# No JPEG mapping found for IDGNAZIM000204.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000204.xml
# No JPEG mapping found for IDGNAZIM000205.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000205.xml
# No JPEG mapping found for IDGNAZIM000206.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000206.xml
# No JPEG mapping found for IDGNAZIM000207.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000207.xml
# No JPEG mapping found for IDGNAZIM000208.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000208.xml
# No JPEG mapping found for IDGNAZIM000209.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000209.xml
# No JPEG mapping found for IDGNAZIM00021.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00021.xml
# No JPEG mapping found for IDGNAZIM000210.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000210.xml
# No JPEG mapping found for IDGNAZIM000211.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000211.xml
# No JPEG mapping found for IDGNAZIM000212.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000212.xml
# No JPEG mapping found for IDGNAZIM000213.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000213.xml
# No JPEG mapping found for IDGNAZIM000214.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000214.xml
# No JPEG mapping found for IDGNAZIM000215.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000215.xml
# No JPEG mapping found for IDGNAZIM000216.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000216.xml
# No JPEG mapping found for IDGNAZIM000217.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000217.xml
# No JPEG mapping found for IDGNAZIM000218.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000218.xml
# No JPEG mapping found for IDGNAZIM000219.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000219.xml
# No JPEG mapping found for IDGNAZIM00022.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00022.xml
# No JPEG mapping found for IDGNAZIM000220.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000220.xml
# No JPEG mapping found for IDGNAZIM000221.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000221.xml
# No JPEG mapping found for IDGNAZIM000222.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000222.xml
# No JPEG mapping found for IDGNAZIM000223.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000223.xml
# No JPEG mapping found for IDGNAZIM000224.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000224.xml
# No JPEG mapping found for IDGNAZIM000225.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000225.xml
# No JPEG mapping found for IDGNAZIM000226.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000226.xml
# No JPEG mapping found for IDGNAZIM000227.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000227.xml
# No JPEG mapping found for IDGNAZIM000228.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000228.xml
# No JPEG mapping found for IDGNAZIM000229.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000229.xml
# No JPEG mapping found for IDGNAZIM00023.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00023.xml
# No JPEG mapping found for IDGNAZIM000230.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000230.xml
# No JPEG mapping found for IDGNAZIM000231.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000231.xml
# No JPEG mapping found for IDGNAZIM000232.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000232.xml
# No JPEG mapping found for IDGNAZIM000233.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000233.xml
# No JPEG mapping found for IDGNAZIM000234.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000234.xml
# No JPEG mapping found for IDGNAZIM000235.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000235.xml
# No JPEG mapping found for IDGNAZIM000236.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000236.xml
# No JPEG mapping found for IDGNAZIM000237.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000237.xml
# No JPEG mapping found for IDGNAZIM000238.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000238.xml
# No JPEG mapping found for IDGNAZIM000239.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000239.xml
# No JPEG mapping found for IDGNAZIM00024.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00024.xml
# No JPEG mapping found for IDGNAZIM000240.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000240.xml
# No JPEG mapping found for IDGNAZIM000241.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000241.xml
# No JPEG mapping found for IDGNAZIM000242.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000242.xml
# No JPEG mapping found for IDGNAZIM000243.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000243.xml
# No JPEG mapping found for IDGNAZIM000244.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000244.xml
# No JPEG mapping found for IDGNAZIM000245.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000245.xml
# No JPEG mapping found for IDGNAZIM000246.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000246.xml
# No JPEG mapping found for IDGNAZIM000247.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000247.xml
# No JPEG mapping found for IDGNAZIM000248.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000248.xml
# No JPEG mapping found for IDGNAZIM000249.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000249.xml
# No JPEG mapping found for IDGNAZIM00025.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00025.xml
# No JPEG mapping found for IDGNAZIM000250.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM000250.xml
# No JPEG mapping found for IDGNAZIM00026.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00026.xml
# No JPEG mapping found for IDGNAZIM00027.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00027.xml
# No JPEG mapping found for IDGNAZIM00028.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00028.xml
# No JPEG mapping found for IDGNAZIM00029.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00029.xml
# No JPEG mapping found for IDGNAZIM0003.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM0003.xml
# No JPEG mapping found for IDGNAZIM00030.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00030.xml
# No JPEG mapping found for IDGNAZIM00031.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00031.xml
# No JPEG mapping found for IDGNAZIM00032.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00032.xml
# No JPEG mapping found for IDGNAZIM00033.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00033.xml
# No JPEG mapping found for IDGNAZIM00034.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00034.xml
# No JPEG mapping found for IDGNAZIM00035.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00035.xml
# No JPEG mapping found for IDGNAZIM00036.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00036.xml
# No JPEG mapping found for IDGNAZIM00037.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00037.xml
# No JPEG mapping found for IDGNAZIM00038.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00038.xml
# No JPEG mapping found for IDGNAZIM00039.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00039.xml
# No JPEG mapping found for IDGNAZIM0004.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM0004.xml
# No JPEG mapping found for IDGNAZIM00040.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00040.xml
# No JPEG mapping found for IDGNAZIM00041.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00041.xml
# No JPEG mapping found for IDGNAZIM00042.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00042.xml
# No JPEG mapping found for IDGNAZIM00043.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00043.xml
# No JPEG mapping found for IDGNAZIM00044.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00044.xml
# No JPEG mapping found for IDGNAZIM00045.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00045.xml
# No JPEG mapping found for IDGNAZIM00046.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00046.xml
# No JPEG mapping found for IDGNAZIM00047.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00047.xml
# No JPEG mapping found for IDGNAZIM00048.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00048.xml
# No JPEG mapping found for IDGNAZIM00049.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00049.xml
# No JPEG mapping found for IDGNAZIM0005.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM0005.xml
# No JPEG mapping found for IDGNAZIM00050.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00050.xml
# No JPEG mapping found for IDGNAZIM00051.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00051.xml
# No JPEG mapping found for IDGNAZIM00052.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00052.xml
# No JPEG mapping found for IDGNAZIM00053.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00053.xml
# No JPEG mapping found for IDGNAZIM00054.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00054.xml
# No JPEG mapping found for IDGNAZIM00055.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00055.xml
# No JPEG mapping found for IDGNAZIM00056.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00056.xml
# No JPEG mapping found for IDGNAZIM00057.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00057.xml
# No JPEG mapping found for IDGNAZIM00058.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00058.xml
# No JPEG mapping found for IDGNAZIM00059.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00059.xml
# No JPEG mapping found for IDGNAZIM0006.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM0006.xml
# No JPEG mapping found for IDGNAZIM00060.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00060.xml
# No JPEG mapping found for IDGNAZIM00061.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00061.xml
# No JPEG mapping found for IDGNAZIM00062.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00062.xml
# No JPEG mapping found for IDGNAZIM00063.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00063.xml
# No JPEG mapping found for IDGNAZIM00064.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00064.xml
# No JPEG mapping found for IDGNAZIM00065.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00065.xml
# No JPEG mapping found for IDGNAZIM00066.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00066.xml
# No JPEG mapping found for IDGNAZIM00067.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00067.xml
# No JPEG mapping found for IDGNAZIM00068.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00068.xml
# No JPEG mapping found for IDGNAZIM00069.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00069.xml
# No JPEG mapping found for IDGNAZIM0007.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM0007.xml
# No JPEG mapping found for IDGNAZIM00070.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00070.xml
# No JPEG mapping found for IDGNAZIM00071.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00071.xml
# No JPEG mapping found for IDGNAZIM00072.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00072.xml
# No JPEG mapping found for IDGNAZIM00073.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00073.xml
# No JPEG mapping found for IDGNAZIM00074.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00074.xml
# No JPEG mapping found for IDGNAZIM00075.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00075.xml
# No JPEG mapping found for IDGNAZIM00076.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00076.xml
# No JPEG mapping found for IDGNAZIM00077.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00077.xml
# No JPEG mapping found for IDGNAZIM00078.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00078.xml
# No JPEG mapping found for IDGNAZIM00079.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00079.xml
# No JPEG mapping found for IDGNAZIM0008.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM0008.xml
# No JPEG mapping found for IDGNAZIM00080.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00080.xml
# No JPEG mapping found for IDGNAZIM00081.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00081.xml
# No JPEG mapping found for IDGNAZIM00082.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00082.xml
# No JPEG mapping found for IDGNAZIM00083.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00083.xml
# No JPEG mapping found for IDGNAZIM00084.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00084.xml
# No JPEG mapping found for IDGNAZIM00085.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00085.xml
# No JPEG mapping found for IDGNAZIM00086.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00086.xml
# No JPEG mapping found for IDGNAZIM00087.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00087.xml
# No JPEG mapping found for IDGNAZIM00088.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00088.xml
# No JPEG mapping found for IDGNAZIM00089.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00089.xml
# No JPEG mapping found for IDGNAZIM0009.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM0009.xml
# No JPEG mapping found for IDGNAZIM00090.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00090.xml
# No JPEG mapping found for IDGNAZIM00091.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00091.xml
# No JPEG mapping found for IDGNAZIM00092.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00092.xml
# No JPEG mapping found for IDGNAZIM00093.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00093.xml
# No JPEG mapping found for IDGNAZIM00094.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00094.xml
# No JPEG mapping found for IDGNAZIM00095.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00095.xml
# No JPEG mapping found for IDGNAZIM00096.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00096.xml
# No JPEG mapping found for IDGNAZIM00097.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00097.xml
# No JPEG mapping found for IDGNAZIM00098.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00098.xml
# No JPEG mapping found for IDGNAZIM00099.tif in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\IDGNAZIM00099.xml
# No Page element found in C:\Users\User\PycharmProjects\Gnazim_New\gnazim\training_data\pagexml\METS.xml

# %%
import os
import xml.etree.ElementTree as ET

def update_xml_filenames(directory):
    """
    Update the imageFilename attribute in XML files from .tif to .jpeg.
    """
    namespace = {'ns': 'http://schema.primaresearch.org/PAGE/gts/pagecontent/2019-07-15'}
    for file in os.listdir(directory):
        if file.lower().endswith('.xml'):
            xml_path = os.path.join(directory, file)
            try:
                tree = ET.parse(xml_path)
                root = tree.getroot()
                page_element = root.find('ns:Page', namespace)

                if page_element is not None:
                    image_filename = page_element.get('imageFilename')
                    if image_filename.lower().endswith('.tif'):
                        new_image_filename = image_filename.replace('.tif', '.jpeg')
                        page_element.set('imageFilename', new_image_filename)
                        tree.write(xml_path)
                        print(f'Updated {xml_path}: {image_filename} to {new_image_filename}')
                    else:
                        print(f'No .tif found in {xml_path}')
                else:
                    print(f'No Page element found in {xml_path}')
            except Exception as e:
                print(f'Error updating XML file {xml_path}: {e}')

def main():
    directory = r'C:\Users\User\PycharmProjects\HebHTR\HebHTR_Transkribus\895769\lubrani-9\alto'
    update_xml_filenames(directory)

if __name__ == '__main__':
    main()
# Out:
# No Page element found in C:\Users\User\PycharmProjects\HebHTR\HebHTR_Transkribus\895769\lubrani-9\alto\0001_לבוא במגע עם ילדי העולים לעמוד על דרכי חנוכם_1.xml
# No Page element found in C:\Users\User\PycharmProjects\HebHTR\HebHTR_Transkribus\895769\lubrani-9\alto\0002_לבוא במגע עם ילדי העולים לעמוד על דרכי חנוכם_2.xml

# %%
import os
import xml.etree.ElementTree as ET

def check_well_formed_xml(directory):
    """
    Check if XML files in the specified directory are well-formed.
    """
    for file in os.listdir(directory):
        if file.lower().endswith('.xml'):
            xml_path = os.path.join(directory, file)
            try:
                tree = ET.parse(xml_path)
                #print(f'{xml_path}: Well-formed')
            except ET.ParseError as e:
                print(f'{xml_path}: XML parsing error - {e}')
            except Exception as e:
                print(f'{xml_path}: Error - {e}')

def main():
    directory = r'C:/Users/User/PycharmProjects/HebHTR/training_data'
    check_well_formed_xml(directory)

if __name__ == '__main__':
    main()

# %%
import os
import xml.etree.ElementTree as ET

def fix_ns0_to_default_namespace(file_path, output_path=None):
    tree = ET.parse(file_path)
    root = tree.getroot()

    # Get the actual URI from ns0:alto
    ns_uri = root.tag.split('}')[0].strip('{')

    # Strip 'ns0:' from all tags
    for elem in root.iter():
        if isinstance(elem.tag, str) and '}' in elem.tag:
            elem.tag = elem.tag.split('}', 1)[1]

    # Replace root tag and reset attributes
    root.attrib.clear()
    root.set('xmlns', ns_uri)
#     root.set('xmlns:xsi', "http://www.w3.org/2001/XMLSchema-instance")
    root.set('{http://www.w3.org/2001/XMLSchema-instance}schemaLocation',
             f"{ns_uri} http://www.loc.gov/standards/alto/v4/alto-4-2.xsd")

    output_path = output_path or file_path
    tree.write(output_path, encoding='utf-8', xml_declaration=True)
    print(f"✅ Fixed namespace in: {output_path}")

def fix_all_xmls_in_folder(folder_path):
    for fname in os.listdir(folder_path):
        if fname.lower().endswith('.xml'):
            in_path = os.path.join(folder_path, fname)
            out_path = os.path.join(folder_path, fname.replace(".xml", "_fixed.xml"))
            try:
                fix_ns0_to_default_namespace(in_path, out_path)
            except Exception as e:
                print(f"❌ Failed to fix {fname}: {e}")

# Example usage
# === Example usage ===
folder = r'C:/Users/User/PycharmProjects/HebHTR/GT_copy'

fix_all_xmls_in_folder("C:/Users/User/PycharmProjects/HebHTR/GT_copy")
# Out:
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\1_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\3_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 10_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 2_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 4_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 5_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 6_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 7_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 8_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 9_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT001_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT002_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT002_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT003_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT003_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT004_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT004_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT005_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT005_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT006_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT006_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT007_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT007_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT008_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT008_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT009_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT009_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT010_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT010_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT011_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT011_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT012_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT012_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT013_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT013_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT014_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT014_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT015_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT015_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT016_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT016_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT017_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT017_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT018_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT018_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT019_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT019_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT020_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT020_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT021_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT021_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT022_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT022_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT023_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT023_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT024_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT024_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT025_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT025_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT026_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT026_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT027_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT027_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT028_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT028_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT029_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT029_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT030_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT030_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT031_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT031_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT032_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT032_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT033_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT033_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT034_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT034_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT035_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT035_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT036_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT036_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT037_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT037_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT038_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT038_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT039_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT039_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT040_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT040_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT041_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT041_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT042_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT042_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT043_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT043_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT044_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT044_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT045_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT045_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT046_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT046_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT047_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT047_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT048_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT048_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT049_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT049_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT050_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT050_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT051_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT051_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT052_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT052_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT053_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT053_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT054_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT054_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT055_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT055_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT056_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT056_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT057_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT057_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT058_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT058_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT059_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT059_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT060_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT060_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT061_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT061_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT062_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT062_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT063_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT063_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT064_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT064_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT065_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT065_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT066_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT066_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT067_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT067_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT068_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT068_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT069_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT069_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT070_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT070_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT071_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT071_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT072_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT072_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT073_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT073_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT074_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT074_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT075_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT075_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT076_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT076_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT077_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT077_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT078_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT078_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT079_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT079_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT080_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT080_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT081_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT081_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT082_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT082_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT083_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT083_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT084_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT084_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT085_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT085_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT086_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT086_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT087_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT087_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT088_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT088_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT089_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT089_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT090_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT090_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT091_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT091_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT092_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT092_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT093_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT093_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT094_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT094_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT095_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT095_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT096_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT096_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT097_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT097_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT098_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT098_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT099_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT099_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT100_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT100_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT101_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT101_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT102_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT102_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT103_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT103_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT104_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT104_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT105_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT105_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT106_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT106_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT107_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT107_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT108_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT108_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT109_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT109_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT110_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT110_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT111_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT111_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT112_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT112_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT113_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT113_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT114_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT114_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT115_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT115_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT116_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT116_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT117_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT117_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT118_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT118_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT119_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT119_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT120_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT120_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT121_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT121_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT122_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT122_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT123_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT123_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT124_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT124_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT125_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT125_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT126_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT126_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT127_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT127_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT128_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT128_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT129_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT129_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT130_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT130_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT131_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT131_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT132_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT132_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT133_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT133_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT134_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT134_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT135_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT135_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT136_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT136_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT137_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT137_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT138_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT138_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT139_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT139_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT140_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT140_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT141_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT141_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT142_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT142_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT143_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT143_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT144_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT144_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT145_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT145_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT146_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT146_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT147_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT147_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT148_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT148_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT149_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT149_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT150_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT150_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT151_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT151_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT152_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT152_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT153_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT153_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT154_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT154_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT155_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT155_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT156_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT156_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT157_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT157_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT158_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT158_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT159_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT159_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT160_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT160_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT161_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT161_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT162_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT162_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT163_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT163_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT164_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT164_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT165_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT165_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT166_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT166_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT167_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT167_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT168_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT168_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT169_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT169_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT170_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT170_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT171_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT171_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT172_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT172_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT173_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT173_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT174_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT174_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT175_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT175_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT176_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT176_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT177_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT177_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT178_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT178_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT179_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT179_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT180_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT180_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT181_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT181_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT182_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT182_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT183_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT183_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT184_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT184_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT185_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT185_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT186_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT186_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT187_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT187_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT188_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT188_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT189_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT189_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT190_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT190_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT191_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT191_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT192_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT192_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT193_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT193_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT194_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT194_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT195_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT195_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT196_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT196_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT197_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT197_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT198_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT198_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT199_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT199_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT200_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT200_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM0001_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000101_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000101_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000109_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000109_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000114_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000114_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000120_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000120_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000128_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000128_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000135_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000135_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000140_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000140_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000142_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000142_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000145_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000145_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000148_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000148_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000153_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000153_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000154_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000154_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000159_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000159_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000161_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000161_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000163_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000163_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000169_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000169_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000181_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000181_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000183_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000183_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000188_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000188_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000190_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000190_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000191_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000191_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000197_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000197_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM0001_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000200_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000200_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000201_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000201_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000205_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000205_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000206_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000206_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000216_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000216_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00023_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000234_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000234_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000239_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000239_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00023_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000240_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000240_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000246_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000246_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000247_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000247_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00028_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00028_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00029_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00029_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM0003_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00030_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00030_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00037_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00037_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM0003_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00042_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00042_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00046_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00046_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00049_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00049_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00054_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00054_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00075_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00075_fixed_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00078_fixed.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00078_fixed_fixed.xml

# %%
import os
import xml.etree.ElementTree as ET

def fix_ns0_to_default_namespace(file_path, output_path=None):
    tree = ET.parse(file_path)
    root = tree.getroot()

    # Get the actual URI from ns0:alto
    ns_uri = root.tag.split('}')[0].strip('{')

    # Strip 'ns0:' from all tags
    for elem in root.iter():
        if isinstance(elem.tag, str) and '}' in elem.tag:
            elem.tag = elem.tag.split('}', 1)[1]

    # Replace root tag and reset attributes
    root.attrib.clear()
    root.set('xmlns', ns_uri)
    root.set('{http://www.w3.org/2001/XMLSchema-instance}schemaLocation',
             f"{ns_uri} http://www.loc.gov/standards/alto/v4/alto-4-2.xsd")

    output_path = output_path or file_path  # 👈 this now defaults to overwriting
    tree.write(output_path, encoding='utf-8', xml_declaration=True)
    print(f"✅ Fixed namespace in: {output_path}")

def fix_all_xmls_in_folder(folder_path):
    for fname in os.listdir(folder_path):
        if fname.lower().endswith('.xml'):
            file_path = os.path.join(folder_path, fname)
            try:
                fix_ns0_to_default_namespace(file_path)
            except Exception as e:
                print(f"❌ Failed to fix {fname}: {e}")

# Run the script on your folder
folder = r'C:/Users/User/PycharmProjects/HebHTR/GT_copy'
fix_all_xmls_in_folder(folder)
# Out:
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\1.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\3.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 10.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 2.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 4.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 5.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 6.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 7.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 8.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\gnazim HTR 9.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT001.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT002.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT003.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT004.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT005.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT006.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT007.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT008.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT009.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT010.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT011.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT012.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT013.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT014.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT015.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT016.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT017.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT018.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT019.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT020.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT021.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT022.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT023.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT024.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT025.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT026.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT027.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT028.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT029.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT030.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT031.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT032.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT033.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT034.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT035.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT036.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT037.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT038.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT039.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT040.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT041.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT042.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT043.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT044.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT045.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT046.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT047.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT048.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT049.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT050.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT051.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT052.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT053.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT054.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT055.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT056.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT057.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT058.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT059.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT060.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT061.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT062.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT063.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT064.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT065.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT066.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT067.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT068.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT069.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT070.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT071.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT072.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT073.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT074.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT075.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT076.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT077.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT078.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT079.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT080.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT081.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT082.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT083.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT084.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT085.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT086.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT087.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT088.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT089.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT090.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT091.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT092.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT093.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT094.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT095.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT096.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT097.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT098.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT099.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT100.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT101.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT102.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT103.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT104.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT105.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT106.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT107.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT108.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT109.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT110.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT111.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT112.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT113.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT114.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT115.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT116.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT117.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT118.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT119.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT120.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT121.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT122.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT123.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT124.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT125.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT126.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT127.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT128.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT129.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT130.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT131.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT132.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT133.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT134.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT135.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT136.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT137.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT138.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT139.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT140.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT141.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT142.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT143.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT144.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT145.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT146.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT147.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT148.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT149.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT150.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT151.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT152.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT153.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT154.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT155.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT156.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT157.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT158.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT159.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT160.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT161.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT162.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT163.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT164.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT165.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT166.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT167.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT168.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT169.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT170.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT171.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT172.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT173.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT174.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT175.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT176.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT177.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT178.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT179.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT180.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT181.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT182.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT183.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT184.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT185.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT186.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT187.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT188.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT189.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT190.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT191.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT192.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT193.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT194.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT195.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT196.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT197.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT198.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT199.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\HEB_HTR_GT200.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM0001.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000101.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000109.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000114.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000120.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000128.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000135.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000140.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000142.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000145.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000148.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000153.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000154.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000159.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000161.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000163.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000169.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000181.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000183.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000188.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000190.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000191.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000197.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000200.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000201.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000205.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000206.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000216.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00023.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000234.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000239.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000240.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000246.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM000247.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00028.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00029.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM0003.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00030.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00037.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00042.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00046.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00049.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00054.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00075.xml
# ✅ Fixed namespace in: C:/Users/User/PycharmProjects/HebHTR/GT_copy\IDGNAZIM00078.xml
