# %%
import os

# %%
folder = f'training_data'
i = 0
for file_name in os.listdir(folder):
    new_name = f'HebHTR_GT_{i+1}'

    # Renaming the file
    os.rename(f'{folder}/{file_name}', f'{folder}/{new_name}')

print('All Files Renamed')
# Out:
# All Files Renamed

# %%
file_name
# Out:
# 'Ahtar_Nummer 9 (28. Ḏū l-ḥiǧǧa 1292 -- 13. Kânûn-ı Sânî 1291 -- 25. Januar 1876)_36.jpg'

# %%
import os
import xml.etree.ElementTree as ET

def rename_files_and_update_xml(folder_path, file_prefix="HEB_HTR_GT_", start_number=1):
    """
    Renames all TIFF images and corresponding XML files in a folder with a sequential naming pattern.
    Also updates the 'fileName' tag inside each XML file.
    
    Parameters:
    - folder_path: Path to the folder containing both TIFF and XML files.
    - file_prefix: The prefix for the new file names (default is 'image_').
    - start_number: The number to start the sequence from (default is 1).
    """
    # Get list of TIFF and XML files in the folder
    files = sorted(os.listdir(folder_path))
  

    xml_files = [f for f in files if f.lower().endswith('.xml')]
    img_files = [f for f in files if f.lower().endswith(('.jpg', '.jpeg', '.tif', '.tiff'))]

    # Make sure there are equal numbers of images and XMLs
    if len(img_files) != len(xml_files):
        print("Error: Number of img files does not match the number of XML files!")
        return

    # Iterate over the files and rename them
    for i, (img_file, xml_file) in enumerate(zip(img_files, xml_files), start=start_number):
        new_name = f"{file_prefix}{i:03d}"  # Format the new name with leading zeros
        image_suffix = img_file.split(sep='.')[-1]
        # Construct the new file names
        new_img_name = f"{new_name}.{image_suffix}"
        new_xml_name = f"{new_name}.xml"

        # Paths to the current and new files
        img_file_path = os.path.join(folder_path, img_file)
        xml_file_path = os.path.join(folder_path, xml_file)
        new_img_file_path = os.path.join(folder_path, new_img_name)
        new_xml_file_path = os.path.join(folder_path, new_xml_name)

        # Rename the image
        os.rename(img_file_path, new_img_file_path)
        print(f"Renamed image: {img_file} -> {new_img_name}")

        # Rename the XML file
        os.rename(xml_file_path, new_xml_file_path)
        print(f"Renamed XML: {xml_file} -> {new_xml_name}")

        # Update the 'fileName' tag in the XML
        update_xml_file_name(new_xml_file_path, new_img_name)

def update_xml_file_name(xml_file_path, new_img_name):
    """
    Updates the 'fileName' tag inside the XML file to match the new image file name.
    
    Parameters:
    - xml_file_path: Path to the XML file.
    - new_img_name: The new image file name to set in the 'fileName' tag.
    """
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Find the fileName tag (assuming the fileName is inside the sourceImageInformation tag)
    ns = {'alto': 'http://www.loc.gov/standards/alto/ns-v4#'}
    file_name_element = root.find('.//alto:sourceImageInformation/alto:fileName', ns)
    
    if file_name_element is not None:
        file_name_element.text = new_img_name  # Set the new image name
        tree.write(xml_file_path, xml_declaration=True, encoding="UTF-8", method="xml")
        print(f"Updated fileName in XML: {new_img_name}")
    else:
        print(f"Warning: fileName tag not found in XML: {xml_file_path}")

# Example usage:
folder_path = r'training_data'  # Replace with the path to your folder containing TIFF and XML files
rename_files_and_update_xml(folder_path, file_prefix="HEB_HTR_GT", start_number=1)
# Out:
# Renamed image: 0001_11-3_312_5_0002-Mattathias-0003.jpg -> HEB_HTR_GT001.jpg
# Renamed XML: 0001_11-3_312_5_0002-Mattathias-0003.xml -> HEB_HTR_GT001.xml
# Updated fileName in XML: HEB_HTR_GT001.jpg
# Renamed image: 0001_11-3_312_5_0003-Mattathias-0001.jpg -> HEB_HTR_GT002.jpg
# Renamed XML: 0001_11-3_312_5_0003-Mattathias-0001.xml -> HEB_HTR_GT002.xml
# Updated fileName in XML: HEB_HTR_GT002.jpg
# Renamed image: 0001_26.4.48 - P1.jpeg -> HEB_HTR_GT003.jpeg
# Renamed XML: 0001_26.4.48 - P1.xml -> HEB_HTR_GT003.xml
# Updated fileName in XML: HEB_HTR_GT003.jpeg
# Renamed image: 0001_CamScanner 11-05-2020 13.22_page-0023.jpg -> HEB_HTR_GT004.jpg
# Renamed XML: 0001_CamScanner 11-05-2020 13.22_page-0023.xml -> HEB_HTR_GT004.xml
# Updated fileName in XML: HEB_HTR_GT004.jpg
# Renamed image: 0001_CamScanner 11-05-2020 13.22_page-0034.jpg -> HEB_HTR_GT005.jpg
# Renamed XML: 0001_CamScanner 11-05-2020 13.22_page-0034.xml -> HEB_HTR_GT005.xml
# Updated fileName in XML: HEB_HTR_GT005.jpg
# Renamed image: 0001_CamScanner 11-05-2020 13.22_page-0039.jpg -> HEB_HTR_GT006.jpg
# Renamed XML: 0001_CamScanner 11-05-2020 13.22_page-0039.xml -> HEB_HTR_GT006.xml
# Updated fileName in XML: HEB_HTR_GT006.jpg
# Renamed image: 0001_CamScanner 11-05-2020 13.22_page-0043.jpg -> HEB_HTR_GT007.jpg
# Renamed XML: 0001_CamScanner 11-05-2020 13.22_page-0043.xml -> HEB_HTR_GT007.xml
# Updated fileName in XML: HEB_HTR_GT007.jpg
# Renamed image: 0001_CamScanner 11-05-2020 13.22_page-0050.jpg -> HEB_HTR_GT008.jpg
# Renamed XML: 0001_CamScanner 11-05-2020 13.22_page-0050.xml -> HEB_HTR_GT008.xml
# Updated fileName in XML: HEB_HTR_GT008.jpg
# Renamed image: 0001_CamScanner 11-05-2020 13.22_page-0052.jpg -> HEB_HTR_GT009.jpg
# Renamed XML: 0001_CamScanner 11-05-2020 13.22_page-0052.xml -> HEB_HTR_GT009.xml
# Updated fileName in XML: HEB_HTR_GT009.jpg
# Renamed image: 0001_CamScanner 11-05-2020 13.22_page-0055.jpg -> HEB_HTR_GT010.jpg
# Renamed XML: 0001_CamScanner 11-05-2020 13.22_page-0055.xml -> HEB_HTR_GT010.xml
# Updated fileName in XML: HEB_HTR_GT010.jpg
# Renamed image: 0001_CamScanner 11-05-2020 13.22_page-0057.jpg -> HEB_HTR_GT011.jpg
# Renamed XML: 0001_CamScanner 11-05-2020 13.22_page-0057.xml -> HEB_HTR_GT011.xml
# Updated fileName in XML: HEB_HTR_GT011.jpg
# Renamed image: 0001_IMG_20190731_123532.jpg -> HEB_HTR_GT012.jpg
# Renamed XML: 0001_IMG_20190731_123532.xml -> HEB_HTR_GT012.xml
# Updated fileName in XML: HEB_HTR_GT012.jpg
# Renamed image: 0001_IMG_20190801_164520.jpg -> HEB_HTR_GT013.jpg
# Renamed XML: 0001_IMG_20190801_164520.xml -> HEB_HTR_GT013.xml
# Updated fileName in XML: HEB_HTR_GT013.jpg
# Renamed image: 0001_ea.en.letters.01.01.01.0010.jpg -> HEB_HTR_GT014.jpg
# Renamed XML: 0001_ea.en.letters.01.01.01.0010.xml -> HEB_HTR_GT014.xml
# Updated fileName in XML: HEB_HTR_GT014.jpg
# Renamed image: 0001_ea.en.letters.01.01.02.0001.jpg -> HEB_HTR_GT015.jpg
# Renamed XML: 0001_ea.en.letters.01.01.02.0001.xml -> HEB_HTR_GT015.xml
# Updated fileName in XML: HEB_HTR_GT015.jpg
# Renamed image: 0001_let5.jpg -> HEB_HTR_GT016.jpg
# Renamed XML: 0001_let5.xml -> HEB_HTR_GT016.xml
# Updated fileName in XML: HEB_HTR_GT016.jpg
# Renamed image: 0001_p001.jpg -> HEB_HTR_GT017.jpg
# Renamed XML: 0001_p001.xml -> HEB_HTR_GT017.xml
# Updated fileName in XML: HEB_HTR_GT017.jpg
# Renamed image: 0001_אני משוקע כולי בספר אמריקני של ג_והן אוהרה_1.jpeg -> HEB_HTR_GT018.jpeg
# Renamed XML: 0001_אני משוקע כולי בספר אמריקני של ג_והן אוהרה_1.xml -> HEB_HTR_GT018.xml
# Updated fileName in XML: HEB_HTR_GT018.jpeg
# Renamed image: 0001_הסילופים שנעשו בתיאור חייו של יוסף לישנסקי_1.jpeg -> HEB_HTR_GT019.jpeg
# Renamed XML: 0001_הסילופים שנעשו בתיאור חייו של יוסף לישנסקי_1.xml -> HEB_HTR_GT019.xml
# Updated fileName in XML: HEB_HTR_GT019.jpeg
# Renamed image: 0001_הפדיון הגבירו כבר פעולתם מירדן ומן הלבנון_1.jpeg -> HEB_HTR_GT020.jpeg
# Renamed XML: 0001_הפדיון הגבירו כבר פעולתם מירדן ומן הלבנון_1.xml -> HEB_HTR_GT020.xml
# Updated fileName in XML: HEB_HTR_GT020.jpeg
# Renamed image: 0001_השגתי כרטיס יחיד לפסטיבל - מחזה של שקספיר_1.jpeg -> HEB_HTR_GT021.jpeg
# Renamed XML: 0001_השגתי כרטיס יחיד לפסטיבל - מחזה של שקספיר_1.xml -> HEB_HTR_GT021.xml
# Updated fileName in XML: HEB_HTR_GT021.jpeg
# Renamed image: 0001_יצחק מולדבי - השתתפותו בהגנת תל חי_1.jpeg -> HEB_HTR_GT022.jpeg
# Renamed XML: 0001_יצחק מולדבי - השתתפותו בהגנת תל חי_1.xml -> HEB_HTR_GT022.xml
# Updated fileName in XML: HEB_HTR_GT022.jpeg
# Renamed image: 0001_ישבתי למעלה משעה עם רחל (ינאית) בבית הנשיא_1.jpeg -> HEB_HTR_GT023.jpeg
# Renamed XML: 0001_ישבתי למעלה משעה עם רחל (ינאית) בבית הנשיא_1.xml -> HEB_HTR_GT023.xml
# Updated fileName in XML: HEB_HTR_GT023.jpeg
# Renamed image: 0001_לבוא במגע עם ילדי העולים לעמוד על דרכי חנוכם_1.jpeg -> HEB_HTR_GT024.jpeg
# Renamed XML: 0001_לבוא במגע עם ילדי העולים לעמוד על דרכי חנוכם_1.xml -> HEB_HTR_GT024.xml
# Updated fileName in XML: HEB_HTR_GT024.jpeg
# Renamed image: 0001_לברכה 10-10-73  .jpg -> HEB_HTR_GT025.jpg
# Renamed XML: 0001_לברכה 10-10-73  .xml -> HEB_HTR_GT025.xml
# Updated fileName in XML: HEB_HTR_GT025.jpg
# Renamed image: 0001_לברכה 7-11-73 _0001.jpg -> HEB_HTR_GT026.jpg
# Renamed XML: 0001_לברכה 7-11-73 _0001.xml -> HEB_HTR_GT026.xml
# Updated fileName in XML: HEB_HTR_GT026.jpg
# Renamed image: 0001_מה שלום גיא ואיך הוא מתפתח.jpeg -> HEB_HTR_GT027.jpeg
# Renamed XML: 0001_מה שלום גיא ואיך הוא מתפתח.xml -> HEB_HTR_GT027.xml
# Updated fileName in XML: HEB_HTR_GT027.jpeg
# Renamed image: 0001_משה שרת חלש... אני חושד בזקן כי בכך רצה_1.jpeg -> HEB_HTR_GT028.jpeg
# Renamed XML: 0001_משה שרת חלש... אני חושד בזקן כי בכך רצה_1.xml -> HEB_HTR_GT028.xml
# Updated fileName in XML: HEB_HTR_GT028.jpeg
# Renamed image: 0001_נורית ודרור קצירי - 1.jpg -> HEB_HTR_GT029.jpg
# Renamed XML: 0001_נורית ודרור קצירי - 1.xml -> HEB_HTR_GT029.xml
# Updated fileName in XML: HEB_HTR_GT029.jpg
# Renamed image: 0001_עמ1 - מידב - 05.05.1952.jpg -> HEB_HTR_GT030.jpg
# Renamed XML: 0001_עמ1 - מידב - 05.05.1952.xml -> HEB_HTR_GT030.xml
# Updated fileName in XML: HEB_HTR_GT030.jpg
# Renamed image: 0001_פגשתי את אורנה פורת ויוסף מילוא_1.jpeg -> HEB_HTR_GT031.jpeg
# Renamed XML: 0001_פגשתי את אורנה פורת ויוסף מילוא_1.xml -> HEB_HTR_GT031.xml
# Updated fileName in XML: HEB_HTR_GT031.jpeg
# Renamed image: 0001_רדיו אמרסון נאה בחיצוניותו וצלול מבחינת הטון_1.jpeg -> HEB_HTR_GT032.jpeg
# Renamed XML: 0001_רדיו אמרסון נאה בחיצוניותו וצלול מבחינת הטון_1.xml -> HEB_HTR_GT032.xml
# Updated fileName in XML: HEB_HTR_GT032.jpeg
# Renamed image: 0002_11-3_312_5_0002-Mattathias-0005.jpg -> HEB_HTR_GT033.jpg
# Renamed XML: 0002_11-3_312_5_0002-Mattathias-0005.xml -> HEB_HTR_GT033.xml
# Updated fileName in XML: HEB_HTR_GT033.jpg
# Renamed image: 0002_11-3_312_5_0003-Mattathias-0002.jpg -> HEB_HTR_GT034.jpg
# Renamed XML: 0002_11-3_312_5_0003-Mattathias-0002.xml -> HEB_HTR_GT034.xml
# Updated fileName in XML: HEB_HTR_GT034.jpg
# Renamed image: 0002_26.4.48 - P2.jpeg -> HEB_HTR_GT035.jpeg
# Renamed XML: 0002_26.4.48 - P2.xml -> HEB_HTR_GT035.xml
# Updated fileName in XML: HEB_HTR_GT035.jpeg
# Renamed image: 0002_CamScanner 11-05-2020 13.22_page-0035.jpg -> HEB_HTR_GT036.jpg
# Renamed XML: 0002_CamScanner 11-05-2020 13.22_page-0035.xml -> HEB_HTR_GT036.xml
# Updated fileName in XML: HEB_HTR_GT036.jpg
# Renamed image: 0002_CamScanner 11-05-2020 13.22_page-0040.jpg -> HEB_HTR_GT037.jpg
# Renamed XML: 0002_CamScanner 11-05-2020 13.22_page-0040.xml -> HEB_HTR_GT037.xml
# Updated fileName in XML: HEB_HTR_GT037.jpg
# Renamed image: 0002_CamScanner 11-05-2020 13.22_page-0056.jpg -> HEB_HTR_GT038.jpg
# Renamed XML: 0002_CamScanner 11-05-2020 13.22_page-0056.xml -> HEB_HTR_GT038.xml
# Updated fileName in XML: HEB_HTR_GT038.jpg
# Renamed image: 0002_IMG_20190731_123552.jpg -> HEB_HTR_GT039.jpg
# Renamed XML: 0002_IMG_20190731_123552.xml -> HEB_HTR_GT039.xml
# Updated fileName in XML: HEB_HTR_GT039.jpg
# Renamed image: 0002_IMG_20190801_164534.jpg -> HEB_HTR_GT040.jpg
# Renamed XML: 0002_IMG_20190801_164534.xml -> HEB_HTR_GT040.xml
# Updated fileName in XML: HEB_HTR_GT040.jpg
# Renamed image: 0002_ea.en.letters.01.01.01.0011.jpg -> HEB_HTR_GT041.jpg
# Renamed XML: 0002_ea.en.letters.01.01.01.0011.xml -> HEB_HTR_GT041.xml
# Updated fileName in XML: HEB_HTR_GT041.jpg
# Renamed image: 0002_ea.en.letters.01.01.02.0002.jpg -> HEB_HTR_GT042.jpg
# Renamed XML: 0002_ea.en.letters.01.01.02.0002.xml -> HEB_HTR_GT042.xml
# Updated fileName in XML: HEB_HTR_GT042.jpg
# Renamed image: 0002_let6.jpg -> HEB_HTR_GT043.jpg
# Renamed XML: 0002_let6.xml -> HEB_HTR_GT043.xml
# Updated fileName in XML: HEB_HTR_GT043.jpg
# Renamed image: 0002_p002.jpg -> HEB_HTR_GT044.jpg
# Renamed XML: 0002_p002.xml -> HEB_HTR_GT044.xml
# Updated fileName in XML: HEB_HTR_GT044.jpg
# Renamed image: 0002_אני משוקע כולי בספר אמריקני של ג_והן אוהרה_2.jpeg -> HEB_HTR_GT045.jpeg
# Renamed XML: 0002_אני משוקע כולי בספר אמריקני של ג_והן אוהרה_2.xml -> HEB_HTR_GT045.xml
# Updated fileName in XML: HEB_HTR_GT045.jpeg
# Renamed image: 0002_הסילופים שנעשו בתיאור חייו של יוסף לישנסקי_2.jpeg -> HEB_HTR_GT046.jpeg
# Renamed XML: 0002_הסילופים שנעשו בתיאור חייו של יוסף לישנסקי_2.xml -> HEB_HTR_GT046.xml
# Updated fileName in XML: HEB_HTR_GT046.jpeg
# Renamed image: 0002_הפדיון הגבירו כבר פעולתם מירדן ומן הלבנון_2.jpeg -> HEB_HTR_GT047.jpeg
# Renamed XML: 0002_הפדיון הגבירו כבר פעולתם מירדן ומן הלבנון_2.xml -> HEB_HTR_GT047.xml
# Updated fileName in XML: HEB_HTR_GT047.jpeg
# Renamed image: 0002_השגתי כרטיס יחיד לפסטיבל - מחזה של שקספיר_2.jpeg -> HEB_HTR_GT048.jpeg
# Renamed XML: 0002_השגתי כרטיס יחיד לפסטיבל - מחזה של שקספיר_2.xml -> HEB_HTR_GT048.xml
# Updated fileName in XML: HEB_HTR_GT048.jpeg
# Renamed image: 0002_יצחק מולדבי - השתתפותו בהגנת תל חי_2.jpeg -> HEB_HTR_GT049.jpeg
# Renamed XML: 0002_יצחק מולדבי - השתתפותו בהגנת תל חי_2.xml -> HEB_HTR_GT049.xml
# Updated fileName in XML: HEB_HTR_GT049.jpeg
# Renamed image: 0002_ישבתי למעלה משעה עם רחל (ינאית) בבית הנשיא_2.jpeg -> HEB_HTR_GT050.jpeg
# Renamed XML: 0002_ישבתי למעלה משעה עם רחל (ינאית) בבית הנשיא_2.xml -> HEB_HTR_GT050.xml
# Updated fileName in XML: HEB_HTR_GT050.jpeg
# Renamed image: 0002_לבוא במגע עם ילדי העולים לעמוד על דרכי חנוכם_2.jpeg -> HEB_HTR_GT051.jpeg
# Renamed XML: 0002_לבוא במגע עם ילדי העולים לעמוד על דרכי חנוכם_2.xml -> HEB_HTR_GT051.xml
# Updated fileName in XML: HEB_HTR_GT051.jpeg
# Renamed image: 0002_משה שרת חלש... אני חושד בזקן כי בכך רצה_2.jpeg -> HEB_HTR_GT052.jpeg
# Renamed XML: 0002_משה שרת חלש... אני חושד בזקן כי בכך רצה_2.xml -> HEB_HTR_GT052.xml
# Updated fileName in XML: HEB_HTR_GT052.jpeg
# Renamed image: 0002_עמ2  - מידב - 05.05.1952.jpg -> HEB_HTR_GT053.jpg
# Renamed XML: 0002_עמ2  - מידב - 05.05.1952.xml -> HEB_HTR_GT053.xml
# Updated fileName in XML: HEB_HTR_GT053.jpg
# Renamed image: 0002_פגשתי את אורנה פורת ויוסף מילוא_2.jpeg -> HEB_HTR_GT054.jpeg
# Renamed XML: 0002_פגשתי את אורנה פורת ויוסף מילוא_2.xml -> HEB_HTR_GT054.xml
# Updated fileName in XML: HEB_HTR_GT054.jpeg
# Renamed image: 0002_רדיו אמרסון נאה בחיצוניותו וצלול מבחינת הטון_2.jpeg -> HEB_HTR_GT055.jpeg
# Renamed XML: 0002_רדיו אמרסון נאה בחיצוניותו וצלול מבחינת הטון_2.xml -> HEB_HTR_GT055.xml
# Updated fileName in XML: HEB_HTR_GT055.jpeg
# Renamed image: 0003_11-3_312_5_0002-Mattathias-0007.jpg -> HEB_HTR_GT056.jpg
# Renamed XML: 0003_11-3_312_5_0002-Mattathias-0007.xml -> HEB_HTR_GT056.xml
# Updated fileName in XML: HEB_HTR_GT056.jpg
# Renamed image: 0003_11-3_312_5_0003-Mattathias-0004.jpg -> HEB_HTR_GT057.jpg
# Renamed XML: 0003_11-3_312_5_0003-Mattathias-0004.xml -> HEB_HTR_GT057.xml
# Updated fileName in XML: HEB_HTR_GT057.jpg
# Renamed image: 0003_IMG_20190731_123604.jpg -> HEB_HTR_GT058.jpg
# Renamed XML: 0003_IMG_20190731_123604.xml -> HEB_HTR_GT058.xml
# Updated fileName in XML: HEB_HTR_GT058.jpg
# Renamed image: 0003_IMG_20190801_164558.jpg -> HEB_HTR_GT059.jpg
# Renamed XML: 0003_IMG_20190801_164558.xml -> HEB_HTR_GT059.xml
# Updated fileName in XML: HEB_HTR_GT059.jpg
# Renamed image: 0003_ea.en.letters.01.01.01.0012.jpg -> HEB_HTR_GT060.jpg
# Renamed XML: 0003_ea.en.letters.01.01.01.0012.xml -> HEB_HTR_GT060.xml
# Updated fileName in XML: HEB_HTR_GT060.jpg
# Renamed image: 0003_ea.en.letters.01.01.02.0003.jpg -> HEB_HTR_GT061.jpg
# Renamed XML: 0003_ea.en.letters.01.01.02.0003.xml -> HEB_HTR_GT061.xml
# Updated fileName in XML: HEB_HTR_GT061.jpg
# Renamed image: 0003_let7.jpg -> HEB_HTR_GT062.jpg
# Renamed XML: 0003_let7.xml -> HEB_HTR_GT062.xml
# Updated fileName in XML: HEB_HTR_GT062.jpg
# Renamed image: 0003_עמ3 - מידב - 05.05.1952.jpg -> HEB_HTR_GT063.jpg
# Renamed XML: 0003_עמ3 - מידב - 05.05.1952.xml -> HEB_HTR_GT063.xml
# Updated fileName in XML: HEB_HTR_GT063.jpg
# Renamed image: 0004_11-3_312_5_0002-Mattathias-0017.jpg -> HEB_HTR_GT064.jpg
# Renamed XML: 0004_11-3_312_5_0002-Mattathias-0017.xml -> HEB_HTR_GT064.xml
# Updated fileName in XML: HEB_HTR_GT064.jpg
# Renamed image: 0004_11-3_312_5_0003-Mattathias-0005.jpg -> HEB_HTR_GT065.jpg
# Renamed XML: 0004_11-3_312_5_0003-Mattathias-0005.xml -> HEB_HTR_GT065.xml
# Updated fileName in XML: HEB_HTR_GT065.jpg
# Renamed image: 0004_IMG_20190731_123616.jpg -> HEB_HTR_GT066.jpg
# Renamed XML: 0004_IMG_20190731_123616.xml -> HEB_HTR_GT066.xml
# Updated fileName in XML: HEB_HTR_GT066.jpg
# Renamed image: 0004_IMG_20190801_164607.jpg -> HEB_HTR_GT067.jpg
# Renamed XML: 0004_IMG_20190801_164607.xml -> HEB_HTR_GT067.xml
# Updated fileName in XML: HEB_HTR_GT067.jpg
# Renamed image: 0004_ea.en.letters.01.01.0003.jpg -> HEB_HTR_GT068.jpg
# Renamed XML: 0004_ea.en.letters.01.01.0003.xml -> HEB_HTR_GT068.xml
# Updated fileName in XML: HEB_HTR_GT068.jpg
# Renamed image: 0004_ea.en.letters.01.01.02.0004.jpg -> HEB_HTR_GT069.jpg
# Renamed XML: 0004_ea.en.letters.01.01.02.0004.xml -> HEB_HTR_GT069.xml
# Updated fileName in XML: HEB_HTR_GT069.jpg
# Renamed image: 0004_let8.jpg -> HEB_HTR_GT070.jpg
# Renamed XML: 0004_let8.xml -> HEB_HTR_GT070.xml
# Updated fileName in XML: HEB_HTR_GT070.jpg
# Renamed image: 0004_עמ4 - מידב - 05.05.1952.jpg -> HEB_HTR_GT071.jpg
# Renamed XML: 0004_עמ4 - מידב - 05.05.1952.xml -> HEB_HTR_GT071.xml
# Updated fileName in XML: HEB_HTR_GT071.jpg
# Renamed image: 0005_11-3_312_5_0002-Mattathias-0019.jpg -> HEB_HTR_GT072.jpg
# Renamed XML: 0005_11-3_312_5_0002-Mattathias-0019.xml -> HEB_HTR_GT072.xml
# Updated fileName in XML: HEB_HTR_GT072.jpg
# Renamed image: 0005_11-3_312_5_0003-Mattathias-0006.jpg -> HEB_HTR_GT073.jpg
# Renamed XML: 0005_11-3_312_5_0003-Mattathias-0006.xml -> HEB_HTR_GT073.xml
# Updated fileName in XML: HEB_HTR_GT073.jpg
# Renamed image: 0005_IMG_20190731_123623.jpg -> HEB_HTR_GT074.jpg
# Renamed XML: 0005_IMG_20190731_123623.xml -> HEB_HTR_GT074.xml
# Updated fileName in XML: HEB_HTR_GT074.jpg
# Renamed image: 0005_IMG_20190801_164616.jpg -> HEB_HTR_GT075.jpg
# Renamed XML: 0005_IMG_20190801_164616.xml -> HEB_HTR_GT075.xml
# Updated fileName in XML: HEB_HTR_GT075.jpg
# Renamed image: 0005_ea.en.letters.01.01.0004.jpg -> HEB_HTR_GT076.jpg
# Renamed XML: 0005_ea.en.letters.01.01.0004.xml -> HEB_HTR_GT076.xml
# Updated fileName in XML: HEB_HTR_GT076.jpg
# Renamed image: 0005_ea.en.letters.01.01.02.0005.jpg -> HEB_HTR_GT077.jpg
# Renamed XML: 0005_ea.en.letters.01.01.02.0005.xml -> HEB_HTR_GT077.xml
# Updated fileName in XML: HEB_HTR_GT077.jpg
# Renamed image: 0006_11-3_312_5_0002-Mattathias-0034.jpg -> HEB_HTR_GT078.jpg
# Renamed XML: 0006_11-3_312_5_0002-Mattathias-0034.xml -> HEB_HTR_GT078.xml
# Updated fileName in XML: HEB_HTR_GT078.jpg
# Renamed image: 0006_11-3_312_5_0003-Mattathias-0008.jpg -> HEB_HTR_GT079.jpg
# Renamed XML: 0006_11-3_312_5_0003-Mattathias-0008.xml -> HEB_HTR_GT079.xml
# Updated fileName in XML: HEB_HTR_GT079.jpg
# Renamed image: 0006_IMG_20190731_123634.jpg -> HEB_HTR_GT080.jpg
# Renamed XML: 0006_IMG_20190731_123634.xml -> HEB_HTR_GT080.xml
# Updated fileName in XML: HEB_HTR_GT080.jpg
# Renamed image: 0006_IMG_20190801_164624.jpg -> HEB_HTR_GT081.jpg
# Renamed XML: 0006_IMG_20190801_164624.xml -> HEB_HTR_GT081.xml
# Updated fileName in XML: HEB_HTR_GT081.jpg
# Renamed image: 0006_ea.en.letters.01.01.0005.jpg -> HEB_HTR_GT082.jpg
# Renamed XML: 0006_ea.en.letters.01.01.0005.xml -> HEB_HTR_GT082.xml
# Updated fileName in XML: HEB_HTR_GT082.jpg
# Renamed image: 0006_ea.en.letters.01.01.02.0006.jpg -> HEB_HTR_GT083.jpg
# Renamed XML: 0006_ea.en.letters.01.01.02.0006.xml -> HEB_HTR_GT083.xml
# Updated fileName in XML: HEB_HTR_GT083.jpg
# Renamed image: 0007_11-3_312_5_0002-Mattathias-0048.jpg -> HEB_HTR_GT084.jpg
# Renamed XML: 0007_11-3_312_5_0002-Mattathias-0048.xml -> HEB_HTR_GT084.xml
# Updated fileName in XML: HEB_HTR_GT084.jpg
# Renamed image: 0007_11-3_312_5_0003-Mattathias-0009.jpg -> HEB_HTR_GT085.jpg
# Renamed XML: 0007_11-3_312_5_0003-Mattathias-0009.xml -> HEB_HTR_GT085.xml
# Updated fileName in XML: HEB_HTR_GT085.jpg
# Renamed image: 0007_IMG_20190731_123643.jpg -> HEB_HTR_GT086.jpg
# Renamed XML: 0007_IMG_20190731_123643.xml -> HEB_HTR_GT086.xml
# Updated fileName in XML: HEB_HTR_GT086.jpg
# Renamed image: 0007_IMG_20190801_164629.jpg -> HEB_HTR_GT087.jpg
# Renamed XML: 0007_IMG_20190801_164629.xml -> HEB_HTR_GT087.xml
# Updated fileName in XML: HEB_HTR_GT087.jpg
# Renamed image: 0007_ea.en.letters.01.01.0006.jpg -> HEB_HTR_GT088.jpg
# Renamed XML: 0007_ea.en.letters.01.01.0006.xml -> HEB_HTR_GT088.xml
# Updated fileName in XML: HEB_HTR_GT088.jpg
# Renamed image: 0007_ea.en.letters.01.01.02.0007.jpg -> HEB_HTR_GT089.jpg
# Renamed XML: 0007_ea.en.letters.01.01.02.0007.xml -> HEB_HTR_GT089.xml
# Updated fileName in XML: HEB_HTR_GT089.jpg
# Renamed image: 0008_11-3_312_5_0002-Mattathias-0050.jpg -> HEB_HTR_GT090.jpg
# Renamed XML: 0008_11-3_312_5_0002-Mattathias-0050.xml -> HEB_HTR_GT090.xml
# Updated fileName in XML: HEB_HTR_GT090.jpg
# Renamed image: 0008_11-3_312_5_0003-Mattathias-0010.jpg -> HEB_HTR_GT091.jpg
# Renamed XML: 0008_11-3_312_5_0003-Mattathias-0010.xml -> HEB_HTR_GT091.xml
# Updated fileName in XML: HEB_HTR_GT091.jpg
# Renamed image: 0008_IMG_20190731_123721.jpg -> HEB_HTR_GT092.jpg
# Renamed XML: 0008_IMG_20190731_123721.xml -> HEB_HTR_GT092.xml
# Updated fileName in XML: HEB_HTR_GT092.jpg
# Renamed image: 0008_IMG_20190801_164641.jpg -> HEB_HTR_GT093.jpg
# Renamed XML: 0008_IMG_20190801_164641.xml -> HEB_HTR_GT093.xml
# Updated fileName in XML: HEB_HTR_GT093.jpg
# Renamed image: 0008_ea.en.letters.01.01.0007.jpg -> HEB_HTR_GT094.jpg
# Renamed XML: 0008_ea.en.letters.01.01.0007.xml -> HEB_HTR_GT094.xml
# Updated fileName in XML: HEB_HTR_GT094.jpg
# Renamed image: 0008_ea.en.letters.01.01.03.0008.jpg -> HEB_HTR_GT095.jpg
# Renamed XML: 0008_ea.en.letters.01.01.03.0008.xml -> HEB_HTR_GT095.xml
# Updated fileName in XML: HEB_HTR_GT095.jpg
# Renamed image: 0009_11-3_312_5_0002-Mattathias-0055.jpg -> HEB_HTR_GT096.jpg
# Renamed XML: 0009_11-3_312_5_0002-Mattathias-0055.xml -> HEB_HTR_GT096.xml
# Updated fileName in XML: HEB_HTR_GT096.jpg
# Renamed image: 0009_11-3_312_5_0003-Mattathias-0014.jpg -> HEB_HTR_GT097.jpg
# Renamed XML: 0009_11-3_312_5_0003-Mattathias-0014.xml -> HEB_HTR_GT097.xml
# Updated fileName in XML: HEB_HTR_GT097.jpg
# Renamed image: 0009_IMG_20190731_123729.jpg -> HEB_HTR_GT098.jpg
# Renamed XML: 0009_IMG_20190731_123729.xml -> HEB_HTR_GT098.xml
# Updated fileName in XML: HEB_HTR_GT098.jpg
# Renamed image: 0009_IMG_20190801_164646.jpg -> HEB_HTR_GT099.jpg
# Renamed XML: 0009_IMG_20190801_164646.xml -> HEB_HTR_GT099.xml
# Updated fileName in XML: HEB_HTR_GT099.jpg
# Renamed image: 0009_ea.en.letters.01.01.0008.jpg -> HEB_HTR_GT100.jpg
# Renamed XML: 0009_ea.en.letters.01.01.0008.xml -> HEB_HTR_GT100.xml
# Updated fileName in XML: HEB_HTR_GT100.jpg
# Renamed image: 0009_ea.en.letters.01.01.03.0009.jpg -> HEB_HTR_GT101.jpg
# Renamed XML: 0009_ea.en.letters.01.01.03.0009.xml -> HEB_HTR_GT101.xml
# Updated fileName in XML: HEB_HTR_GT101.jpg
# Renamed image: 0010_11-3_312_5_0002-Mattathias-0057.jpg -> HEB_HTR_GT102.jpg
# Renamed XML: 0010_11-3_312_5_0002-Mattathias-0057.xml -> HEB_HTR_GT102.xml
# Updated fileName in XML: HEB_HTR_GT102.jpg
# Renamed image: 0010_11-3_312_5_0003-Mattathias-0015.jpg -> HEB_HTR_GT103.jpg
# Renamed XML: 0010_11-3_312_5_0003-Mattathias-0015.xml -> HEB_HTR_GT103.xml
# Updated fileName in XML: HEB_HTR_GT103.jpg
# Renamed image: 0010_IMG_20190731_123743.jpg -> HEB_HTR_GT104.jpg
# Renamed XML: 0010_IMG_20190731_123743.xml -> HEB_HTR_GT104.xml
# Updated fileName in XML: HEB_HTR_GT104.jpg
# Renamed image: 0010_IMG_20190801_164653.jpg -> HEB_HTR_GT105.jpg
# Renamed XML: 0010_IMG_20190801_164653.xml -> HEB_HTR_GT105.xml
# Updated fileName in XML: HEB_HTR_GT105.jpg
# Renamed image: 0010_ea.en.letters.01.01.0009.jpg -> HEB_HTR_GT106.jpg
# Renamed XML: 0010_ea.en.letters.01.01.0009.xml -> HEB_HTR_GT106.xml
# Updated fileName in XML: HEB_HTR_GT106.jpg
# Renamed image: 0010_ea.en.letters.01.01.03.0011.jpg -> HEB_HTR_GT107.jpg
# Renamed XML: 0010_ea.en.letters.01.01.03.0011.xml -> HEB_HTR_GT107.xml
# Updated fileName in XML: HEB_HTR_GT107.jpg
# Renamed image: 0011_11-3_312_5_0002-Mattathias-0065.jpg -> HEB_HTR_GT108.jpg
# Renamed XML: 0011_11-3_312_5_0002-Mattathias-0065.xml -> HEB_HTR_GT108.xml
# Updated fileName in XML: HEB_HTR_GT108.jpg
# Renamed image: 0011_11-3_312_5_0003-Mattathias-0017.jpg -> HEB_HTR_GT109.jpg
# Renamed XML: 0011_11-3_312_5_0003-Mattathias-0017.xml -> HEB_HTR_GT109.xml
# Updated fileName in XML: HEB_HTR_GT109.jpg
# Renamed image: 0011_IMG_20190731_123749.jpg -> HEB_HTR_GT110.jpg
# Renamed XML: 0011_IMG_20190731_123749.xml -> HEB_HTR_GT110.xml
# Updated fileName in XML: HEB_HTR_GT110.jpg
# Renamed image: 0011_IMG_20190801_164658.jpg -> HEB_HTR_GT111.jpg
# Renamed XML: 0011_IMG_20190801_164658.xml -> HEB_HTR_GT111.xml
# Updated fileName in XML: HEB_HTR_GT111.jpg
# Renamed image: 0011_ea.en.letters.01.01.03.0012.jpg -> HEB_HTR_GT112.jpg
# Renamed XML: 0011_ea.en.letters.01.01.03.0012.xml -> HEB_HTR_GT112.xml
# Updated fileName in XML: HEB_HTR_GT112.jpg
# Renamed image: 0012_11-3_312_5_0002-Mattathias-0066.jpg -> HEB_HTR_GT113.jpg
# Renamed XML: 0012_11-3_312_5_0002-Mattathias-0066.xml -> HEB_HTR_GT113.xml
# Updated fileName in XML: HEB_HTR_GT113.jpg
# Renamed image: 0012_11-3_312_5_0003-Mattathias-0019.jpg -> HEB_HTR_GT114.jpg
# Renamed XML: 0012_11-3_312_5_0003-Mattathias-0019.xml -> HEB_HTR_GT114.xml
# Updated fileName in XML: HEB_HTR_GT114.jpg
# Renamed image: 0012_IMG_20190731_123755.jpg -> HEB_HTR_GT115.jpg
# Renamed XML: 0012_IMG_20190731_123755.xml -> HEB_HTR_GT115.xml
# Updated fileName in XML: HEB_HTR_GT115.jpg
# Renamed image: 0012_IMG_20190801_164706.jpg -> HEB_HTR_GT116.jpg
# Renamed XML: 0012_IMG_20190801_164706.xml -> HEB_HTR_GT116.xml
# Updated fileName in XML: HEB_HTR_GT116.jpg
# Renamed image: 0013_11-3_312_5_0002-Mattathias-0067.jpg -> HEB_HTR_GT117.jpg
# Renamed XML: 0013_11-3_312_5_0002-Mattathias-0067.xml -> HEB_HTR_GT117.xml
# Updated fileName in XML: HEB_HTR_GT117.jpg
# Renamed image: 0013_11-3_312_5_0003-Mattathias-0021.jpg -> HEB_HTR_GT118.jpg
# Renamed XML: 0013_11-3_312_5_0003-Mattathias-0021.xml -> HEB_HTR_GT118.xml
# Updated fileName in XML: HEB_HTR_GT118.jpg
# Renamed image: 0013_IMG_20190731_123802.jpg -> HEB_HTR_GT119.jpg
# Renamed XML: 0013_IMG_20190731_123802.xml -> HEB_HTR_GT119.xml
# Updated fileName in XML: HEB_HTR_GT119.jpg
# Renamed image: 0013_IMG_20190801_164710.jpg -> HEB_HTR_GT120.jpg
# Renamed XML: 0013_IMG_20190801_164710.xml -> HEB_HTR_GT120.xml
# Updated fileName in XML: HEB_HTR_GT120.jpg
# Renamed image: 0014_11-3_312_5_0002-Mattathias-0087.jpg -> HEB_HTR_GT121.jpg
# Renamed XML: 0014_11-3_312_5_0002-Mattathias-0087.xml -> HEB_HTR_GT121.xml
# Updated fileName in XML: HEB_HTR_GT121.jpg
# Renamed image: 0014_11-3_312_5_0003-Mattathias-0026.jpg -> HEB_HTR_GT122.jpg
# Renamed XML: 0014_11-3_312_5_0003-Mattathias-0026.xml -> HEB_HTR_GT122.xml
# Updated fileName in XML: HEB_HTR_GT122.jpg
# Renamed image: 0014_IMG_20190731_123809.jpg -> HEB_HTR_GT123.jpg
# Renamed XML: 0014_IMG_20190731_123809.xml -> HEB_HTR_GT123.xml
# Updated fileName in XML: HEB_HTR_GT123.jpg
# Renamed image: 0014_IMG_20190801_164719.jpg -> HEB_HTR_GT124.jpg
# Renamed XML: 0014_IMG_20190801_164719.xml -> HEB_HTR_GT124.xml
# Updated fileName in XML: HEB_HTR_GT124.jpg
# Renamed image: 0015_11-3_312_5_0002-Mattathias-0102.jpg -> HEB_HTR_GT125.jpg
# Renamed XML: 0015_11-3_312_5_0002-Mattathias-0102.xml -> HEB_HTR_GT125.xml
# Updated fileName in XML: HEB_HTR_GT125.jpg
# Renamed image: 0015_IMG_20190731_123819.jpg -> HEB_HTR_GT126.jpg
# Renamed XML: 0015_IMG_20190731_123819.xml -> HEB_HTR_GT126.xml
# Updated fileName in XML: HEB_HTR_GT126.jpg
# Renamed image: 0015_IMG_20190801_164725.jpg -> HEB_HTR_GT127.jpg
# Renamed XML: 0015_IMG_20190801_164725.xml -> HEB_HTR_GT127.xml
# Updated fileName in XML: HEB_HTR_GT127.jpg
# Renamed image: 0016_11-3_312_5_0002-Mattathias-0107.jpg -> HEB_HTR_GT128.jpg
# Renamed XML: 0016_11-3_312_5_0002-Mattathias-0107.xml -> HEB_HTR_GT128.xml
# Updated fileName in XML: HEB_HTR_GT128.jpg
# Renamed image: 0016_IMG_20190731_123829.jpg -> HEB_HTR_GT129.jpg
# Renamed XML: 0016_IMG_20190731_123829.xml -> HEB_HTR_GT129.xml
# Updated fileName in XML: HEB_HTR_GT129.jpg
# Renamed image: 0016_IMG_20190801_164734.jpg -> HEB_HTR_GT130.jpg
# Renamed XML: 0016_IMG_20190801_164734.xml -> HEB_HTR_GT130.xml
# Updated fileName in XML: HEB_HTR_GT130.jpg
# Renamed image: 0017_11-3_312_5_0002-Mattathias-0112.jpg -> HEB_HTR_GT131.jpg
# Renamed XML: 0017_11-3_312_5_0002-Mattathias-0112.xml -> HEB_HTR_GT131.xml
# Updated fileName in XML: HEB_HTR_GT131.jpg
# Renamed image: 0017_IMG_20190731_123842.jpg -> HEB_HTR_GT132.jpg
# Renamed XML: 0017_IMG_20190731_123842.xml -> HEB_HTR_GT132.xml
# Updated fileName in XML: HEB_HTR_GT132.jpg
# Renamed image: 0017_IMG_20190801_164741.jpg -> HEB_HTR_GT133.jpg
# Renamed XML: 0017_IMG_20190801_164741.xml -> HEB_HTR_GT133.xml
# Updated fileName in XML: HEB_HTR_GT133.jpg
# Renamed image: 0018_11-3_312_5_0002-Mattathias-0113.jpg -> HEB_HTR_GT134.jpg
# Renamed XML: 0018_11-3_312_5_0002-Mattathias-0113.xml -> HEB_HTR_GT134.xml
# Updated fileName in XML: HEB_HTR_GT134.jpg
# Renamed image: 0018_IMG_20190731_123853.jpg -> HEB_HTR_GT135.jpg
# Renamed XML: 0018_IMG_20190731_123853.xml -> HEB_HTR_GT135.xml
# Updated fileName in XML: HEB_HTR_GT135.jpg
# Renamed image: 0018_IMG_20190801_164755.jpg -> HEB_HTR_GT136.jpg
# Renamed XML: 0018_IMG_20190801_164755.xml -> HEB_HTR_GT136.xml
# Updated fileName in XML: HEB_HTR_GT136.jpg
# Renamed image: 0019_11-3_312_5_0002-Mattathias-0114.jpg -> HEB_HTR_GT137.jpg
# Renamed XML: 0019_11-3_312_5_0002-Mattathias-0114.xml -> HEB_HTR_GT137.xml
# Updated fileName in XML: HEB_HTR_GT137.jpg
# Renamed image: 0019_IMG_20190731_123858.jpg -> HEB_HTR_GT138.jpg
# Renamed XML: 0019_IMG_20190731_123858.xml -> HEB_HTR_GT138.xml
# Updated fileName in XML: HEB_HTR_GT138.jpg
# Renamed image: 0019_IMG_20190801_164801.jpg -> HEB_HTR_GT139.jpg
# Renamed XML: 0019_IMG_20190801_164801.xml -> HEB_HTR_GT139.xml
# Updated fileName in XML: HEB_HTR_GT139.jpg
# Renamed image: 0020_11-3_312_5_0002-Mattathias-0118.jpg -> HEB_HTR_GT140.jpg
# Renamed XML: 0020_11-3_312_5_0002-Mattathias-0118.xml -> HEB_HTR_GT140.xml
# Updated fileName in XML: HEB_HTR_GT140.jpg
# Renamed image: 0020_IMG_20190731_123908.jpg -> HEB_HTR_GT141.jpg
# Renamed XML: 0020_IMG_20190731_123908.xml -> HEB_HTR_GT141.xml
# Updated fileName in XML: HEB_HTR_GT141.jpg
# Renamed image: 0020_IMG_20190801_164811.jpg -> HEB_HTR_GT142.jpg
# Renamed XML: 0020_IMG_20190801_164811.xml -> HEB_HTR_GT142.xml
# Updated fileName in XML: HEB_HTR_GT142.jpg
# Renamed image: 0021_11-3_312_5_0002-Mattathias-0124.jpg -> HEB_HTR_GT143.jpg
# Renamed XML: 0021_11-3_312_5_0002-Mattathias-0124.xml -> HEB_HTR_GT143.xml
# Updated fileName in XML: HEB_HTR_GT143.jpg
# Renamed image: 0021_IMG_20190731_123917.jpg -> HEB_HTR_GT144.jpg
# Renamed XML: 0021_IMG_20190731_123917.xml -> HEB_HTR_GT144.xml
# Updated fileName in XML: HEB_HTR_GT144.jpg
# Renamed image: 0021_IMG_20190801_164815.jpg -> HEB_HTR_GT145.jpg
# Renamed XML: 0021_IMG_20190801_164815.xml -> HEB_HTR_GT145.xml
# Updated fileName in XML: HEB_HTR_GT145.jpg
# Renamed image: 0022_11-3_312_5_0002-Mattathias-0135.jpg -> HEB_HTR_GT146.jpg
# Renamed XML: 0022_11-3_312_5_0002-Mattathias-0135.xml -> HEB_HTR_GT146.xml
# Updated fileName in XML: HEB_HTR_GT146.jpg
# Renamed image: 0022_IMG_20190731_123926.jpg -> HEB_HTR_GT147.jpg
# Renamed XML: 0022_IMG_20190731_123926.xml -> HEB_HTR_GT147.xml
# Updated fileName in XML: HEB_HTR_GT147.jpg
# Renamed image: 0022_IMG_20190801_164825.jpg -> HEB_HTR_GT148.jpg
# Renamed XML: 0022_IMG_20190801_164825.xml -> HEB_HTR_GT148.xml
# Updated fileName in XML: HEB_HTR_GT148.jpg
# Renamed image: 0023_11-3_312_5_0002-Mattathias-0156.jpg -> HEB_HTR_GT149.jpg
# Renamed XML: 0023_11-3_312_5_0002-Mattathias-0156.xml -> HEB_HTR_GT149.xml
# Updated fileName in XML: HEB_HTR_GT149.jpg
# Renamed image: 0023_IMG_20190731_123934.jpg -> HEB_HTR_GT150.jpg
# Renamed XML: 0023_IMG_20190731_123934.xml -> HEB_HTR_GT150.xml
# Updated fileName in XML: HEB_HTR_GT150.jpg
# Renamed image: 0023_IMG_20190801_164828.jpg -> HEB_HTR_GT151.jpg
# Renamed XML: 0023_IMG_20190801_164828.xml -> HEB_HTR_GT151.xml
# Updated fileName in XML: HEB_HTR_GT151.jpg
# Renamed image: 0024_11-3_312_5_0002-Mattathias-0158.jpg -> HEB_HTR_GT152.jpg
# Renamed XML: 0024_11-3_312_5_0002-Mattathias-0158.xml -> HEB_HTR_GT152.xml
# Updated fileName in XML: HEB_HTR_GT152.jpg
# Renamed image: 0024_IMG_20190731_123944.jpg -> HEB_HTR_GT153.jpg
# Renamed XML: 0024_IMG_20190731_123944.xml -> HEB_HTR_GT153.xml
# Updated fileName in XML: HEB_HTR_GT153.jpg
# Renamed image: 0024_IMG_20190801_164837.jpg -> HEB_HTR_GT154.jpg
# Renamed XML: 0024_IMG_20190801_164837.xml -> HEB_HTR_GT154.xml
# Updated fileName in XML: HEB_HTR_GT154.jpg
# Renamed image: 0025_11-3_312_5_0002-Mattathias-0159.jpg -> HEB_HTR_GT155.jpg
# Renamed XML: 0025_11-3_312_5_0002-Mattathias-0159.xml -> HEB_HTR_GT155.xml
# Updated fileName in XML: HEB_HTR_GT155.jpg
# Renamed image: 0025_IMG_20190731_123948.jpg -> HEB_HTR_GT156.jpg
# Renamed XML: 0025_IMG_20190731_123948.xml -> HEB_HTR_GT156.xml
# Updated fileName in XML: HEB_HTR_GT156.jpg
# Renamed image: 0025_IMG_20190801_164840.jpg -> HEB_HTR_GT157.jpg
# Renamed XML: 0025_IMG_20190801_164840.xml -> HEB_HTR_GT157.xml
# Updated fileName in XML: HEB_HTR_GT157.jpg
# Renamed image: 0026_11-3_312_5_0002-Mattathias-0160.jpg -> HEB_HTR_GT158.jpg
# Renamed XML: 0026_11-3_312_5_0002-Mattathias-0160.xml -> HEB_HTR_GT158.xml
# Updated fileName in XML: HEB_HTR_GT158.jpg
# Renamed image: 0026_IMG_20190731_123957.jpg -> HEB_HTR_GT159.jpg
# Renamed XML: 0026_IMG_20190731_123957.xml -> HEB_HTR_GT159.xml
# Updated fileName in XML: HEB_HTR_GT159.jpg
# Renamed image: 0026_IMG_20190801_164857.jpg -> HEB_HTR_GT160.jpg
# Renamed XML: 0026_IMG_20190801_164857.xml -> HEB_HTR_GT160.xml
# Updated fileName in XML: HEB_HTR_GT160.jpg
# Renamed image: 0027_11-3_312_5_0002-Mattathias-0161.jpg -> HEB_HTR_GT161.jpg
# Renamed XML: 0027_11-3_312_5_0002-Mattathias-0161.xml -> HEB_HTR_GT161.xml
# Updated fileName in XML: HEB_HTR_GT161.jpg
# Renamed image: 0027_IMG_20190731_124001.jpg -> HEB_HTR_GT162.jpg
# Renamed XML: 0027_IMG_20190731_124001.xml -> HEB_HTR_GT162.xml
# Updated fileName in XML: HEB_HTR_GT162.jpg
# Renamed image: 0027_IMG_20190801_164907.jpg -> HEB_HTR_GT163.jpg
# Renamed XML: 0027_IMG_20190801_164907.xml -> HEB_HTR_GT163.xml
# Updated fileName in XML: HEB_HTR_GT163.jpg
# Renamed image: 0028_11-3_312_5_0002-Mattathias-0162.jpg -> HEB_HTR_GT164.jpg
# Renamed XML: 0028_11-3_312_5_0002-Mattathias-0162.xml -> HEB_HTR_GT164.xml
# Updated fileName in XML: HEB_HTR_GT164.jpg
# Renamed image: 0028_IMG_20190731_124025.jpg -> HEB_HTR_GT165.jpg
# Renamed XML: 0028_IMG_20190731_124025.xml -> HEB_HTR_GT165.xml
# Updated fileName in XML: HEB_HTR_GT165.jpg
# Renamed image: 0028_IMG_20190801_164922.jpg -> HEB_HTR_GT166.jpg
# Renamed XML: 0028_IMG_20190801_164922.xml -> HEB_HTR_GT166.xml
# Updated fileName in XML: HEB_HTR_GT166.jpg
# Renamed image: 0029_11-3_312_5_0002-Mattathias-0168.jpg -> HEB_HTR_GT167.jpg
# Renamed XML: 0029_11-3_312_5_0002-Mattathias-0168.xml -> HEB_HTR_GT167.xml
# Updated fileName in XML: HEB_HTR_GT167.jpg
# Renamed image: 0029_IMG_20190731_124030.jpg -> HEB_HTR_GT168.jpg
# Renamed XML: 0029_IMG_20190731_124030.xml -> HEB_HTR_GT168.xml
# Updated fileName in XML: HEB_HTR_GT168.jpg
# Renamed image: 0029_IMG_20190801_164926.jpg -> HEB_HTR_GT169.jpg
# Renamed XML: 0029_IMG_20190801_164926.xml -> HEB_HTR_GT169.xml
# Updated fileName in XML: HEB_HTR_GT169.jpg
# Renamed image: 0030_11-3_312_5_0002-Mattathias-0170.jpg -> HEB_HTR_GT170.jpg
# Renamed XML: 0030_11-3_312_5_0002-Mattathias-0170.xml -> HEB_HTR_GT170.xml
# Updated fileName in XML: HEB_HTR_GT170.jpg
# Renamed image: 0030_IMG_20190731_124040.jpg -> HEB_HTR_GT171.jpg
# Renamed XML: 0030_IMG_20190731_124040.xml -> HEB_HTR_GT171.xml
# Updated fileName in XML: HEB_HTR_GT171.jpg
# Renamed image: 0030_IMG_20190801_164943.jpg -> HEB_HTR_GT172.jpg
# Renamed XML: 0030_IMG_20190801_164943.xml -> HEB_HTR_GT172.xml
# Updated fileName in XML: HEB_HTR_GT172.jpg
# Renamed image: 0031_11-3_312_5_0002-Mattathias-0171.jpg -> HEB_HTR_GT173.jpg
# Renamed XML: 0031_11-3_312_5_0002-Mattathias-0171.xml -> HEB_HTR_GT173.xml
# Updated fileName in XML: HEB_HTR_GT173.jpg
# Renamed image: 0031_IMG_20190731_124047.jpg -> HEB_HTR_GT174.jpg
# Renamed XML: 0031_IMG_20190731_124047.xml -> HEB_HTR_GT174.xml
# Updated fileName in XML: HEB_HTR_GT174.jpg
# Renamed image: 0031_IMG_20190801_164949.jpg -> HEB_HTR_GT175.jpg
# Renamed XML: 0031_IMG_20190801_164949.xml -> HEB_HTR_GT175.xml
# Updated fileName in XML: HEB_HTR_GT175.jpg
# Renamed image: 0032_11-3_312_5_0002-Mattathias-0173.jpg -> HEB_HTR_GT176.jpg
# Renamed XML: 0032_11-3_312_5_0002-Mattathias-0173.xml -> HEB_HTR_GT176.xml
# Updated fileName in XML: HEB_HTR_GT176.jpg
# Renamed image: 0032_IMG_20190731_124057.jpg -> HEB_HTR_GT177.jpg
# Renamed XML: 0032_IMG_20190731_124057.xml -> HEB_HTR_GT177.xml
# Updated fileName in XML: HEB_HTR_GT177.jpg
# Renamed image: 0032_IMG_20190801_165000.jpg -> HEB_HTR_GT178.jpg
# Renamed XML: 0032_IMG_20190801_165000.xml -> HEB_HTR_GT178.xml
# Updated fileName in XML: HEB_HTR_GT178.jpg
# Renamed image: 0033_11-3_312_5_0002-Mattathias-0174.jpg -> HEB_HTR_GT179.jpg
# Renamed XML: 0033_11-3_312_5_0002-Mattathias-0174.xml -> HEB_HTR_GT179.xml
# Updated fileName in XML: HEB_HTR_GT179.jpg
# Renamed image: 0033_IMG_20190731_124102.jpg -> HEB_HTR_GT180.jpg
# Renamed XML: 0033_IMG_20190731_124102.xml -> HEB_HTR_GT180.xml
# Updated fileName in XML: HEB_HTR_GT180.jpg
# Renamed image: 0033_IMG_20190801_165005.jpg -> HEB_HTR_GT181.jpg
# Renamed XML: 0033_IMG_20190801_165005.xml -> HEB_HTR_GT181.xml
# Updated fileName in XML: HEB_HTR_GT181.jpg
# Renamed image: 0034_11-3_312_5_0002-Mattathias-0180.jpg -> HEB_HTR_GT182.jpg
# Renamed XML: 0034_11-3_312_5_0002-Mattathias-0180.xml -> HEB_HTR_GT182.xml
# Updated fileName in XML: HEB_HTR_GT182.jpg
# Renamed image: 0034_IMG_20190731_124110.jpg -> HEB_HTR_GT183.jpg
# Renamed XML: 0034_IMG_20190731_124110.xml -> HEB_HTR_GT183.xml
# Updated fileName in XML: HEB_HTR_GT183.jpg
# Renamed image: 0034_IMG_20190801_165014.jpg -> HEB_HTR_GT184.jpg
# Renamed XML: 0034_IMG_20190801_165014.xml -> HEB_HTR_GT184.xml
# Updated fileName in XML: HEB_HTR_GT184.jpg
# Renamed image: 0035_11-3_312_5_0002-Mattathias-0189.jpg -> HEB_HTR_GT185.jpg
# Renamed XML: 0035_11-3_312_5_0002-Mattathias-0189.xml -> HEB_HTR_GT185.xml
# Updated fileName in XML: HEB_HTR_GT185.jpg
# Renamed image: 0035_IMG_20190731_124118.jpg -> HEB_HTR_GT186.jpg
# Renamed XML: 0035_IMG_20190731_124118.xml -> HEB_HTR_GT186.xml
# Updated fileName in XML: HEB_HTR_GT186.jpg
# Renamed image: 0035_IMG_20190801_165019.jpg -> HEB_HTR_GT187.jpg
# Renamed XML: 0035_IMG_20190801_165019.xml -> HEB_HTR_GT187.xml
# Updated fileName in XML: HEB_HTR_GT187.jpg
# Renamed image: 0036_11-3_312_5_0002-Mattathias-0190.jpg -> HEB_HTR_GT188.jpg
# Renamed XML: 0036_11-3_312_5_0002-Mattathias-0190.xml -> HEB_HTR_GT188.xml
# Updated fileName in XML: HEB_HTR_GT188.jpg
# Renamed image: 0036_IMG_20190731_124127.jpg -> HEB_HTR_GT189.jpg
# Renamed XML: 0036_IMG_20190731_124127.xml -> HEB_HTR_GT189.xml
# Updated fileName in XML: HEB_HTR_GT189.jpg
# Renamed image: 0036_IMG_20190801_165026.jpg -> HEB_HTR_GT190.jpg
# Renamed XML: 0036_IMG_20190801_165026.xml -> HEB_HTR_GT190.xml
# Updated fileName in XML: HEB_HTR_GT190.jpg
# Renamed image: 0037_11-3_312_5_0002-Mattathias-0196.jpg -> HEB_HTR_GT191.jpg
# Renamed XML: 0037_11-3_312_5_0002-Mattathias-0196.xml -> HEB_HTR_GT191.xml
# Updated fileName in XML: HEB_HTR_GT191.jpg
# Renamed image: 0037_IMG_20190731_124135.jpg -> HEB_HTR_GT192.jpg
# Renamed XML: 0037_IMG_20190731_124135.xml -> HEB_HTR_GT192.xml
# Updated fileName in XML: HEB_HTR_GT192.jpg
# Renamed image: 0037_IMG_20190801_165030.jpg -> HEB_HTR_GT193.jpg
# Renamed XML: 0037_IMG_20190801_165030.xml -> HEB_HTR_GT193.xml
# Updated fileName in XML: HEB_HTR_GT193.jpg
# Renamed image: 0038_11-3_312_5_0002-Mattathias-0198.jpg -> HEB_HTR_GT194.jpg
# Renamed XML: 0038_11-3_312_5_0002-Mattathias-0198.xml -> HEB_HTR_GT194.xml
# Updated fileName in XML: HEB_HTR_GT194.jpg
# Renamed image: 0038_IMG_20190731_124147.jpg -> HEB_HTR_GT195.jpg
# Renamed XML: 0038_IMG_20190731_124147.xml -> HEB_HTR_GT195.xml
# Updated fileName in XML: HEB_HTR_GT195.jpg
# Renamed image: 0038_IMG_20190801_165034.jpg -> HEB_HTR_GT196.jpg
# Renamed XML: 0038_IMG_20190801_165034.xml -> HEB_HTR_GT196.xml
# Updated fileName in XML: HEB_HTR_GT196.jpg
# Renamed image: 0039_11-3_312_5_0002-Mattathias-0200.jpg -> HEB_HTR_GT197.jpg
# Renamed XML: 0039_11-3_312_5_0002-Mattathias-0200.xml -> HEB_HTR_GT197.xml
# Updated fileName in XML: HEB_HTR_GT197.jpg
# Renamed image: 0039_IMG_20190731_124153.jpg -> HEB_HTR_GT198.jpg
# Renamed XML: 0039_IMG_20190731_124153.xml -> HEB_HTR_GT198.xml
# Updated fileName in XML: HEB_HTR_GT198.jpg
# Renamed image: 0039_IMG_20190801_165042.jpg -> HEB_HTR_GT199.jpg
# Renamed XML: 0039_IMG_20190801_165042.xml -> HEB_HTR_GT199.xml
# Updated fileName in XML: HEB_HTR_GT199.jpg
# Renamed image: 0040_11-3_312_5_0002-Mattathias-0201.jpg -> HEB_HTR_GT200.jpg
# Renamed XML: 0040_11-3_312_5_0002-Mattathias-0201.xml -> HEB_HTR_GT200.xml
# Updated fileName in XML: HEB_HTR_GT200.jpg

# %%
img_file = 'blablalbla.jpeg'
img_file.split(sep='.')[1]
# Out:
# 'jpeg'
